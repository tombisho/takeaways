# %% [markdown]
# Checking the raw data

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.text import *
import string
from unidecode import unidecode

# %%
df = pd.read_csv('/home/trpb2/data/takeaway/result_2019-11-06.txt', sep = '\t')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'FHRSID', 'LocalAuthorityBusinessID', 'BusinessName',
#        'BusinessType', 'BusinessTypeID', 'AddressLine1', 'AddressLine2',
#        'AddressLine3', 'AddressLine4', 'PostCode', 'RatingValue', 'RatingDate',
#        'LocalAuthorityCode', 'LocalAuthorityName', 'scores.Hygiene',
#        'scores.Structural', 'scores.ConfidenceInManagement',
#        'geocode.longitude', 'geocode.latitude', 'meta.extractDate',
#        'LocalAuthorityId', 'DownloadDate', 'LastPublishedDate'],
#       dtype='object')

# %%
len(df)
# Out:
# 531605

# %%
len(df[df.BusinessType == 'Takeaway/sandwich shop'])
# Out:
# 54288

# %%
len(df[df.BusinessType == 'Restaurant/Cafe/Canteen'])
# Out:
# 121025

# %%
df[df.BusinessType == 'Takeaway/sandwich shop']
# Out:
#         Unnamed: 0   FHRSID LocalAuthorityBusinessID  \
# 9                9   506499             PI/000023107
# 10              10  1132343             PI/000096668
# 20              20   987293             PI/000084185
# 44              44   506480             PI/000022130
# 58              58   505949             PI/000000955
# 66              66   507025             PI/000075216
# 91              91   741406             PI/000090505
# 106            106  1014387             PI/000096703
# 139            139   799963             PI/000091698
# 142            142   813277             PI/000091533
# 180            180   785612             PI/000091508
# 183            183   507011             PI/000075052
# 211            211   506570             PI/000026940
# 212            212   922159             PI/000092515
# 231            231   850595             PI/000092451
# 320            320   861798             PI/000092952
# 328            328  1071991             PI/000098653
# ...

# %%
df.groupby('LocalAuthorityName').size()
# Out:
# LocalAuthorityName
# Aberdeen City                           1977
# Aberdeenshire                           2074
# Adur                                     439
# Allerdale                               1125
# Amber Valley                            1024
# Anglesey                                 740
# Angus                                    928
# Antrim and Newtownabbey                 1128
# Ards and North Down                     1317
# Argyll and Bute                          907
# Armagh City, Banbridge and Craigavon    1677
# Arun                                    1162
# Ashfield                                 834
# Ashford                                 1089
# Aylesbury Vale                          1401
# Babergh                                  857
# Barking and Dagenham                    1017
# Barnet                                  2132
# Barnsley                                1833
# Barrow-in-Furness                        545
# ...
