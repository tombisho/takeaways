# %% [markdown]
# ## Takeaway name classifier implementation

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.text import *
import string
from unidecode import unidecode

# %% [markdown]
# ## Consumer the PHE data and label
#
# Load the file and the model, apply the model and store the output

# %%
df_phe = pd.read_csv('30_03_2020_PHE_method.csv')

# %%
df = pd.read_csv('07_07_2020_final.csv')

valid_idx = df[df.valid].index
train_idx = df[~df.valid].index

bal_idx = []
for k, v in zip(df.index, df.bal):
    bal_idx += [k]*v

# %%
df2_phe = df_phe[["BusinessName"]]

# %%
df2_phe
# Out:
#                                             BusinessName
# 0                                           abc barbeque
# 1                                    abm - happy kitchen
# 2                            adilias station road bakery
# 3                                     amt cappuccino bar
# 4                                  arbury court fish bar
# 5                    arjuna ltd kitchen 1 & ground floor
# 6                                       baguette company
# 7                                     barracuda fish bar
# 8                            bon appetit mayfair limited
# 9                                       boost juice bars
# 10                                               cafe 24
# 11                                           cafe aristo
# 12                             cambridge blue sandwiches
# 13                             cambridge blue sandwiches
# 14                          cambridge farmers outlet hut
# 15                                          cherry house
# 16                                       chicken cottage
# 17                                          chicken rush
# 18                                       chinese canteen
# 19                                            chosen bun
# 20                                    christ's park cafe
# 21                  cinnamon/panshee bangladesh takeaway
# 22                                            city kebab
# 23                                          crepeaffaire
# 24                                     cromwell takeaway
# 25                                          cyprus kebab
# 26                                      delice de france
# 27                                               delight
# 28                                        domino's pizza
# 29                                        domino's pizza
# ...                                                  ...
# 65223                                     taste of china
# 65224                                     the real china
# 65225                                burger king limited
# 65226                                burger king limited
# 65227                                   byron hamburgers
# 65228  cafe rouge (also t/a stack & grill, wonder chi...
# 65229                       chef lu's chinese restaurant
# 65230                              cjs chicken and pizza
# 65231                                       indian ocean
# 65232               indian tiffin service york - england
# 65233                                                kfc
# 65234                                                kfc
# 65235             masala craft fine indian kitchen & bar
# 65236                          mcdonalds restaurants ltd
# 65237                          mcdonalds restaurants ltd
# 65238                          mcdonalds restaurants ltd
# 65239                          mcdonalds restaurants ltd
# 65240                                      pizza express
# 65241                                      pizza express
# 65242                                      pizza express
# 65243                               pizza hut restaurant
# 65244                               pizza hut restaurant
# 65245                          sapphire chinese takeaway
# 65246                                   sloppy's burgers
# 65247                                             subway
# 65248                                the garden of india
# 65249                                  the indian lounge
# 65250                       the mulan chinese restaurant
# 65251                               the viceroy of india
# 65252                       thompsons fish & chips (a64)
#
# [65253 rows x 1 columns]

# %%
class LetterTokenizer(BaseTokenizer):
    "Character level tokenizer function."
    def __init__(self, lang): pass
    def tokenizer(self, t:str) -> List[str]:
        out = []
        i = 0
        while i < len(t):
            if t[i:].startswith(BOS):
                out.append(BOS)
                i += len(BOS)
            else:
                out.append(t[i])
                i += 1
        return out
            
    def add_special_cases(self, toks:Collection[str]): pass

# %%
itos = [UNK, BOS] + list(string.ascii_lowercase + " -'@&)(." +"0123456789")

# %%
vocab=Vocab(itos)
tokenizer=Tokenizer(LetterTokenizer, pre_rules=[], post_rules=[])

# %%
train_df = df.iloc[train_idx, [3,2]]
bal_df = df.iloc[bal_idx, [3,2]]
valid_df = df.iloc[valid_idx, [3,2]]

# %%
df_small = df2_phe[0:200]

# %% [markdown]
# ## Classifier with Just Eat data

# %%
data = TextClasDataBunch.from_df(path='.', train_df=bal_df, valid_df=valid_df,
                         tokenizer=tokenizer, vocab=vocab,
                         mark_fields=False, bs=128)

# %%
data.add_test(df2_phe)

# %%
data
# Out:
# TextClasDataBunch;
#
# Train: LabelList (40038 items)
# x: TextList
# xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a,xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a,xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a,xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a,xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a
# y: CategoryList
# Fast Food,Fast Food,Fast Food,Fast Food,Fast Food
# Path: .;
#
# Valid: LabelList (4000 items)
# x: TextList
# xxbos   o m a r   s h a r i f s,xxbos   c h a r g h a s   f a s t   f o o d,xxbos   r o b e r t o ' s   p i z z a,xxbos   p o p   i n,xxbos   j a s m i n e   i n n
# y: CategoryList
# South Asian,Fast Food,Pizza,Fish & Chips,Southeast & East Asian
# Path: .;
#
# Test: LabelList (65253 items)
# x: TextList
# xxbos   a b c   b a r b e q u e,xxbos   a b m   -   h a p p y   k i t c h e n,xxbos   a d i l i a s   s t a t i o n   r o a d   b a k e r y,xxbos   a m t   c a p p u c c i n o   b a r,xxbos   a r b u r y   c o u r t   f i s h   b a r
# y: EmptyLabelList
# ,,,,
# Path: .

# %%
learn = text_classifier_learner(data, AWD_LSTM, drop_mult=0.4, bptt=70)

# %%
learn.load('07_07_2020_final')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (40038 items)
# x: TextList
# xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a,xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a,xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a,xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a,xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a
# y: CategoryList
# Fast Food,Fast Food,Fast Food,Fast Food,Fast Food
# Path: .;
#
# Valid: LabelList (4000 items)
# x: TextList
# xxbos   o m a r   s h a r i f s,xxbos   c h a r g h a s   f a s t   f o o d,xxbos   r o b e r t o ' s   p i z z a,xxbos   p o p   i n,xxbos   j a s m i n e   i n n
# y: CategoryList
# South Asian,Fast Food,Pizza,Fish & Chips,Southeast & East Asian
# Path: .;
#
# Test: LabelList (65253 items)
# x: TextList
# xxbos   a b c   b a r b e q u e,xxbos   a b m   -   h a p p y   k i t c h e n,xxbos   a d i l i a s   s t a t i o n   r o a d   b a k e r y,xxbos   a m t   c a p p u c c i n o   b a r,xxbos   a r b u r y   c o u r t   f i s h   b a r
# y: EmptyLabelList
# ,,,,
# Path: ., model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(46, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(46, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1150, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1150, 1150, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1150, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.16000000000000003)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x2ac6e4371ae8>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: ...
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(46, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(46, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.16000000000000003)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=10, bias=True)
#     )
#   )
# )], add_time=True, silent=None)

# %%
learn.predict(df2_phe.BusinessName[18])
# Out:
# (Category Southeast & East Asian,
#  tensor(9),
#  tensor([3.0248e-08, 7.4545e-10, 7.3720e-11, 5.8726e-33, 3.5318e-10, 7.4385e-11,
#          3.0552e-08, 1.1761e-09, 1.6489e-07, 1.0000e+00]))

# %%
#txt_ci = TextClassificationInterpretation.from_learner(learn)
interp2 = TextClassificationInterpretation(learn, *learn.get_preds(ds_type = DatasetType.Test, ordered = True, with_loss = True))

# %%
preds = interp2.pred_class

# %%
probs = [i.numpy().max() for i in interp2.probs]

# %%
probs
# Out:
# [0.90618414,
#  0.8066343,
#  0.978884,
#  0.9709519,
#  0.9940362,
#  0.36029842,
#  0.9999646,
#  0.9977162,
#  0.5591927,
#  0.63854796,
#  0.95245385,
#  0.67052406,
#  0.999739,
#  0.999739,
#  0.77140063,
#  0.79457814,
#  0.99999833,
#  0.99999976,
#  0.99999976,
#  0.93750024,
#  0.87470937,
#  0.9949708,
#  0.9999994,
#  0.9996081,
#  0.6075147,
#  0.99999976,
#  0.90337515,
#  0.8164276,
#  0.9999918,
#  0.9999918,
#  0.9999918,
#  0.32498372,
#  0.9999969,
#  0.9397374,
#  0.611787,
#  0.9999995,
#  0.67263985,
#  0.9038936,
#  0.9781718,
#  0.9865247,
#  0.98953676,
#  0.999509,
#  0.96630424,
#  0.41494775,
#  0.5112004,
#  0.8072738,
#  0.9975032,
#  0.99801874,
#  0.86194766,
#  0.4354783,
#  0.9981231,
#  0.9981231,
#  0.98034954,
#  0.83195794,
#  0.37740615,
#  0.9987237,
#  0.8655512,
#  0.8756727,
#  0.9999707,
#  0.9915308,
#  0.9999796,
#  0.9999889,
#  0.9998423,
#  0.43819976,
#  0.8542738,
#  0.97256666,
#  0.94277346,
#  0.9668719,
#  0.9668719,
#  0.9668719,
#  0.85582733,
#  0.96804374,
#  0.5728723,
#  0.99961615,
#  0.8498602,
#  0.57807,
#  0.9971859,
#  0.44072592,
#  0.9910987,
#  0.8793216,
#  0.9917195,
#  0.58288926,
#  0.71657455,
#  0.38955033,
#  0.99777204,
#  0.47091344,
#  0.38568628,
#  0.77516246,
#  0.9969783,
#  0.9999944,
#  0.9394789,
#  0.6317746,
#  0.9947941,
#  1.0,
#  0.9997936,
#  0.9999918,
#  0.9999918,
#  0.99999976,
#  0.9999722,
#  0.9999931,
#  0.9999969,
#  0.99657875,
#  0.9956053,
#  0.99984777,
#  0.9931518,
#  0.9993198,
#  0.9999405,
#  0.7536201,
#  0.5618377,
#  0.9998821,
#  0.9616581,
#  0.9968548,
#  0.94367146,
#  0.9999845,
#  0.388491,
#  0.3099327,
#  0.9662338,
#  0.99976414,
#  0.98073995,
#  0.9998142,
#  0.99607974,
#  0.999767,
#  0.995122,
#  0.4747635,
#  0.999803,
#  0.9997218,
#  0.99969447,
#  0.2729793,
#  0.9997818,
#  0.7015314,
#  0.9328294,
#  0.99999976,
#  0.3322219,
#  0.9994112,
#  0.5790111,
#  0.8320805,
#  1.0,
#  0.5526615,
#  0.99813014,
#  0.9276864,
#  0.9135768,
#  0.8734779,
#  0.99999774,
#  0.99999774,
#  0.9979201,
#  0.9943468,
#  0.9898037,
#  0.9999918,
#  0.9999918,
#  0.99997723,
#  0.67658794,
#  0.99999857,
#  0.62979776,
#  0.99999595,
#  0.99999976,
#  0.5305914,
#  0.999997,
#  0.9369094,
#  0.24696317,
#  0.98758477,
#  0.9863171,
#  0.9962071,
#  0.99999964,
#  0.97926897,
#  0.99204975,
#  1.0,
#  0.99596244,
#  0.9990375,
#  0.93358433,
#  0.9999807,
#  0.5094875,
#  0.5094875,
#  0.9999999,
#  0.999895,
#  0.7017055,
#  0.99993205,
#  0.9999962,
#  0.98992246,
#  0.9999994,
#  0.9980241,
#  0.9999987,
#  0.93077815,
#  0.46817243,
#  0.99931216,
#  0.65094984,
#  0.50578874,
#  0.9999695,
#  0.9999584,
#  0.9999398,
#  0.80438584,
#  0.98656946,
#  0.9968913,
#  0.9971083,
#  0.754716,
#  0.9999993,
#  0.99820256,
#  0.991601,
#  0.9999918,
#  0.7469948,
#  0.9999937,
#  0.9687937,
#  0.7535107,
#  0.99998224,
#  0.99885094,
#  0.9787613,
#  0.9999989,
#  0.9292859,
#  0.9999995,
#  0.99803036,
#  0.9999999,
#  0.9999521,
#  0.93301344,
#  0.99644274,
#  0.9921759,
#  0.6062255,
#  0.86942923,
#  0.6095015,
#  0.99988854,
#  0.60032254,
#  0.9997758,
#  0.9999963,
#  0.7346881,
#  0.9951153,
#  0.51039356,
#  0.9990243,
#  0.99827886,
#  0.99985075,
#  0.9901805,
#  0.9668687,
#  0.9668687,
#  0.9992693,
#  0.6906321,
#  0.9999708,
#  0.5056486,
#  0.7089672,
#  0.99999964,
#  0.9845633,
#  0.9990019,
#  0.9848103,
#  0.996902,
#  0.48742524,
#  0.9945468,
#  0.9995029,
#  1.0,
#  0.9999995,
#  0.9999995,
#  0.99510205,
#  0.9999906,
#  0.9996165,
#  0.9999918,
#  0.9999918,
#  0.9999918,
#  0.99975306,
#  0.9990771,
#  0.9935893,
#  0.9999695,
#  0.9396238,
#  0.9983517,
#  0.9915912,
#  0.99955934,
#  0.97816885,
#  0.8985307,
#  0.9999995,
#  0.99999857,
#  0.50933206,
#  0.50004536,
#  0.9892719,
#  0.99208117,
#  0.9906341,
#  0.9999865,
#  0.9999976,
#  0.999882,
#  0.9998098,
#  0.54399455,
#  0.9947195,
#  0.9999672,
#  0.99937844,
#  0.99999213,
#  0.6633542,
#  0.383693,
#  0.9668687,
#  0.9668687,
#  0.9668687,
#  0.9873066,
#  0.9977381,
#  0.89934516,
#  0.9999784,
#  0.4339301,
#  ...]

# %%
result = preds.numpy()

# %%
result
# Out:
# array([0, 0, 7, 6, ..., 8, 9, 8, 4])

# %%
labelled_preds = [learn.data.classes[i] for i in result]

# %%
labelled_preds
# Out:
# ['Burger',
#  'Burger',
#  'Sand/Caf/Bake',
#  'Pizza',
#  'Fish & Chips',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Chicken',
#  'Sand/Caf/Bake',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Chicken',
#  'Southeast & East Asian',
#  'Chicken',
#  'Chicken',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Kebab',
#  'Desserts',
#  'Fish & Chips',
#  'Kebab',
#  'Sand/Caf/Bake',
#  'Fish & Chips',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Kebab',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Desserts',
#  'Fish & Chips',
#  'South Asian',
#  'Desserts',
#  'South Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Kebab',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Pizza',
#  'Desserts',
#  'Sand/Caf/Bake',
#  'Pizza',
#  'South Asian',
#  'Chicken',
#  'Chicken',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Pizza',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Pizza',
#  'Desserts',
#  'Desserts',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Fast Food',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Pizza',
#  'Fish & Chips',
#  'Kebab',
#  'Pizza',
#  'Kebab',
#  'Fish & Chips',
#  'Kebab',
#  'Fish & Chips',
#  'South Asian',
#  'Southeast & East Asian',
#  'Burger',
#  'Fish & Chips',
#  'Pizza',
#  'Pizza',
#  'Kebab',
#  'Kebab',
#  'Kebab',
#  'Kebab',
#  'South Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Pizza',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Pizza',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Fish & Chips',
#  'Fast Food',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fast Food',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Kebab',
#  'Pizza',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Burger',
#  'Chicken',
#  'Fast Food',
#  'Southeast & East Asian',
#  'South Asian',
#  'South Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'South Asian',
#  'Fish & Chips',
#  'Pizza',
#  'Pizza',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Kebab',
#  'Desserts',
#  'Fish & Chips',
#  'Burger',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Fish & Chips',
#  'Kebab',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Kebab',
#  'Chicken',
#  'Chicken',
#  'Kebab',
#  'Pizza',
#  'Desserts',
#  'Southeast & East Asian',
#  'Pizza',
#  'Fish & Chips',
#  'Kebab',
#  'South Asian',
#  'Southeast & East Asian',
#  'Kebab',
#  'Burger',
#  'Fast Food',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'Pizza',
#  'Pizza',
#  'Kebab',
#  'South Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Pizza',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'South Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Pizza',
#  'Southeast & East Asian',
#  'Chicken',
#  'Chicken',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Pizza',
#  'South Asian',
#  'Pizza',
#  'South Asian',
#  'Kebab',
#  'Fish & Chips',
#  'Fish & Chips',
#  'South Asian',
#  'Pizza',
#  'Fish & Chips',
#  'Kebab',
#  'Burger',
#  'Southeast & East Asian',
#  'Chicken',
#  'Chicken',
#  'South Asian',
#  'South Asian',
#  'South Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'South Asian',
#  'Pizza',
#  'Kebab',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Southeast & East Asian',
#  'South Asian',
#  'South Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'South Asian',
#  'Pizza',
#  'Pizza',
#  'Sand/Caf/Bake',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Desserts',
#  'Burger',
#  'Kebab',
#  'Southeast & East Asian',
#  'South Asian',
#  'Chicken',
#  'Pizza',
#  'Kebab',
#  'South Asian',
#  'Chicken',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Burger',
#  'Southeast & East Asian',
#  'Pizza',
#  'South Asian',
#  'Fish & Chips',
#  'South Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Fast Food',
#  'Pizza',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Fast Food',
#  'South Asian',
#  'Fish & Chips',
#  'Chicken',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Fish & Chips',
#  'South Asian',
#  'Fish & Chips',
#  'Desserts',
#  'Southeast & East Asian',
#  'Kebab',
#  'Chicken',
#  'South Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fast Food',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Burger',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'South Asian',
#  'Fish & Chips',
#  'Chicken',
#  'Sand/Caf/Bake',
#  'Pizza',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Pizza',
#  'Burger',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Pizza',
#  'Kebab',
#  'Pizza',
#  'Pizza',
#  'Burger',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Chicken',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'South Asian',
#  'Pizza',
#  'Pizza',
#  'South Asian',
#  'Kebab',
#  'Pizza',
#  'Fish & Chips',
#  'Burger',
#  'Southeast & East Asian',
#  'South Asian',
#  'Southeast & East Asian',
#  'Pizza',
#  'Chicken',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Fish & Chips',
#  'South Asian',
#  'Burger',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Burger',
#  'Fast Food',
#  'Fish & Chips',
#  'South Asian',
#  'Chicken',
#  'Chicken',
#  'Fast Food',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Chicken',
#  'South Asian',
#  'Pizza',
#  'South Asian',
#  'South Asian',
#  'South Asian',
#  'Pizza',
#  'Southeast & East Asian',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Burger',
#  'Desserts',
#  'Pizza',
#  'Fast Food',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Chicken',
#  'Chicken',
#  'Chicken',
#  'Desserts',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Desserts',
#  'Desserts',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Burger',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Fast Food',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'South Asian',
#  'Pizza',
#  'Fast Food',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Chicken',
#  'Sand/Caf/Bake',
#  'Chicken',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'South Asian',
#  'Pizza',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Fish & Chips',
#  'Fast Food',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Sand/Caf/Bake',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'South Asian',
#  'Kebab',
#  'South Asian',
#  'South Asian',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Burger',
#  'South Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fast Food',
#  'Fish & Chips',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Pizza',
#  'Sand/Caf/Bake',
#  'Burger',
#  'Chicken',
#  'Southeast & East Asian',
#  'South Asian',
#  'Southeast & East Asian',
#  'Kebab',
#  'South Asian',
#  'Burger',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fast Food',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'South Asian',
#  'South Asian',
#  'Kebab',
#  'South Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Kebab',
#  'Pizza',
#  'Fish & Chips',
#  'Chicken',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Pizza',
#  'Fish & Chips',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fast Food',
#  'Burger',
#  'Southeast & East Asian',
#  'South Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Pizza',
#  'South Asian',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Pizza',
#  'Kebab',
#  'Southeast & East Asian',
#  'Kebab',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'South Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fast Food',
#  'Fish & Chips',
#  'South Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Burger',
#  'Kebab',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Fast Food',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Desserts',
#  'Desserts',
#  'Pizza',
#  'South Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Kebab',
#  'Southeast & East Asian',
#  'Pizza',
#  'Pizza',
#  'Fish & Chips',
#  'Chicken',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'Fish & Chips',
#  'South Asian',
#  'Kebab',
#  'South Asian',
#  'Fish & Chips',
#  'Pizza',
#  'Desserts',
#  'South Asian',
#  'Pizza',
#  'Pizza',
#  'Kebab',
#  'Sand/Caf/Bake',
#  'Burger',
#  'Chicken',
#  'Fish & Chips',
#  'Desserts',
#  'Kebab',
#  'Southeast & East Asian',
#  'South Asian',
#  'Kebab',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Southeast & East Asian',
#  'Burger',
#  'Fish & Chips',
#  'Pizza',
#  'South Asian',
#  'Southeast & East Asian',
#  'Pizza',
#  'Pizza',
#  'Kebab',
#  'South Asian',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'Pizza',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Kebab',
#  'Kebab',
#  'Fish & Chips',
#  'Fish & Chips',
#  'South Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Pizza',
#  'Fast Food',
#  'Chicken',
#  'Fish & Chips',
#  'Chicken',
#  'Chicken',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Southeast & East Asian',
#  'Kebab',
#  'South Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Kebab',
#  'Chicken',
#  'Fish & Chips',
#  'Kebab',
#  'Southeast & East Asian',
#  'Fast Food',
#  'Kebab',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'South Asian',
#  'Burger',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'South Asian',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Southeast & East Asian',
#  'South Asian',
#  'Fast Food',
#  'Sand/Caf/Bake',
#  'Pizza',
#  'Chicken',
#  'Burger',
#  'Fish & Chips',
#  'South Asian',
#  'Fish & Chips',
#  'Desserts',
#  'Burger',
#  'Southeast & East Asian',
#  'Desserts',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Desserts',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'South Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'South Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Chicken',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Southeast & East Asian',
#  'Kebab',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Burger',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Chicken',
#  'Chicken',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Desserts',
#  'South Asian',
#  'Pizza',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'South Asian',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Southeast & East Asian',
#  'Pizza',
#  'Pizza',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'South Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'Desserts',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Chicken',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Kebab',
#  'Fish & Chips',
#  'Kebab',
#  'South Asian',
#  'Pizza',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Kebab',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Pizza',
#  'South Asian',
#  'Fast Food',
#  'Fish & Chips',
#  'Pizza',
#  'Pizza',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Chicken',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Burger',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Chicken',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'Kebab',
#  'Fish & Chips',
#  'Chicken',
#  'Chicken',
#  'Kebab',
#  'South Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'South Asian',
#  'Fish & Chips',
#  'South Asian',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Chicken',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Burger',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'Chicken',
#  'Kebab',
#  'Fast Food',
#  'Fish & Chips',
#  'South Asian',
#  'South Asian',
#  'South Asian',
#  'Chicken',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'South Asian',
#  'Kebab',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Burger',
#  'South Asian',
#  'Southeast & East Asian',
#  'Desserts',
#  'Sand/Caf/Bake',
#  'South Asian',
#  'South Asian',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'South Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'South Asian',
#  'South Asian',
#  'Pizza',
#  'Burger',
#  'Chicken',
#  'South Asian',
#  'Southeast & East Asian',
#  'Chicken',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Fish & Chips',
#  'Kebab',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'South Asian',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Chicken',
#  'Burger',
#  'Pizza',
#  'Pizza',
#  'Burger',
#  'Fish & Chips',
#  'South Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'South Asian',
#  'Fish & Chips',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Fast Food',
#  'Burger',
#  'Kebab',
#  'Sand/Caf/Bake',
#  'Kebab',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Desserts',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Chicken',
#  'Chicken',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Kebab',
#  'South Asian',
#  'Pizza',
#  'Pizza',
#  'Pizza',
#  'Southeast & East Asian',
#  'Pizza',
#  'Fish & Chips',
#  'Pizza',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Kebab',
#  'Fast Food',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Kebab',
#  'Chicken',
#  'Southeast & East Asian',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Fish & Chips',
#  'Pizza',
#  'Kebab',
#  'Pizza',
#  'Fish & Chips',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Pizza',
#  'South Asian',
#  'Pizza',
#  'Pizza',
#  'Chicken',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Sand/Caf/Bake',
#  'Southeast & East Asian',
#  'Fish & Chips',
#  'Chicken',
#  'Pizza',
#  'Southeast & East Asian',
#  ...]

# %%
df2_phe['output'] = labelled_preds
# Out:
# /home/trpb2/.conda/envs/fastai_v1/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_label = df2_phe

# %%
replacers = ["mcdonald", "burger king", "kfc", "papa john", "domino", "subway", "gregg" ]

# %%
chain_map = {"mcdonald":"Burger", "kfc":"Chicken"}
#chains2 = {r"\b{}\b".format(k): v for k, v in chains2.items()}

# %%
for item in replacers:
    df_label.loc[df_label['BusinessName'].str.contains(item), 'tempName'] = item

df_label["output"]=df_label["tempName"].map(chain_map).fillna(df_label['output'])
# Out:
# /home/trpb2/.conda/envs/fastai_v1/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/trpb2/.conda/envs/fastai_v1/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/trpb2/.conda/envs/fastai_v1/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/trpb2/.conda/envs/fastai_v1/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/trpb2/.conda/envs/fastai_v1/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_out = df_phe
df_out['output'] = df_label['output']
df_out['probs'] = probs

# %%
df_out
# Out:
#        Unnamed: 0   FHRSID LocalAuthorityBusinessID  \
# 0               9   506499             PI/000023107
# 1              10  1132343             PI/000096668
# 2              20   987293             PI/000084185
# 3              43   506480             PI/000022130
# 4              57   505949             PI/000000955
# 5              65   507025             PI/000075216
# 6              90   741406             PI/000090505
# 7             105  1014387             PI/000096703
# 8             138   799963             PI/000091698
# 9             141   813277             PI/000091533
# 10            178   785612             PI/000091508
# 11            181   507011             PI/000075052
# 12            208   506570             PI/000026940
# 13            209   922159             PI/000092515
# 14            228   850595             PI/000092451
# 15            316   861798             PI/000092952
# 16            324  1071991             PI/000098653
# 17            325   506948             PI/000073042
# 18            327   730090             PI/000085691
# 19            334  1043482             PI/000094036
# 20            338  1160004             PI/000098975
# 21            342   816226             PI/000092242
# 22            344   506429             PI/000019610
# 23            391   705112             PI/000046453
# 24            393  1027419             PI/000097216
# 25            399   656917             PI/000084523
# 26            405   506884             PI/000071172
# 27            406   983730             PI/000096045
# 28            425   506561             PI/000026188
# 29            426   636730             PI/000083075
# ...           ...      ...                      ...
# 65223        1741   192763                    32606
# 65224        1870   376379                    52826
# 65225         234   245851                    25047
# 65226         235   245302                    21858
# 65227         250   245553                      249
# 65228         262   245758                    20000
# 65229         316   245411                     3322
# 65230         346   456420                    34740
# 65231         737   245027                     4696
# 65232         738   972426                    64439
# 65233         785   244952                     1558
# 65234         786   576468                    51764
# 65235         918   245889                     5343
# 65236         927   714991                    53391
# 65237         928   245189                    16490
# 65238         929   244703                    22102
# 65239         930   834142                    62396
# 65240        1130   245635                     3936
# 65241        1131   244993                      221
# 65242        1132   245363                    40592
# 65243        1136   245126                      248
# 65244        1137   246106                    26512
# 65245        1261   676651                    25999
# 65246        1303  1045090                    65736
# 65247        1378   245947                    29270
# 65248        1507   246261                     3535
# 65249        1532   244996                    29956
# 65250        1562   244965                     7854
# 65251        1624   245292                    21766
# 65252        1659   244755                    27673
#
#                                             BusinessName  \
# 0                                           abc barbeque
# 1                                    abm - happy kitchen
# 2                            adilias station road bakery
# 3                                     amt cappuccino bar
# 4                                  arbury court fish bar
# 5                    arjuna ltd kitchen 1 & ground floor
# 6                                       baguette company
# 7                                     barracuda fish bar
# 8                            bon appetit mayfair limited
# 9                                       boost juice bars
# 10                                               cafe 24
# 11                                           cafe aristo
# 12                             cambridge blue sandwiches
# 13                             cambridge blue sandwiches
# 14                          cambridge farmers outlet hut
# 15                                          cherry house
# 16                                       chicken cottage
# 17                                          chicken rush
# 18                                       chinese canteen
# 19                                            chosen bun
# 20                                    christ's park cafe
# 21                  cinnamon/panshee bangladesh takeaway
# 22                                            city kebab
# 23                                          crepeaffaire
# 24                                     cromwell takeaway
# 25                                          cyprus kebab
# 26                                      delice de france
# 27                                               delight
# 28                                        domino's pizza
# 29                                        domino's pizza
# ...                                                  ...
# 65223                                     taste of china
# 65224                                     the real china
# 65225                                burger king limited
# 65226                                burger king limited
# 65227                                   byron hamburgers
# 65228  cafe rouge (also t/a stack & grill, wonder chi...
# 65229                       chef lu's chinese restaurant
# 65230                              cjs chicken and pizza
# 65231                                       indian ocean
# 65232               indian tiffin service york - england
# 65233                                                kfc
# 65234                                                kfc
# 65235             masala craft fine indian kitchen & bar
# 65236                          mcdonalds restaurants ltd
# 65237                          mcdonalds restaurants ltd
# 65238                          mcdonalds restaurants ltd
# 65239                          mcdonalds restaurants ltd
# 65240                                      pizza express
# 65241                                      pizza express
# 65242                                      pizza express
# 65243                               pizza hut restaurant
# 65244                               pizza hut restaurant
# 65245                          sapphire chinese takeaway
# 65246                                   sloppy's burgers
# 6                          Addenbrookes                           Hills Road
# 7                        39 Ditton Lane                            Cambridge
# 8        Astrazeneca Uk Ltd Bon Appetit          Cambridge Biomedical Campus
# 9                             Juice Bar                            Lion Yard
# 10                     24 Regent Street                            Cambridge
# 11                     16 Silver Street                            Cambridge
# 12                        48 Hills Road                            Cambridge
# 13     The Faculty Of Law Sidgwick Site                         10 West Road
# 14                        Street Record                         Station Road
# 15                       53 High Street                        Cherry Hinton
# 16                        83A Mill Road                            Cambridge
# 17                       164 Hills Road                            Cambridge
# 18                     30 Bridge Street                            Cambridge
# 19                        27 Hills Road                            Cambridge
# 20                   The Bus Stop Kiosk                       Christs Pieces
# 21                      180 High Street                           Chesterton
# 22                     73 Regent Street                            Cambridge
# 23                     66 Bridge Street                            Cambridge
# 24                     29 Cromwell Road                            Cambridge
# 25                62 Cherry Hinton Road                            Cambridge
# 26                     Kiosk Platform 1            Cambridge Railway Station
# 27                     23 Barnwell Road                            Cambridge
# 28                      113 Histon Road                            Cambridge
# 29                   11 Rectory Terrace                          High Street
# ...                                 ...                                  ...
# 65223                               NaN                    221 Beverley Road
# 65224                               NaN  Unit 43 St Stephens Shopping Centre
# 65225                               NaN                        Stirling Road
# 65226                   Railway Station                         Station Road
# 65227                               NaN                     11 High Ousegate
# 65228                               NaN                     52 Low Petergate
# 65229                     40 Huby Court                   Speculation Street
# 65230                               NaN                     74 Fourth Avenue
# 65231                               NaN                         37 The Green
# 65232                               NaN                                  NaN
# 65233                               NaN                    47 Blossom Street
# 65234                               NaN                        Stirling Road
# 65235                               NaN                      12A King Street
# 65236                               NaN                    Monks Cross Drive
# 65237                               NaN                        Hurricane Way
# 65238      Unit F6 York Designer Outlet                   St Nicholas Avenue
# 65239                               NaN                   Boroughbridge Road
# 65240                               NaN                10 St Sampsons Square
# 65241                               NaN                     17 Museum Street
# 65242      Unit F7 York Designer Outlet                   St Nicholas Avenue
# 65243                               NaN                          10 Pavement
# 65244      Unit F4 Monks Cross Shopping                    Monks Cross Drive
# 65245                               NaN                         76 The Mount
# 65246                       Sparks York                     17-21 Piccadilly
# 65247                               NaN                    2 Clifford Street
# 65248                               NaN                     5 Fawcett Street
# 65249                               NaN                         26 Swinegate
# 65250                     2 Tower Court                         Oakdale Road
# 65251                               NaN                          26 Monkgate
# 65252                         Hazelbush                          Malton Road
#
#                  AddressLine3              AddressLine4  ...  \
# 0                   Cambridge            Cambridgeshire  ...
# 1              Cambridgeshire                       NaN  ...
# 2              Cambridgeshire                       NaN  ...
# 3                   Cambridge            Cambridgeshire  ...
# 4              Cambridgeshire                       NaN  ...
# 5              Cambridgeshire                       NaN  ...
# 6                   Cambridge            Cambridgeshire  ...
# 7              Cambridgeshire                       NaN  ...
# 8        Francis Crick Avenue  Cambridge Cambridgeshire  ...
# 9                   Cambridge            Cambridgeshire  ...
# 10             Cambridgeshire                       NaN  ...
# 11             Cambridgeshire                       NaN  ...
# 12             Cambridgeshire                       NaN  ...
# 13                  Cambridge            Cambridgeshire  ...
# 14                  Cambridge            Cambridgeshire  ...
# 15                  Cambridge            Cambridgeshire  ...
# 16             Cambridgeshire                       NaN  ...
# 17             Cambridgeshire                       NaN  ...
# 18             Cambridgeshire                       NaN  ...
# 19             Cambridgeshire                       NaN  ...
# 20             Drummer Street  Cambridge Cambridgeshire  ...
# 21                  Cambridge            Cambridgeshire  ...
# 22             Cambridgeshire                       NaN  ...
# 23             Cambridgeshire                       NaN  ...
# 24             Cambridgeshire                       NaN  ...
# 25             Cambridgeshire                       NaN  ...
# 26               Station Road  Cambridge Cambridgeshire  ...
# 27             Cambridgeshire                       NaN  ...
# 28             Cambridgeshire                       NaN  ...
# 29              Cherry Hinton  Cambridge Cambridgeshire  ...
# ...                       ...                       ...  ...
# 65223      Kingston Upon Hull                       NaN  ...
# 65224           110 Ferensway        Kingston Upon Hull  ...
# 65225                    York                       NaN  ...
# 65226                    York                       NaN  ...
# 65227                    York                       NaN  ...
# 65228                    York                       NaN  ...
# 65229                    York                       NaN  ...
# 65230                    York                       NaN  ...
# 65231                   Acomb                      York  ...
# 65232                     NaN                       NaN  ...
# 65233                    York                       NaN  ...
# 65234            Clifton Moor                      York  ...
# 65235                    York                       NaN  ...
# 65236              Huntington                      York  ...
# 65237                    York                       NaN  ...
# 65238                    York                       NaN  ...
# 65239               Poppleton                      York  ...
# 65240                    York                       NaN  ...
# 65241                    York                       NaN  ...
# 65242                    York                       NaN  ...
# 65243                    York                       NaN  ...
# 65244              Huntington                      York  ...
# 65245                    York                       NaN  ...
# 65246                    York                       NaN  ...
# 65247                    York                       NaN  ...
# 65248                    York                       NaN  ...
# 65249                    York                       NaN  ...
# 65250                    York                       NaN  ...
# 65251                    York                       NaN  ...
# 65252  Stockton On The Forest                      York  ...
#
#       scores.Structural scores.ConfidenceInManagement geocode.longitude  \
# 0                  15.0                          10.0          0.143618
# 1                   NaN                           NaN          0.145604
# 2                   5.0                           5.0          0.131527
# 3                  15.0                           5.0          0.137284
# 4                   5.0                           5.0          0.128207
# 5                   5.0                           0.0          0.133661
# 6                   5.0                           0.0               NaN
# 7                   5.0                           5.0          0.168617
# 8                  10.0                           5.0               NaN
# 9                   5.0                           5.0          0.121312
# 10                 10.0                           5.0          0.124801
# 11                  5.0                           5.0          0.116213
# 12                  5.0                           5.0          0.129207
# 13                 10.0                          10.0          0.109670
# 14                  5.0                          10.0               NaN
# 15                  5.0                           5.0          0.173007
# 16                 15.0                          20.0          0.136538
# 17                 10.0                          10.0          0.135849
# 18                 10.0                          10.0          0.117171
# 19                 10.0                          10.0          0.129470
# 20                 15.0                          20.0               NaN
# 21                 15.0                          10.0          0.143687
# 22                  0.0                           0.0          0.125982
# 23                 10.0                          10.0          0.118708
# 24                  5.0                           5.0          0.146573
# 25                 10.0                          10.0          0.138899
# 26                  5.0                           5.0          0.137283
# 27                 10.0                          20.0          0.163205
# 28                  5.0                           0.0          0.110813
# 29                  0.0                           5.0          0.173618
# ...                 ...                           ...               ...
# 65223              10.0                          10.0         -0.349352
# 65224               5.0                          10.0         -0.345079
# 65225               0.0                           5.0         -1.102793
# 65226               0.0                           0.0         -1.093038
# 65227               5.0                           5.0         -1.081473
# 65228              10.0                           5.0         -1.081227
# 65229               5.0                          10.0         -1.071501
# 65230               5.0                           5.0         -1.059542
# 65231              10.0                          10.0         -1.130466
# 65232               5.0                          10.0               NaN
# 65233               5.0                           0.0         -1.093081
# 65234               5.0                           0.0         -1.102793
# 65235              10.0                           5.0         -1.082696
# 65236               5.0                           0.0         -1.049217
# 65237               5.0                           5.0         -1.110386
# 65238               5.0                           0.0         -1.077482
# 65239               5.0                           5.0         -1.142935
# 65240               0.0                           0.0         -1.081648
# 65241               5.0                           0.0         -1.086438
# 65242               5.0                           5.0         -1.077482
# 65243               5.0                           0.0         -1.079388
# 65244               5.0                           5.0         -1.045283
# 65245              20.0                          20.0         -1.094662
# 65246               5.0                           5.0         -1.079523
# 65247               0.0                           5.0         -1.082174
# 65248              10.0                           5.0         -1.075757
# 65249              10.0                          10.0         -1.081578
# 65250               5.0                           5.0         -1.101276
# 65251               5.0                           5.0         -1.075815
# 65252               5.0                           5.0         -0.984506
#
#        geocode.latitude     meta.extractDate  LocalAuthorityId  DownloadDate  \
# 0             52.198028  0001-01-01T00:00:00                 1    2019-09-25
# 1             52.212226  0001-01-01T00:00:00                 1    2019-09-25
# 2             52.195190  0001-01-01T00:00:00                 1    2019-09-25
# 3             52.194106  0001-01-01T00:00:00                 1    2019-09-25
# 4             52.224635  0001-01-01T00:00:00                 1    2019-09-25
# 5             52.201248  0001-01-01T00:00:00                 1    2019-09-25
# 6                   NaN  0001-01-01T00:00:00                 1    2019-09-25
# 7             52.216176  0001-01-01T00:00:00                 1    2019-09-25
# 8                   NaN  0001-01-01T00:00:00                 1    2019-09-25
# 9             52.204698  0001-01-01T00:00:00                 1    2019-09-25
# 10            52.201740  0001-01-01T00:00:00                 1    2019-09-25
# 11            52.202093  0001-01-01T00:00:00                 1    2019-09-25
# 12            52.196859  0001-01-01T00:00:00                 1    2019-09-25
# 13            52.201769  0001-01-01T00:00:00                 1    2019-09-25
# 14                  NaN  0001-01-01T00:00:00                 1    2019-09-25
# 15            52.186736  0001-01-01T00:00:00                 1    2019-09-25
# 16            52.200530  0001-01-01T00:00:00                 1    2019-09-25
# 17            52.188889  0001-01-01T00:00:00                 1    2019-09-25
# 18            52.209629  0001-01-01T00:00:00                 1    2019-09-25
# 19            52.197151  0001-01-01T00:00:00                 1    2019-09-25
# 20                  NaN  0001-01-01T00:00:00                 1    2019-09-25
# 21            52.218016  0001-01-01T00:00:00                 1    2019-09-25
# 22            52.201027  0001-01-01T00:00:00                 1    2019-09-25
# 23            52.208090  0001-01-01T00:00:00                 1    2019-09-25
# 24            52.202263  0001-01-01T00:00:00                 1    2019-09-25
# 25            52.188744  0001-01-01T00:00:00                 1    2019-09-25
# 26            52.194105  0001-01-01T00:00:00                 1    2019-09-25
# 27            52.211140  0001-01-01T00:00:00                 1    2019-09-25
# 28            52.217539  0001-01-01T00:00:00                 1    2019-09-25
# 29            52.187884  0001-01-01T00:00:00                 1    2019-09-25
# ...                 ...                  ...               ...           ...
# 65223         53.757794  0001-01-01T00:00:00               405    2019-09-25
# 18     2019-09-25T00:30:05.643  Southeast & East Asian  1.000000
# 19     2019-09-25T00:30:05.643  Southeast & East Asian  0.937500
# 20     2019-09-25T00:30:05.643           Sand/Caf/Bake  0.874709
# 21     2019-09-25T00:30:05.643             South Asian  0.994971
# 22     2019-09-25T00:30:05.643                   Kebab  0.999999
# 23     2019-09-25T00:30:05.643                Desserts  0.999608
# 24     2019-09-25T00:30:05.643            Fish & Chips  0.607515
# 25     2019-09-25T00:30:05.643                   Kebab  1.000000
# 26     2019-09-25T00:30:05.643           Sand/Caf/Bake  0.903375
# 27     2019-09-25T00:30:05.643            Fish & Chips  0.816428
# 28     2019-09-25T00:30:05.643                   Pizza  0.999992
# 29     2019-09-25T00:30:05.643                   Pizza  0.999992
# ...                        ...                     ...       ...
# 65223   2019-09-25T00:34:05.44  Southeast & East Asian  0.999734
# 65224   2019-09-25T00:34:05.44  Southeast & East Asian  0.967481
# 65225   2019-09-25T00:34:06.72                  Burger  0.999993
# 65226   2019-09-25T00:34:06.72                  Burger  0.999993
# 65227   2019-09-25T00:34:06.72                  Burger  0.999997
# 65228   2019-09-25T00:34:06.72                 Chicken  0.608496
# 65229   2019-09-25T00:34:06.72  Southeast & East Asian  0.999999
# 65230   2019-09-25T00:34:06.72               Fast Food  0.999831
# 65231   2019-09-25T00:34:06.72             South Asian  0.999633
# 65232   2019-09-25T00:34:06.72             South Asian  0.998467
# 65233   2019-09-25T00:34:06.72                 Chicken  0.508087
# 65234   2019-09-25T00:34:06.72                 Chicken  0.508087
# 65235   2019-09-25T00:34:06.72             South Asian  0.994248
# 65236   2019-09-25T00:34:06.72                  Burger  0.471480
# 65237   2019-09-25T00:34:06.72                  Burger  0.471480
# 65238   2019-09-25T00:34:06.72                  Burger  0.471480
# 65239   2019-09-25T00:34:06.72                  Burger  0.471480
# 65240   2019-09-25T00:34:06.72                   Pizza  0.999917
# 65241   2019-09-25T00:34:06.72                   Pizza  0.999917
# 65242   2019-09-25T00:34:06.72                   Pizza  0.999917
# 65243   2019-09-25T00:34:06.72                   Pizza  0.999273
# 65244   2019-09-25T00:34:06.72                   Pizza  0.999273
# 65245   2019-09-25T00:34:06.72  Southeast & East Asian  0.999996
# 65246   2019-09-25T00:34:06.72                  Burger  1.000000
# 65247   2019-09-25T00:34:06.72           Sand/Caf/Bake  0.967114
# 65248   2019-09-25T00:34:06.72             South Asian  0.998136
# 65249   2019-09-25T00:34:06.72             South Asian  0.999752
# 65250   2019-09-25T00:34:06.72  Southeast & East Asian  0.999948
# 65251   2019-09-25T00:34:06.72             South Asian  0.999603
# 65252   2019-09-25T00:34:06.72            Fish & Chips  0.986273
#
# [65253 rows x 26 columns]

# %%
df_out.to_csv('07_07_2020_phe_output.csv', index=False)

# %%
counts = df_out.groupby('output').BusinessName.count().sort_values(ascending=False)
counts
# Out:
# output
# Southeast & East Asian    12789
# Fish & Chips              10013
# Pizza                      9843
# Sand/Caf/Bake              8491
# South Asian                8014
# Burger                     5430
# Chicken                    4266
# Kebab                      3909
# Desserts                   1281
# Fast Food                  1217
# Name: BusinessName, dtype: int64
