# %% [markdown]
# Offline steps:
#
# 1. Combine scraped files
# 2. Use Notepad++ to convert encoding to UTF8
# 3. sort out carriage returns etc.
# 4. End up with rawest_just_eat.csv
#
# Long story:
# 1. Get raw scraped files
# 2. Open them in Notepad++ and choose Encode in UTF8
# 3. This didn't work for #7 which had to be saved as unicode text and then saved as UTF 8
# 4. Then knit them together in Python

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.text import *
import string
from unidecode import unidecode

# %%
je = pd.read_csv('/home/trpb2/data/takeaway/rawest_just_eat.csv')

# %%
my_dir = '/home/trpb2/takeaways/data/scraped/'

# %%
je_temp = pd.concat([pd.read_csv(my_dir+f) for f in os.listdir(my_dir)], ignore_index = True)

# %%
je = je_temp[['Name','Cuisines']]

# %%
je = pd.concat([je['Name'], je['Cuisines'].str.split(', ', expand=True)], axis=1)

# %%
je.columns = ['text','label','label2','label3']

# %%
je[je.label.isna()]
# Out:
#               text label label2 label3
# 171    We're sorry   NaN    NaN    NaN
# 366    We're sorry   NaN    NaN    NaN
# 377    We're sorry   NaN    NaN    NaN
# 433    We're sorry   NaN    NaN    NaN
# 519    We're sorry   NaN    NaN    NaN
# 616    We're sorry   NaN    NaN    NaN
# 1296   We're sorry   NaN    NaN    NaN
# 1338   We're sorry   NaN    NaN    NaN
# 1641   We're sorry   NaN    NaN    NaN
# 1687   We're sorry   NaN    NaN    NaN
# 1737   We're sorry   NaN    NaN    NaN
# 1757   We're sorry   NaN    NaN    NaN
# 2017   We're sorry   NaN    NaN    NaN
# 2142   We're sorry   NaN    NaN    NaN
# 2455   We're sorry   NaN    NaN    NaN
# 2668   We're sorry   NaN    NaN    NaN
# 2892   We're sorry   NaN    NaN    NaN
# 3065   We're sorry   NaN    NaN    NaN
# 3202   We're sorry   NaN    NaN    NaN
# 3281   We're sorry   NaN    NaN    NaN
# 3728   We're sorry   NaN    NaN    NaN
# 3745   We're sorry   NaN    NaN    NaN
# 3764   We're sorry   NaN    NaN    NaN
# 3821   We're sorry   NaN    NaN    NaN
# 18048          NaN   NaN    NaN    NaN
# 22302          NaN   NaN    NaN    NaN
# 26660          NaN   NaN    NaN    NaN
# 32687          NaN   NaN    NaN    NaN

# %%
je.dropna(thresh=3, inplace=True)

# %%
je['text'] = je.text.str.lower()

# %%
deliv = pd.read_csv('/home/trpb2/data/takeaway/deliveroo_full_scrape_combined_12.04.2020.csv')

# %%
cols = [0,1,6,7,8,9,10,11,12]
deliv.drop(deliv.columns[cols], axis=1,inplace=True)

# %%
deliv.columns = ['text','label','label2','label3']

# %%
deliv['text'] = deliv.text.str.lower()

# %%
deliv = deliv[deliv['text'].notna()]

# %%
df = pd.concat([je, deliv], ignore_index=True)

# %% [markdown]
# ## Character Set
#
# What letters outside of ASCII are in the names?

# %%
foreign_chars = Counter(_ for _ in ''.join(str(list(df.text))) if _ not in string.ascii_letters)
foreign_chars.most_common()
# Out:
# [(' ', 143302),
#  ("'", 81943),
#  (',', 43252),
#  ('-', 14291),
#  ('"', 8795),
#  ('&', 3757),
#  ('®', 579),
#  ('(', 556),
#  (')', 555),
#  ('2', 374),
#  ('’', 373),
#  ('1', 364),
#  ('.', 295),
#  ('@', 227),
#  ('4', 216),
#  ('0', 189),
#  ('3', 166),
#  ('8', 119),
#  ('7', 115),
#  ('9', 110),
#  ('5', 109),
#  ('6', 108),
#  ('\\', 100),
#  ('!', 96),
#  ('/', 78),
#  ('é', 64),
#  ('`', 24),
#  ('+', 21),
#  ('´', 19),
#  ('–', 11),
#  ('城', 11),
#  ('味', 10),
#  ('‘', 9),
#  (':', 9),
#  ('食', 9),
#  ('#', 8),
#  ('美', 8),
#  ('小', 8),
#  ('ä', 6),
#  ('è', 6),
#  ('中', 6),
#  ('大', 6),
#  ('菜', 6),
#  ('馆', 6),
#  ('面', 6),
#  ('米', 6),
#  ('*', 5),
#  ('ö', 5),
#  ('?', 5),
#  ('老', 5),
#  ('餐', 5),
#  ('香', 5),
#  ('🍣', 5),
#  ('⚡', 4),
#  ('茶', 4),
#  ('国', 4),
#  ('酒', 4),
#  ('家', 4),
#  ('豪', 4),
#  ('轩', 4),
#  ('好', 4),
#  ('辣', 4),
#  ('ï', 4),
#  ('🌶', 4),
#  ('🏄', 4),
#  ('ê', 3),
#  ('南', 3),
#  ('东', 3),
#  ('太', 3),
#  ('華', 3),
#  ('館', 3),
#  ('🐓', 3),
#  ('临', 3),
#  ('樓', 3),
#  ('友', 3),
#  ('帝', 3),
#  ('吃', 3),
#  ('皇', 3),
#  ('羊', 3),
#  ('宫', 3),
#  ('🇯', 3),
#  ('🇵', 3),
#  ('西', 3),
#  ('安', 3),
#  ('记', 3),
#  ('肉', 3),
#  ('红', 3),
#  ('火', 3),
#  ('齐', 3),
#  ('水', 3),
#  ('🇬', 3),
#  ('🇷', 3),
#  ('ó', 2),
#  ('%', 2),
#  ('~', 2),
#  ('ü', 2),
#  ('°', 2),
#  ('居', 2),
#  ('屋', 2),
#  ('全', 2),
#  ('金', 2),
#  ('成', 2),
#  ('都', 2),
#  ('熊', 2),
#  ('新', 2),
#  ('川', 2),
#  ('🏆', 2),
#  ('楼', 2),
#  ('麵', 2),
#  ('冠', 2),
#  ('厅', 2),
#  ('点', 2),
#  ('心', 2),
#  ('🥑', 2),
#  ('軒', 2),
#  ('富', 2),
#  ('龙', 2),
#  ('麻', 2),
#  ('锅', 2),
#  ('朋', 2),
#  ('炸', 2),
#  ('鸡', 2),
#  ('海', 2),
#  ('朝', 2),
#  ('冒', 2),
#  ('厨', 2),
#  ('王', 2),
#  ('湘', 2),
#  ('í', 2),
#  ('府', 2),
#  ('子', 2),
#  ('🍕', 2),
#  ('鹭', 2),
#  ('曼', 2),
#  ('手', 2),
#  ('作', 2),
#  ('拉', 2),
#  ('乌', 2),
#  ('冬', 2),
#  ('蜀', 2),
#  ('人', 2),
#  ('韩', 2),
#  ('凉', 2),
#  ('皮', 2),
#  ('夹', 2),
#  ('馍', 2),
#  ('间', 2),
#  ('🐔', 2),
#  ('🇨', 2),
#  ('一', 2),
#  ('柒', 2),
#  ('山', 2),
#  ('道', 2),
#  ('炭', 2),
#  ('云', 2),
#  ('🍔', 2),
#  ('🍖', 2),
#  ('🔥', 2),
#  ('华', 2),
#  ('线', 2),
#  ('[', 1),
#  ('á', 1),
#  ('_', 1),
#  ('波', 1),
#  ('霸', 1),
#  ('時', 1),
#  ('間', 1),
#  ('煲', 1),
#  ('迦', 1),
#  ('广', 1),
#  ('元', 1),
#  ('素', 1),
#  ('日', 1),
#  ('出', 1),
#  ('猫', 1),
#  ('师', 1),
#  ('傅', 1),
#  ('四', 1),
#  ('风', 1),
#  ('明', 1),
#  ('珠', 1),
#  ('餞', 1),
#  ('来', 1),
#  ('哥', 1),
#  ('如', 1),
#  ('意', 1),
#  ('星', 1),
#  ('年', 1),
#  ('凰', 1),
#  ('底', 1),
#  ('捞', 1),
#  ('汉', 1),
#  ('漢', 1),
#  ('ě', 1),
#  ('呷', 1),
#  ('回', 1),
#  ('港', 1),
#  ('式', 1),
#  ('陳', 1),
#  ('記', 1),
#  ('燒', 1),
#  ('臘', 1),
#  ('ç', 1),
#  ('桥', 1),
#  ('爱', 1),
#  ('俱', 1),
#  ('乐', 1),
#  ('部', 1),
#  ('锦', 1),
#  ('里', 1),
#  ('焯', 1),
#  ('粤', 1),
#  ('诚', 1),
#  ('品', 1),
#  ('駿', 1),
#  ('茗', 1),
#  ('上', 1),
#  ('妹', 1),
#  ('裕', 1),
#  ('园', 1),
#  ('根', 1),
#  ('据', 1),
#  ('地', 1),
#  ('宮', 1),
#  ('农', 1),
#  ('國', 1),
#  ('先', 1),
#  ('生', 1),
#  ('孟', 1),
#  ('非', 1),
#  ('的', 1),
#  ('料', 1),
#  ('理', 1),
#  ('🌱', 1),
#  ('汇', 1),
#  ('银', 1),
#  ('急', 1),
#  ('行', 1),
#  ('有', 1),
#  ('北', 1),
#  ('超', 1),
#  ('市', 1),
#  ('方', 1),
#  ('芭', 1),
#  ('雅', 1),
#  ('漂', 1),
#  ('亮', 1),
#  ('ã', 1),
#  ('佳', 1),
#  ('🇳', 1),
#  ('灯', 1),
#  ('笼', 1),
#  ('）', 1),
#  ('禾', 1),
#  ('聚', 1),
#  ('堂', 1),
#  ('饭', 1),
#  ('盒', 1),
#  ('主', 1),
#  ('义', 1),
#  ('奶', 1),
#  ('映', 1),
#  ('塘', 1),
#  ('石', 1),
#  ('库', 1),
#  ('门', 1),
#  ('春', 1),
#  ('天', 1),
#  ('紅', 1),
#  ('陽', 1),
#  ('廳', 1),
#  ('巴', 1),
#  ('â', 1),
#  ('郎', 1),
#  ('湖', 1),
#  ('烤', 1),
#  ('蓝', 1),
#  ('月', 1),
#  ('🍨', 1),
#  ('🍦', 1),
#  ('重', 1),
#  ('庆', 1),
#  ('街', 1),
#  ('|', 1),
#  ('ì', 1),
#  ('英', 1),
#  ('荣', 1),
#  ('和', 1),
#  ('气', 1),
#  ('貓', 1),
#  ('杨', 1),
#  ('公', 1),
#  ('延', 1),
#  ('吉', 1),
#  ('串', 1),
#  ('芳', 1),
#  ('永', 1),
#  ('雲', 1),
#  ('鄭', 1),
#  ('🇾', 1),
#  ('七', 1),
#  ('思', 1),
#  ('包', 1),
#  ('快', 1),
#  ('（', 1),
#  ('東', 1),
#  ('園', 1),
#  (']', 1)]

# %%
df['ascii_name'] = df.text.apply(lambda x: unidecode(str(x)))
df[df.text != df.ascii_name]
# Out:
#                                                     text        label  \
# 56                         subway® - 7 wellmeadow street   Sandwiches
# 93                                           café  bagel       Bagels
# 99                         ollie’s kebab ye / fish&chips        Kebab
# 110                        subway® gravesend high street      Subways
# 118                               hennie penny’s chicken      Chicken
# 192                                subway® - london road   Sandwiches
# 214                                 subway® - charon way   Sandwiches
# 299                         subway® wakefield drive thru      Subways
# 346                       subway® - coventry high street   Sandwiches
# 350                            subway®- 9/11 high street   Sandwiches
# 355                                subway® - turner rise   Sandwiches
# 356                               subway® - hull station   Sandwiches
# 368                             subway® chatham dockside   Sandwiches
# 445                                 subway® passey place      Subways
# 450                          subway® - st. peters street   Sandwiches
# 455                                              subway®   Sandwiches
# 475                               subway® - whitton road   Sandwiches
# 481                                         subway® bury      Subways
# 488                                        lily’s bistro    Breakfast
# 505                                          kaviné cafe      English
# 529                                  subway® walton vale      Subways
# 577                     subway® - north road, darlington      Subways
# 578                                              subway®   Sandwiches
# 616                             subway® - 39 high street   Sandwiches
# 618                          subway® - framwellgate moor   Sandwiches
# 620                              subway® - quarry street   Sandwiches
# 641                                              subway®   Sandwiches
# 652                     subway® midland way (nottingham)      Subways
# 693                                    subway® chingford      Subways
# 695                               subway® moulsford mews      Subways
# ...                                                  ...          ...
# 42948                           yong xiang 永香 - brockley  Gluten Free
# 42988                               yun hua 雲華 - clapham      Seafood
# 42993                    yun restaurant 云 - east central      Chinese
# 42994                        yun restaurant 云 - vauxhall      Chinese
# 43014                          zamano’s pizza - woolston     American
# 43054                                  zheng chelsea 鄭餐館   Vegetarian
# 43083                          🇬🇷 hungry donkey greek 🇬🇷        Vegan
# 43084                           🇬🇷uncle tony's taverna🇨🇾        Greek
# 43085                  🌶 bombay bicycle chef - kilburn 🌶        Curry
# 43086                            🌶 bombay bicycle chef 🌶        Curry
# 43087                                     🍔 rox burger 🍔      British
# 43088                        🍖 bullgogi 🍖 - holland park       Korean
# 43089                                         🍣 maguro 🍣        Sushi
# 43090                             🏄 honi poke - mayfair🏄       Salads
# 43091                                      🏄 honi poke 🏄     Japanese
# 43092                                           🔥 gogi 🔥       Korean
# 43093  七茶/ seven tea (bubble tea) - leicester city ce...   Bubble Tea
# 43094                                    味美思包子 - radford      Chinese
# 43095                   大华小吃 da hua street food - hendon      Chinese
# 43096                     大华快餐（dahua fast food) - hendon      Chinese
# 43097                        家 home kong - salford quays      Noodles
# 43098                     山水间 shan shui jian - limehouse      Chinese
# 43099               東園小館 - east garden - willesden green      Chinese
# 43100         米kome japanese & korean sushi - brick lane       Korean
# 43101                    米kome japanese sushi - woodford     Japanese
# 43102                         米线 "mixian" - rice noodles      Chinese
# 43103                           米线 "mixian" rice noodles      Chinese
# 43104                      羊城 - yang sing  - princess st      Chinese
# 43105       食全小厨 fodal oriental kitchen - \tcanary wharf      Noodles
# 43106                       香辣居 chilli legend - shadwell      Chicken
#
#              label2    label3  \
# 56            Lunch     Halal
# 93            Vegan      None
# 99     Fish & Chips      None
# 110      Sandwiches      None
# 118        American      None
# 192           Halal      None
# 214           Lunch      None
# 299      Sandwiches      None
# 346           Lunch      None
# 350           Lunch      None
# 355           Lunch      None
# 356           Lunch     Halal
# 368           Lunch      None
# 445      Sandwiches      None
# 450           Lunch      None
# 455          Salads      None
# 475           Lunch      None
# 481      Sandwiches      None
# 488      Sandwiches      None
# 505        European      None
# 529      Sandwiches      None
# 577           Lunch      None
# 578          Salads      None
# 616           Lunch      None
# 618           Lunch      None
# 620          Salads      None
# 641         English      None
# 652      Sandwiches      None
# 693      Sandwiches     Halal
# 695      Sandwiches     Halal
# ...             ...       ...
# 42948       Noodles   Chinese
# 42988         Curry   Chinese
# 42993       Noodles   Chinese
# 42994       Noodles   Chinese
# 43014         Halal  American
# 43054       Chinese   Chinese
# 43083        Salads     Greek
# 43084         Mezze     Greek
# 43085        Indian    Indian
# 43086        Indian    Indian
# 43087        Brunch   British
# 43088           Bbq    Korean
# 43089      Japanese  Japanese
# 43090          Poke  Hawaiian
# 43091       Healthy  Japanese
# 43092           Bbq    Korean
# 43093       Chinese   Chinese
# 43094       Noodles   Chinese
# 43095       Dim Sum   Chinese
# 43096           Bbq   Chinese
# 43097       Chinese   Chinese
# 43098       Dim Sum   Chinese
# 43099           NaN   Chinese
# 43100      Japanese    Korean
# 43101        Korean  Japanese
# 43102         Asian   Chinese
# 43103       Chicken   Chinese
# 43104       Dim Sum   Chinese
# 43105       Chinese   Chinese
# 43106       Noodles       NaN
#
#                                               ascii_name
# 56                       subway(r) - 7 wellmeadow street
# 93                                           cafe  bagel
# 99                         ollie's kebab ye / fish&chips
# 110                      subway(r) gravesend high street
# 118                               hennie penny's chicken
# 192                              subway(r) - london road
# 214                               subway(r) - charon way
# 299                       subway(r) wakefield drive thru
# 346                     subway(r) - coventry high street
# 350                          subway(r)- 9/11 high street
# 355                              subway(r) - turner rise
# 356                             subway(r) - hull station
# 368                           subway(r) chatham dockside
# 445                               subway(r) passey place
# 450                        subway(r) - st. peters street
# 455                                            subway(r)
# 475                             subway(r) - whitton road
# 481                                       subway(r) bury
# 488                                        lily's bistro
# 505                                          kavine cafe
# 529                                subway(r) walton vale
# 577                   subway(r) - north road, darlington
# 578                                            subway(r)
# 616                           subway(r) - 39 high street
# 618                        subway(r) - framwellgate moor
# 620                            subway(r) - quarry street
# 641                                            subway(r)
# 652                   subway(r) midland way (nottingham)
# 693                                  subway(r) chingford
# 695                             subway(r) moulsford mews
# ...                                                  ...
# 42948                  yong xiang Yong Xiang  - brockley
# 42988                         yun hua Yun Hua  - clapham
# 42993                 yun restaurant Yun  - east central
# 42994                     yun restaurant Yun  - vauxhall
# 43014                          zamano's pizza - woolston
# 43054                      zheng chelsea Zheng Can Guan
# 43083                               hungry donkey greek
# 43084                               uncle tony's taverna
# 43085                     bombay bicycle chef - kilburn
# 43086                               bombay bicycle chef
# 43087                                        rox burger
# 43088                           bullgogi  - holland park
# 43089                                            maguro
# 43090                                honi poke - mayfair
# 43091                                         honi poke
# 43092                                              gogi
# 43093  Qi Cha / seven tea (bubble tea) - leicester ci...
# 43094                       Wei Mei Si Bao Zi  - radford
# 43095       Da Hua Xiao Chi  da hua street food - hendon
# 43096         Da Hua Kuai Can (dahua fast food) - hendon
# 43097                     Jia  home kong - salford quays
# 43098         Shan Shui Jian  shan shui jian - limehouse
# 43099  Dong Yuan Xiao Guan  - east garden - willesden...
# 43100       Mi kome japanese & korean sushi - brick lane
# 43101                  Mi kome japanese sushi - woodford
# 43102                   Mi Xian  "mixian" - rice noodles
# 43103                     Mi Xian  "mixian" rice noodles
# 43104             Yang Cheng  - yang sing  - princess st
# 43105  Shi Quan Xiao Chu  fodal oriental kitchen - \t...
# 43106              Xiang La Ju  chilli legend - shadwell
#
# [1234 rows x 5 columns]

# %%
foreign_chars = Counter(_ for _ in ''.join(str(list(df.ascii_name))) if _ not in string.ascii_letters)
foreign_chars.most_common()
# Out:
# [(' ', 143734),
#  ("'", 81576),
#  (',', 43252),
#  ('-', 14302),
#  ('"', 9563),
#  ('&', 3757),
#  ('(', 1136),
#  (')', 1135),
#  ('2', 374),
#  ('1', 364),
#  ('.', 295),
#  ('@', 227),
#  ('4', 216),
#  ('0', 188),
#  ('3', 166),
#  ('8', 119),
#  ('7', 115),
#  ('9', 110),
#  ('5', 109),
#  ('6', 108),
#  ('\\', 97),
#  ('!', 96),
#  ('/', 78),
#  ('`', 24),
#  ('+', 21),
#  (':', 9),
#  ('?', 9),
#  ('#', 8),
#  ('[', 5),
#  ('*', 5),
#  (']', 5),
#  ('%', 2),
#  ('~', 2),
#  ('_', 1),
#  ('|', 1)]

# %%
df[df.text.str.contains('`')]
# Out:
#                                    text           label    label2   label3  \
# 229                       tim`s chipper    Fish & Chips     Kebab     None
# 2635                         tk`s pizza           Pizza   Italian    Halal
# 3856                 valentino`s pizzas         Italian     Pizza     None
# 7009               st andrew`s takeaway    Fish & Chips     Pizza     None
# 12344                            pepe`s           Pizza   Burgers     None
# 13671                    sauro`s chippy    Fish & Chips   Burgers     None
# 15367               tj`s chicken xpress         Chicken   Burgers     None
# 15543             smithy`s fish & chips    Fish & Chips     Pizza     None
# 17267                    cafe de nero`s         Italian     Pizza     None
# 17270               riccardo`s pizzeria           Kebab     Pizza     None
# 18605                shaheen`s takeaway          Indian     Curry     None
# 18805        sami`s moroccan restaurant  Middle Eastern     Pizza     None
# 20581            yau`s oriental delight         Chinese      Thai     None
# 21563                  raja`s pizza bar           Pizza     Wraps    Halal
# 23939                     uk`s pizzeria           Pizza     Kebab     None
# 24008                           ziggy`s          Indian     Curry    Halal
# 24363                         rosario`s         Italian     Pizza     None
# 25903   uncle sam`s new york burger bar        American   Burgers     None
# 26761                        raimondo`s           Pizza     Kebab     None
# 27927                         saprano`s        American     Pizza    Halal
# 28415                      papi`s pizza           Pizza   Chicken    Halal
# 29587                    torino`s pizza           Pizza     Kebab     None
# 29986           tang`s chinese takeaway         Chinese  Oriental     None
# 35412  henry higgins` - southend on sea         Burgers   British  British
#
#                              ascii_name
# 229                       tim`s chipper
# 2635                         tk`s pizza
# 3856                 valentino`s pizzas
# 7009               st andrew`s takeaway
# 12344                            pepe`s
# 13671                    sauro`s chippy
# 15367               tj`s chicken xpress
# 15543             smithy`s fish & chips
# 17267                    cafe de nero`s
# 17270               riccardo`s pizzeria
# 18605                shaheen`s takeaway
# 18805        sami`s moroccan restaurant
# 20581            yau`s oriental delight
# 21563                  raja`s pizza bar
# 23939                     uk`s pizzeria
# 24008                           ziggy`s
# 24363                         rosario`s
# 25903   uncle sam`s new york burger bar
# 26761                        raimondo`s
# 27927                         saprano`s
# 28415                      papi`s pizza
# 29587                    torino`s pizza
# 29986           tang`s chinese takeaway
# 35412  henry higgins` - southend on sea

# %%
df['ascii_name_fix'] = df.ascii_name.str.replace('`',"'")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace("'","")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('~'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace(']'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('['," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('\\'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('%'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('*'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace(':'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('+'," and ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('&'," and ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('/'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace(')'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('('," ")
suss_chars = ['`',']','%','&','(',')']
df[df.ascii_name_fix.str.contains('|'.join(suss_chars))]
# Out:
# /home/trpb2/.conda/envs/fastai_v1/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   app.launch_new_instance()
#                                                     text         label  \
# 0                         southern fried chicken & pizza       Chicken
# 1                        pizza hut delivery - cambuslang         Pizza
# 2                                       the curry garden        Indian
# 3                                            j & d kebab         Kebab
# 4                                       pepe's piri piri       Chicken
# 5                                maharani indian cuisine        Indian
# 6                                          sweet jamrock     Caribbean
# 7                                                zaafran        Indian
# 8                                           omar sharifs         Kebab
# 9                                             pizza home         Pizza
# 10                                              al badar         Pizza
# 11                        royal plaza chinese restaurant       Chinese
# 12                                  arifa tandoori house        Indian
# 13                                  turtle bay - croydon     Caribbean
# 14                                       massala express        Indian
# 15                                              munchees        Indian
# 16                          bella italia - east kilbride       Italian
# 17                                                ashoka        Indian
# 18                                    charghas fast food        Indian
# 19                                           the grill-o       Burgers
# 20                                  stoneleigh brasserie        Indian
# 21                        asda kitchen - gillingham pier         Pizza
# 22                             harry ramsden - playhouse  Fish & Chips
# 23                                     manha spice house        Indian
# 24                                       roberto's pizza         Pizza
# 25                                     yalpa kebab house         Kebab
# 26                                       tartan tandoori         Pizza
# 27                                           chicken.com         Pizza
# 28                                       icestone gelato      Desserts
# 29                                                pop in  Fish & Chips
# ...                                                  ...           ...
# 43077                              zumu sushi - wilmslow    Vegetarian
# 43078                             zu's - ilford - ilford        Indian
# 43079                                  zu's - upton park        Indian
# 43080                           zz green - finsbury park    Vegetarian
# 43081   zzang korean restaurant - swiss cottage editions        Korean
# 43082                          zzetta - soul fired pizza         Pizza
# 43083                          🇬🇷 hungry donkey greek 🇬🇷         Vegan
# 43084                           🇬🇷uncle tony's taverna🇨🇾         Greek
# 43085                  🌶 bombay bicycle chef - kilburn 🌶         Curry
# 43086                            🌶 bombay bicycle chef 🌶         Curry
# 43087                                     🍔 rox burger 🍔       British
# 43088                        🍖 bullgogi 🍖 - holland park        Korean
# 43089                                         🍣 maguro 🍣         Sushi
# 43090                             🏄 honi poke - mayfair🏄        Salads
# 43091                                      🏄 honi poke 🏄      Japanese
# 43092                                           🔥 gogi 🔥        Korean
# 43093  七茶/ seven tea (bubble tea) - leicester city ce...    Bubble Tea
# 43094                                    味美思包子 - radford       Chinese
# 43095                   大华小吃 da hua street food - hendon       Chinese
# 43096                     大华快餐（dahua fast food) - hendon       Chinese
# 43097                        家 home kong - salford quays       Noodles
# 43098                     山水间 shan shui jian - limehouse       Chinese
# 43099               東園小館 - east garden - willesden green       Chinese
# 43100         米kome japanese & korean sushi - brick lane        Korean
# 43101                    米kome japanese sushi - woodford      Japanese
# 43102                         米线 "mixian" - rice noodles       Chinese
# 43103                           米线 "mixian" rice noodles       Chinese
# 43104                      羊城 - yang sing  - princess st       Chinese
# 43105       食全小厨 fodal oriental kitchen - \tcanary wharf       Noodles
# 43106                       香辣居 chilli legend - shadwell       Chicken
#
#             label2    label3  \
# 0            Pizza     Halal
# 1           Salads      None
# 2      Bangladeshi     Halal
# 3          Turkish      None
# 4        Peri Peri      None
# 5            Curry      None
# 6        Fast Food      None
# 7            Curry      None
# 8           Indian     Halal
# 9          Chicken      None
# 10           Curry      None
# 11            Thai      None
# 12           Curry      None
# 13        Jamaican      None
# 14           Curry      None
# 15         Italian     Halal
# 16           Pasta      None
# 17           Curry     Halal
# 18           Pizza     Halal
# 19         Chicken      None
# 20      Vegetarian     Halal
# 21       Ice Cream      None
# 22         English      None
# 23           Curry     Halal
# 24           Kebab      None
# 25           Pizza      None
# 26           Kebab      None
# 27         Chicken     Halal
# 28       Ice Cream      None
# 29           Kebab      None
# ...            ...       ...
# 43077        Sushi  Japanese
# 43078        Halal    Indian
# 43079        Halal    Indian
# 43080        Vegan   Chinese
# 43081          NaN    Korean
# 43082      Italian   Italian
# 43083       Salads     Greek
# 43084        Mezze     Greek
# 43085       Indian    Indian
# 43086       Indian    Indian
# 43087       Brunch   British
# 43088          Bbq    Korean
# 43089     Japanese  Japanese
# 43090         Poke  Hawaiian
# 43091      Healthy  Japanese
# 43092          Bbq    Korean
# 43093      Chinese   Chinese
# 43094      Noodles   Chinese
# 43095      Dim Sum   Chinese
# 43096          Bbq   Chinese
# 43097      Chinese   Chinese
# 43098      Dim Sum   Chinese
# 43099          NaN   Chinese
# 43100     Japanese    Korean
# 43101       Korean  Japanese
# 43102        Asian   Chinese
# 43103      Chicken   Chinese
# 43104      Dim Sum   Chinese
# 43105      Chinese   Chinese
# 43106      Noodles       NaN
#
#                                               ascii_name  \
# 0                         southern fried chicken & pizza
# 1                        pizza hut delivery - cambuslang
# 2                                       the curry garden
# 3                                            j & d kebab
# 4                                       pepe's piri piri
# 5                                maharani indian cuisine
# 6                                          sweet jamrock
# 7                                                zaafran
# 8                                           omar sharifs
# 9                                             pizza home
# 10                                              al badar
# 11                        royal plaza chinese restaurant
# 12                                  arifa tandoori house
# 13                                  turtle bay - croydon
# 14                                       massala express
# 15                                              munchees
# 16                          bella italia - east kilbride
# 17                                                ashoka
# 18                                    charghas fast food
# 19                                           the grill-o
# 20                                  stoneleigh brasserie
# 21                        asda kitchen - gillingham pier
# 22                             harry ramsden - playhouse
# 23                                     manha spice house
# 24                                       roberto's pizza
# 25                                     yalpa kebab house
# 26                                       tartan tandoori
# 27                                           chicken.com
# 28                                       icestone gelato
# 29                                                pop in
# ...                                                  ...
# 43077                              zumu sushi - wilmslow
# 43078                             zu's - ilford - ilford
# 43079                                  zu's - upton park
# 43080                           zz green - finsbury park
# 43081   zzang korean restaurant - swiss cottage editions
# 43082                          zzetta - soul fired pizza
# 43083                               hungry donkey greek
# 43084                               uncle tony's taverna
# 43085                     bombay bicycle chef - kilburn
# 43086                               bombay bicycle chef
# 43087                                        rox burger
# 43088                           bullgogi  - holland park
# 43089                                            maguro
# 43090                                honi poke - mayfair
# 43091                                         honi poke
# 43092                                              gogi
# 43093  Qi Cha / seven tea (bubble tea) - leicester ci...
# 43094                       Wei Mei Si Bao Zi  - radford
# 43095       Da Hua Xiao Chi  da hua street food - hendon
# 43096         Da Hua Kuai Can (dahua fast food) - hendon
# 43097                     Jia  home kong - salford quays
# 43098         Shan Shui Jian  shan shui jian - limehouse
# 43099  Dong Yuan Xiao Guan  - east garden - willesden...
# 43100       Mi kome japanese & korean sushi - brick lane
# 43101                  Mi kome japanese sushi - woodford
# 43102                   Mi Xian  "mixian" - rice noodles
# 43103                     Mi Xian  "mixian" rice noodles
# 43104             Yang Cheng  - yang sing  - princess st
# 43105  Shi Quan Xiao Chu  fodal oriental kitchen - \t...
# 43106              Xiang La Ju  chilli legend - shadwell
#
#                                           ascii_name_fix
# 0                     southern fried chicken  and  pizza
# 1                        pizza hut delivery - cambuslang
# 2                                       the curry garden
# 3                                        j  and  d kebab
# 4                                        pepes piri piri
# 5                                maharani indian cuisine
# 6                                          sweet jamrock
# 7                                                zaafran
# 8                                           omar sharifs
# 9                                             pizza home
# 10                                              al badar
# 11                        royal plaza chinese restaurant
# 12                                  arifa tandoori house
# 13                                  turtle bay - croydon
# 14                                       massala express
# 15                                              munchees
# 16                          bella italia - east kilbride
# 17                                                ashoka
# 18                                    charghas fast food
# 19                                           the grill-o
# 20                                  stoneleigh brasserie
# 21                        asda kitchen - gillingham pier
# 22                             harry ramsden - playhouse
# 23                                     manha spice house
# 24                                        robertos pizza
# 25                                     yalpa kebab house
# 26                                       tartan tandoori
# 27                                           chicken.com
# 28                                       icestone gelato
# 29                                                pop in
# ...                                                  ...
# 43077                              zumu sushi - wilmslow
# 43078                              zus - ilford - ilford
# 43079                                   zus - upton park
# 43080                           zz green - finsbury park
# 43081   zzang korean restaurant - swiss cottage editions
# 43082                          zzetta - soul fired pizza
# 43083                               hungry donkey greek
# 43084                                uncle tonys taverna
# 43085                     bombay bicycle chef - kilburn
# 43086                               bombay bicycle chef
# 43087                                        rox burger
# 43088                           bullgogi  - holland park
# 43089                                            maguro
# 43090                                honi poke - mayfair
# 43091                                         honi poke
# 43092                                              gogi
# 43093  Qi Cha   seven tea  bubble tea  - leicester ci...
# 43094                       Wei Mei Si Bao Zi  - radford
# 43095       Da Hua Xiao Chi  da hua street food - hendon
# 43096         Da Hua Kuai Can  dahua fast food  - hendon
# 43097                     Jia  home kong - salford quays
# 43098         Shan Shui Jian  shan shui jian - limehouse
# 43099  Dong Yuan Xiao Guan  - east garden - willesden...
# 43100   Mi kome japanese  and  korean sushi - brick lane
# 43101                  Mi kome japanese sushi - woodford
# 43102                   Mi Xian  "mixian" - rice noodles
# 43103                     Mi Xian  "mixian" rice noodles
# 43104             Yang Cheng  - yang sing  - princess st
# 43105  Shi Quan Xiao Chu  fodal oriental kitchen - \t...
# 43106              Xiang La Ju  chilli legend - shadwell
#
# [43107 rows x 6 columns]

# %%
df = df.drop(columns=['text', 'ascii_name'])

# %%
df
# Out:
#               label       label2    label3  \
# 0           Chicken        Pizza     Halal
# 1             Pizza       Salads      None
# 2            Indian  Bangladeshi     Halal
# 3             Kebab      Turkish      None
# 4           Chicken    Peri Peri      None
# 5            Indian        Curry      None
# 6         Caribbean    Fast Food      None
# 7            Indian        Curry      None
# 8             Kebab       Indian     Halal
# 9             Pizza      Chicken      None
# 10            Pizza        Curry      None
# 11          Chinese         Thai      None
# 12           Indian        Curry      None
# 13        Caribbean     Jamaican      None
# 14           Indian        Curry      None
# 15           Indian      Italian     Halal
# 16          Italian        Pasta      None
# 17           Indian        Curry     Halal
# 18           Indian        Pizza     Halal
# 19          Burgers      Chicken      None
# 20           Indian   Vegetarian     Halal
# 21            Pizza    Ice Cream      None
# 22     Fish & Chips      English      None
# 23           Indian        Curry     Halal
# 24            Pizza        Kebab      None
# 25            Kebab        Pizza      None
# 26            Pizza        Kebab      None
# 27            Pizza      Chicken     Halal
# 28         Desserts    Ice Cream      None
# 29     Fish & Chips        Kebab      None
# ...             ...          ...       ...
# 43077    Vegetarian        Sushi  Japanese
# 43078        Indian        Halal    Indian
# 43079        Indian        Halal    Indian
# 43080    Vegetarian        Vegan   Chinese
# 43081        Korean          NaN    Korean
# 43082         Pizza      Italian   Italian
# 43083         Vegan       Salads     Greek
# 43084         Greek        Mezze     Greek
# 43085         Curry       Indian    Indian
# 43086         Curry       Indian    Indian
# 43087       British       Brunch   British
# 43088        Korean          Bbq    Korean
# 43089         Sushi     Japanese  Japanese
# 43090        Salads         Poke  Hawaiian
# 43091      Japanese      Healthy  Japanese
# 43092        Korean          Bbq    Korean
# 43093    Bubble Tea      Chinese   Chinese
# 43094       Chinese      Noodles   Chinese
# 43095       Chinese      Dim Sum   Chinese
# 43096       Chinese          Bbq   Chinese
# 43097       Noodles      Chinese   Chinese
# 43098       Chinese      Dim Sum   Chinese
# 43099       Chinese          NaN   Chinese
# 43100        Korean     Japanese    Korean
# 43101      Japanese       Korean  Japanese
# 43102       Chinese        Asian   Chinese
# 43103       Chinese      Chicken   Chinese
# 43104       Chinese      Dim Sum   Chinese
# 43105       Noodles      Chinese   Chinese
# 43106       Chicken      Noodles       NaN
#
#                                           ascii_name_fix
# 0                     southern fried chicken  and  pizza
# 1                        pizza hut delivery - cambuslang
# 2                                       the curry garden
# 3                                        j  and  d kebab
# 4                                        pepes piri piri
# 5                                maharani indian cuisine
# 6                                          sweet jamrock
# 7                                                zaafran
# 8                                           omar sharifs
# 9                                             pizza home
# 10                                              al badar
# 11                        royal plaza chinese restaurant
# 12                                  arifa tandoori house
# 13                                  turtle bay - croydon
# 14                                       massala express
# 15                                              munchees
# 16                          bella italia - east kilbride
# 17                                                ashoka
# 18                                    charghas fast food
# 19                                           the grill-o
# 20                                  stoneleigh brasserie
# 21                        asda kitchen - gillingham pier
# 22                             harry ramsden - playhouse
# 23                                     manha spice house
# 24                                        robertos pizza
# 25                                     yalpa kebab house
# 26                                       tartan tandoori
# 27                                           chicken.com
# 28                                       icestone gelato
# 29                                                pop in
# ...                                                  ...
# 43077                              zumu sushi - wilmslow
# 43078                              zus - ilford - ilford
# 43079                                   zus - upton park
# 43080                           zz green - finsbury park
# 43081   zzang korean restaurant - swiss cottage editions
# 43082                          zzetta - soul fired pizza
# 43083                               hungry donkey greek
# 43084                                uncle tonys taverna
# 43085                     bombay bicycle chef - kilburn
# 43086                               bombay bicycle chef
# 43087                                        rox burger
# 43088                           bullgogi  - holland park
# 43089                                            maguro
# 43090                                honi poke - mayfair
# 43091                                         honi poke
# 43092                                              gogi
# 43093  Qi Cha   seven tea  bubble tea  - leicester ci...
# 43094                       Wei Mei Si Bao Zi  - radford
# 43095       Da Hua Xiao Chi  da hua street food - hendon
# 43096         Da Hua Kuai Can  dahua fast food  - hendon
# 43097                     Jia  home kong - salford quays
# 43098         Shan Shui Jian  shan shui jian - limehouse
# 43099  Dong Yuan Xiao Guan  - east garden - willesden...
# 43100   Mi kome japanese  and  korean sushi - brick lane
# 43101                  Mi kome japanese sushi - woodford
# 43102                   Mi Xian  "mixian" - rice noodles
# 43103                     Mi Xian  "mixian" rice noodles
# 43104             Yang Cheng  - yang sing  - princess st
# 43105  Shi Quan Xiao Chu  fodal oriental kitchen - \t...
# 43106              Xiang La Ju  chilli legend - shadwell
#
# [43107 rows x 4 columns]

# %% [markdown]
# ## Get rid of some key chains
# we just take their most common tag in each column

# %%
hard_coded_chains = ["asda kitchen", "basilico", "bella italia", "birdbox", "blazing bird", "burger king", "caspian pizza", "chicken cottage", "chiquito", "firezza", "frankie & benny's", "gbk", "greggs", "harvester", "itsu", "kfc", "kick ass", "las iguanas", "papa john", "pizza hut", "stack & grill", "stacks", "subway", "tim horton", "toby carvery", "tortilla -", "turtle bay", "wimpy", "yo!"]
for chain in hard_coded_chains:
    to_drop = df[df.ascii_name_fix.str.contains(chain, regex= True, na=False)]
    df = df[~df.ascii_name_fix.isin(to_drop.ascii_name_fix.tolist())]
    to_append = {'ascii_name_fix' : chain, 'trim':chain, 'trim2':chain}
    labels = ['label','label2','label3']
    for l in labels:
        mode_l = to_drop[l].mode()
        if len(mode_l) > 0:
            to_append[l] = mode_l[0]
        else:
            #to_append[l] = np.nan
            to_append[l] = 'None'
    df = df.append(to_append, ignore_index=True)
    
# warning because of brackets in gbk

# %%
df['trim'] = df['ascii_name_fix'].str.split(r' - ').str.get(0)
df['trim2'] = df['ascii_name_fix'].str.split(" \(").str.get(0)

# %%
df
# Out:
#                 label          label2    label3  \
# 0             Chicken           Pizza     Halal
# 1              Indian     Bangladeshi     Halal
# 2               Kebab         Turkish      None
# 3             Chicken       Peri Peri      None
# 4              Indian           Curry      None
# 5           Caribbean       Fast Food      None
# 6              Indian           Curry      None
# 7               Kebab          Indian     Halal
# 8               Pizza         Chicken      None
# 9               Pizza           Curry      None
# 10            Chinese            Thai      None
# 11             Indian           Curry      None
# 12             Indian           Curry      None
# 13             Indian         Italian     Halal
# 14             Indian           Curry     Halal
# 15             Indian           Pizza     Halal
# 16            Burgers         Chicken      None
# 17             Indian      Vegetarian     Halal
# 18       Fish & Chips         English      None
# 19             Indian           Curry     Halal
# 20              Pizza           Kebab      None
# 21              Kebab           Pizza      None
# 22              Pizza           Kebab      None
# 23              Pizza         Chicken     Halal
# 24           Desserts       Ice Cream      None
# 25       Fish & Chips           Kebab      None
# 26              Pizza           Kebab      None
# 27              Pizza          Fusion      None
# 28              Pasta           Pizza      None
# 29             Indian           Curry     Halal
# ...               ...             ...       ...
# 40167         Chicken         Noodles       NaN
# 40168           Pizza        Desserts     Halal
# 40169         Italian           Pizza   Italian
# 40170         Italian           Pizza   Italian
# 40171         Chicken         Burgers      None
# 40172         Chicken           Wings      None
# 40173         Burgers        American      None
# 40174           Pizza           Kebab     Halal
# 40175         Chicken   Fried Chicken  American
# 40176         Tex Mex         Mexican      None
# 40177     Gluten Free         Italian   Italian
# 40178            None            None      None
# 40179         Burgers        American      None
# 40180       Breakfast      Sandwiches      None
# 40181         Burgers         Chicken      None
# 40182           Sushi        Japanese     Halal
# 40183         Chicken           Halal     Halal
# 40184         Mexican        Burritos     Halal
# 40185  Latin American  Brazilian food  American
# 40186           Pizza        American   Italian
# 40187           Pizza         Italian   Italian
# 40188            None            None      None
# 40189         Burgers         Chicken  American
# 40190      Sandwiches           Lunch     Halal
# 40191      Sandwiches          Drinks      None
# 40192         British   Roast Dinners      None
# 40193         Mexican         Healthy   Spanish
# 40194       Caribbean        Jamaican      None
# 40195         British         Burgers   British
# 40196           Sushi        Japanese  Japanese
#
#                               ascii_name_fix  \
# 0         southern fried chicken  and  pizza
# 1                           the curry garden
# 2                            j  and  d kebab
# 3                            pepes piri piri
# 4                    maharani indian cuisine
# 5                              sweet jamrock
# 6                                    zaafran
# 7                               omar sharifs
# 8                                 pizza home
# 9                                   al badar
# 10            royal plaza chinese restaurant
# 11                      arifa tandoori house
# 12                           massala express
# 13                                  munchees
# 14                                    ashoka
# 15                        charghas fast food
# 16                               the grill-o
# 17                      stoneleigh brasserie
# 18                 harry ramsden - playhouse
# 19                         manha spice house
# 20                            robertos pizza
# 21                         yalpa kebab house
# 22                           tartan tandoori
# 23                               chicken.com
# 24                           icestone gelato
# 25                                    pop in
# 26                         varietys takeaway
# 27                                  das kino
# 28        a mano coffee bar  and  restaurant
# 29                                spice zone
# ...                                      ...
# 40167  Xiang La Ju  chilli legend - shadwell
# 40168                           asda kitchen
# 40169                               basilico
# 40170                           bella italia
# 40171                                birdbox
# 40172                           blazing bird
# 40173                            burger king
# 40174                          caspian pizza
# 40175                        chicken cottage
# 40176                               chiquito
# 40177                                firezza
# 40178                      frankie & benny's
# 40179                                    gbk
# 40180                                 greggs
# 40181                              harvester
# 40182                                   itsu
# 40183                                    kfc
# 40184                               kick ass
# 40185                            las iguanas
# 40186                              papa john
# 40187                              pizza hut
# 40188                          stack & grill
# 40189                                 stacks
# 40190                                 subway
# 40191                             tim horton
# 40192                           toby carvery
# 40193                             tortilla -
# 40194                             turtle bay
# 40195                                  wimpy
# 40196                                    yo!
#
#                                      trim  \
# 0      southern fried chicken  and  pizza
# 1                        the curry garden
# 2                         j  and  d kebab
# 3                         pepes piri piri
# 4                 maharani indian cuisine
# 5                           sweet jamrock
# 6                                 zaafran
# 7                            omar sharifs
# 8                              pizza home
# 9                                al badar
# 10         royal plaza chinese restaurant
# 11                   arifa tandoori house
# 12                        massala express
# 13                               munchees
# 14                                 ashoka
# 15                     charghas fast food
# 16                            the grill-o
# 17                   stoneleigh brasserie
# 18                          harry ramsden
# 19                      manha spice house
# 20                         robertos pizza
# 21                      yalpa kebab house
# 22                        tartan tandoori
# 23                            chicken.com
# 24                        icestone gelato
# 25                                 pop in
# 26                      varietys takeaway
# 27                               das kino
# 28     a mano coffee bar  and  restaurant
# 29                             spice zone
# ...                                   ...
# 40167          Xiang La Ju  chilli legend
# 40168                        asda kitchen
# 40169                            basilico
# 40170                        bella italia
# 40171                             birdbox
# 40172                        blazing bird
# 40173                         burger king
# 40174                       caspian pizza
# 40175                     chicken cottage
# 40176                            chiquito
# 40177                             firezza
# 40178                   frankie & benny's
# 40179                                 gbk
# 40180                              greggs
# 40181                           harvester
# 40182                                itsu
# 40183                                 kfc
# 40184                            kick ass
# 40185                         las iguanas
# 40186                           papa john
# 40187                           pizza hut
# 40188                       stack & grill
# 40189                              stacks
# 40190                              subway
# 40191                          tim horton
# 40192                        toby carvery
# 40193                          tortilla -
# 40194                          turtle bay
# 40195                               wimpy
# 40196                                 yo!
#
#                                        trim2
# 0         southern fried chicken  and  pizza
# 1                           the curry garden
# 2                            j  and  d kebab
# 3                            pepes piri piri
# 4                    maharani indian cuisine
# 5                              sweet jamrock
# 6                                    zaafran
# 7                               omar sharifs
# 8                                 pizza home
# 9                                   al badar
# 10            royal plaza chinese restaurant
# 11                      arifa tandoori house
# 12                           massala express
# 13                                  munchees
# 14                                    ashoka
# 15                        charghas fast food
# 16                               the grill-o
# 17                      stoneleigh brasserie
# 18                 harry ramsden - playhouse
# 19                         manha spice house
# 20                            robertos pizza
# 21                         yalpa kebab house
# 22                           tartan tandoori
# 23                               chicken.com
# 24                           icestone gelato
# 25                                    pop in
# 26                         varietys takeaway
# 27                                  das kino
# 28        a mano coffee bar  and  restaurant
# 29                                spice zone
# ...                                      ...
# 40167  Xiang La Ju  chilli legend - shadwell
# 40168                           asda kitchen
# 40169                               basilico
# 40170                           bella italia
# 40171                                birdbox
# 40172                           blazing bird
# 40173                            burger king
# 40174                          caspian pizza
# 40175                        chicken cottage
# 40176                               chiquito
# 40177                                firezza
# 40178                      frankie & benny's
# 40179                                    gbk
# 40180                                 greggs
# 40181                              harvester
# 40182                                   itsu
# 40183                                    kfc
# 40184                               kick ass
# 40185                            las iguanas
# 40186                              papa john
# 40187                              pizza hut
# 40188                          stack & grill
# 40189                                 stacks
# 40190                                 subway
# 40191                             tim horton
# 40192                           toby carvery
# 40193                             tortilla -
# 40194                             turtle bay
# 40195                                  wimpy
# 40196                                    yo!
#
# [40197 rows x 6 columns]

# %%
#suspected chains are those that have a - or (
# then test the split name with the full name, if they are not equal then they had a - or ()
sus_chains = df[(df['trim']!=df['ascii_name_fix'])|(df['trim2']!=df['ascii_name_fix'])]
print([sus_chains[col].str.len().min() for col in ['trim','trim2']])
# Out:
# [2, 10]

# %%
sus_chains = df[(df['trim']!=df['ascii_name_fix'])]['trim'].to_list()
sus_chains2 = df[(df['trim2']!=df['ascii_name_fix'])]['trim2'].to_list()
sus_chains_list = sus_chains + sus_chains2
len(sus_chains)
# Out:
# 11122

# %%
my_count = Counter(sus_chains_list)
counts = pd.DataFrame(my_count.most_common(), columns=['ascii_name_fix', 'count'])

# %%
# we probably just want the ones where they occur more than once. Otherwise we get places like
# pizza - the finest which is not a chain
counts[counts['count']>1]
# Out:
#                       ascii_name_fix  count
# 0                              co-op    265
# 1               frankie  and  bennys     80
# 2                              shell     58
# 3                 roosters piri piri     50
# 4                          morrisons     50
# 5                             creams     48
# 6                            wenzels     46
# 7                             kaspas     43
# 8                         tops pizza     42
# 9                      harry ramsden     41
# 10       favorite chicken  and  ribs     39
# 11                   support the nhs     37
# 12                   pepes piri piri     33
# 13                      dixy chicken     32
# 14                german doner kebab     29
# 15               the ice cream store     29
# 16                       pieminister     28
# 17                 the ice cream hub     28
# 18               joe  and  the juice     25
# 19                         cluxxx it     24
# 20                      sams chicken     24
# 21   stack  and  grill by cafe rouge     22
# 22                     majestic wine     22
# 23                          mccolls      19
# 24               little dessert shop     18
# 25                 bang bang burrito     17
# 26                            kokoro     17
# 27                         mac shack     17
# 28                  pepes piri piri      17
# 29                            shell      17
# ..                               ...    ...
# 762                     vegan lovers      2
# 763                    veggie master      2
# 764                        veri peri      2
# 765                    wafflemeister      2
# 766                    walnuts cafe       2
# 767                   warrens bakery      2
# 768                          welcome      2
# 769                    what the fish      2
# 770                   what the pitta      2
# 771                        wing wing      2
# 772                         wingmans      2
# 773                      wings world      2
# 774                      wok express      2
# 775                      wok to walk      2
# 776                          woky ko      2
# 777              wood fired pizzeria      2
# 778                      woody grill      2
# 779      woodys burgers chicken ribs      2
# 780                      wrap lovers      2
# 781                          wrapito      2
# 782          wraps pittas  and  buns      2
# 783                   yak  and  yeti      2
# 784                            yamas      2
# 785                 yifang fruit tea      2
# 786                         yum sing      2
# 787                     yummie pizza      2
# 788              yun restaurant Yun       2
# 789                 zeera restaurant      2
# 790                            zitti      2
# 791                              zus      2
#
# [792 rows x 2 columns]

# %%
# leave at 10 to catch chains not duplicates - need to review by eye
# chain_dupe1 = name_classes1.loc[name_classes1['count']> 10,['trim']].trim.to_list()
# chain_dupe2 = name_classes2.loc[name_classes2['count']> 10,['trim2']].trim2.to_list()
# to_trim_down = list(set().union(chain_dupe1,chain_dupe2))
to_trim_down = counts.loc[counts['count']> 1,['ascii_name_fix']].ascii_name_fix.to_list()
#to_trim_down = counts.ascii_name_fix.to_list()

# %%
to_trim_down
# Out:
# ['co-op',
#  'frankie  and  bennys',
#  'shell',
#  'roosters piri piri',
#  'morrisons',
#  'creams',
#  'wenzels',
#  'kaspas',
#  'tops pizza',
#  'harry ramsden',
#  'favorite chicken  and  ribs',
#  'support the nhs',
#  'pepes piri piri',
#  'dixy chicken',
#  'german doner kebab',
#  'the ice cream store',
#  'pieminister',
#  'the ice cream hub',
#  'joe  and  the juice',
#  'cluxxx it',
#  'sams chicken',
#  'stack  and  grill by cafe rouge',
#  'majestic wine',
#  'mccolls ',
#  'little dessert shop',
#  'bang bang burrito',
#  'kokoro',
#  'mac shack',
#  'pepes piri piri ',
#  'shell ',
#  'off licence',
#  'wok  and  go',
#  'ice cream store',
#  'wenzels ',
#  'chopstix noodle bar',
#  'heavenly desserts',
#  'co-op ',
#  'morleys',
#  'morrisons ',
#  'nisa local',
#  'coast to coast',
#  'five guys',
#  'leon',
#  'shell select',
#  'fireaway',
#  'pleesecakes',
#  'the drinks factory',
#  'roosters piri piri ',
#  'rosas thai cafe',
#  'oodles chinese',
#  'rios piri piri',
#  'nandos',
#  'amorino',
#  'caprinos pizza',
#  'chabad',
#  'holy cow',
#  'nirala sweets',
#  'remeo gelato ice cream store',
#  'sprinkles gelato',
#  'king of wings',
#  'miss millies fried chicken',
#  'doorstep desserts',
#  'mylahore',
#  'burger plus',
#  'maroush',
#  'best kebab',
#  'big dog ',
#  'big dog',
#  'german doner kebab ',
#  'herbies pizza',
#  'pizza 2 night',
#  'pizza time',
#  'freddys chicken  and  pizza',
#  'wrapchic',
#  'the pizza room',
#  'tikka twins',
#  'giraffe',
#  'treatz',
#  'creams cafe',
#  ' and cake',
#  'banana tree',
#  'halo top',
#  'ice stone gelato',
#  'nisa',
#  'peri peri original',
#  'selekt chicken',
#  'steakout',
#  'baskin robbins',
#  'cornstar tacos',
#  'cream curls',
#  'wingos',
#  'morleys fried chicken',
#  'best one',
#  'brew house',
#  'farmhouse pizza',
#  'hache',
#  'heinekens brew house',
#  'il palagio',
#  'kens fried chicken',
#  'marr fish bar',
#  'perfect pizza',
#  'pizza verde',
#  'planted kitchen ',
#  'super pizza',
#  'taj mahal',
#  'taste of india',
#  'taste of lahore',
#  'the hotdog factory',
#  'wicked wings',
#  'wing world',
#  'fishnchickn',
#  'auntie annes',
#  'the codfather',
#  'eds easy diner',
#  'chennai dosa',
#  'huckleberry chicken',
#  'afters',
#  'clucks burger',
#  'bella napoli pizzeria',
#  'bengal brasserie',
#  'big johns',
#  'delightful desserts',
#  'epic chicken',
#  'hot rod burger',
#  'ice cream store ',
#  'ichiban don',
#  'iconic waffles',
#  'kaspas ',
#  'louies hot chicken',
#  'mackin cheez',
#  'neds noodle bar',
#  'perfect chicken',
#  'sonora mexicano',
#  'sushimania ',
#  'tasty african restaurant',
#  'the great british cheesecake company',
#  'marco  and  carl',
#  'drakes fish  and  chips',
#  'ultimate cafe',
#  'deep blue',
#  'favorite chicken',
#  'mommy thai',
#  'go pho',
#  'burrito kitchen',
#  'planet pizza',
#  'zabardast',
#  'toros steakhouse',
#  'garfunkels',
#  'taka taka',
#  'chick chicken',
#  'the grill',
#  '400 rabbits',
#  'al dente',
#  'amigos burgers and shakes',
#  'archies',
#  'bengal spice',
#  'bird',
#  'bubbleology',
#  'charcoal grill',
#  'chefly ',
#  'chefly',
#  'chicken hut',
#  'chilli flames',
#  'chop and wok',
#  'chunky chicken',
#  'churchills fish  and  chips',
#  'cinnamon',
#  'cottons',
#  'daylesford organic farmshop',
#  'earthbuns',
#  'epic hotdogs',
#  'grill house',
#  'iro sushi',
#  'its pizza time',
#  'jeroboams wine merchants',
#  'king kebab',
#  'little india',
#  'mahmoods',
#  'manjaros',
#  'master chef',
#  'napoli pizza',
#  'pasta remoli',
#  'pizza inn',
#  'pizza to go',
#  'pokai',
#  'red planet pizza',
#  'sahara grill',
#  'saravana bhavan',
#  'shawarma express',
#  'spar',
#  'star pizza',
#  'sushimania',
#  'sutton  and  sons',
#  'tgf pizza',
#  'thai rice',
#  'the athenian',
#  'the fat pizza',
#  'wicked burgers',
#  'wraps  and  wings',
#  'buddies usa',
#  'lucky star',
#  'joes kitchen',
#  'smokeys',
#  'five lads',
#  'the good earth express',
#  'al-safa grill',
#  'fast break',
#  'streetcube',
#  'the ramen company',
#  'tasty chicken',
#  'havanas burgers  and  shakes',
#  'allens fried chicken',
#  'pizza gogo',
#  'la pizzeria',
#  'kaspas desserts',
#  'the lobster pot',
#  '3 for 10 pizza',
#  '500 degrees pizzeria',
#  'arriba arriba',
#  'bbq express',
#  'bottle apostle',
#  'br8',
#  'chatime',
#  'cheeky chickos ',
#  'cheeky chickos',
#  'chicago pizza',
#  'chick filler',
#  'chicken express',
#  'chicken shack',
#  'chicken valley',
#  'chicking',
#  'china garden',
#  'chop  and  wok',
#  'cinnamon spice',
#  'cookies  and  cream',
#  'costcutter',
#  'creams cafe ',
#  'dessert heaven',
#  'dessert island',
#  'dip  and  flip',
#  'dixy chicken  and  pizza',
#  'dominique ansel bakery',
#  'eataliano',
#  'eggsquisite',
#  'favorite chicken and ribs',
#  'flamingo',
#  'forno pizza',
#  'franzos',
#  'georges fish bar',
#  'golden grill',
#  'griller',
#  'haagen-dazs parlour',
#  'hare  and  tortoise',
#  'ichiban don ',
#  'indian kitchen',
#  'indian ocean',
#  'joe  and  the juice ',
#  'just desserts',
#  'kebabish',
#  'kings grill',
#  'kiyoto sushi',
#  'kokoro ',
#  'kulcha express',
#  'lebanese grill',
#  'londis',
#  'love pizza',
#  'm. manze pie  and  mash',
#  'maemes',
#  'mashs wing ranch',
#  'miso noodle bar',
#  'munchies',
#  'perfect fried chicken ',
#  'perfect fried chicken',
#  'peri peri grill',
#  'pizaza',
#  'pizza hot 4 you',
#  'pizza king',
#  'pizza perfect',
#  'pizza place',
#  'pizza plus',
#  'pizza roma',
#  'premier convenience store',
#  'red dog saloon',
#  'retail24',
#  'romeo pizza',
#  'ronis',
#  'roosters',
#  'roosters spot',
#  'royal fish bar',
#  'sabeez',
#  'saffron',
#  'saravana bhavan ',
#  'scrambled  and  wild',
#  'sensations',
#  'sicilian pizza',
#  'slumdog delivered',
#  'smokin rooster',
#  'spice island',
#  'spice lounge',
#  'spicy grill',
#  'sundaes gelato',
#  'sushi shop',
#  'tasty grill',
#  'that pizza place',
#  'the chippy',
#  'the coffee hub',
#  'the ice cream store ',
#  'the pizza club',
#  'the urban chocolatier',
#  'tupi',
#  'village pizza',
#  'you me sushi',
#  'stonehouse',
#  'baja',
#  'camile thai',
#  'nepal restaurant',
#  'firejacks',
#  'asda groceries',
#  'desi chicken',
#  'indico',
#  'al',
#  'the coffee room',
#  'the fishermans wife',
#  'pepe nero',
#  'aldwych',
#  'the olive tree',
#  'choices takeaway',
#  'filling station',
#  'balkan taste',
#  'pizza republic',
#  'jollof n jerk',
#  'rikshaw',
#  'out fry',
#  'antalya restaurant',
#  'rola wala',
#  'eastern eye',
#  'babucci',
#  'dolce desserts',
#  'robinsons bakery',
#  'the pizza company',
#  'chopd',
#  'sutton fish bar',
#  'mr chips',
#  'jennys jerk chicken',
#  'la cucina',
#  'robin hood',
#  'kathmandu',
#  'chicago rib shack',
#  'zaks fish bar',
#  'snappy tomato pizza',
#  'valentinos',
#  'mint leaf',
#  'chesters',
#  'pfc',
#  'hally moos',
#  'mooboo bubble tea',
#  'feng sushi',
#  'dragon',
#  'boys cafe',
#  'cafe indus',
#  'taberu',
#  'snaxatac',
#  'favourite chicken',
#  'pcg',
#  'dessert rush',
#  'waynes coffee',
#  'zing zing',
#  'eurasian tandoori',
#  'kasturi',
#  'colombo by ayubowan',
#  'balti king',
#  '3 for 10 pizza ',
#  'a burgers veggie kitchen by taster',
#  'abd el wahab',
#  'abu zaad',
#  'afc',
#  'afters original',
#  'aj baguettes',
#  'al forno',
#  'ala pizza',
#  'alfresco',
#  'amaretto',
#  'american pizza',
#  'anatolia',
#  'archies ',
#  'arepas aglaes',
#  'aroma',
#  'ashoka',
#  'awesome chips ',
#  'badiani gelato',
#  'bagel and shake',
#  'bagel express',
#  'bagel zone',
#  'baker and spice',
#  'band of burgers',
#  'bang',
#  'bang bang burrito ',
#  'basement browns',
#  'basil wood oven pizzeria',
#  'beats burgers',
#  'bella roma',
#  'bengal curry house',
#  'bengal spices',
#  'bengal village',
#  'bentobab',
#  'big bite',
#  'black bear burger',
#  'bombay bites',
#  'bombay cuisine',
#  'bosa kitchen',
#  'boteco do brasil',
#  'bottle shop',
#  'bravo! by macellaio',
#  'braw burgers and pizzas',
#  'bread ahead',
#  'brentwood spice',
#  'brgr',
#  'brooklyn pizza crew',
#  'bubble tea  and  ice cream',
#  'buenos',
#  'buns',
#  'buns  and  bao ',
#  'burger ranch',
#  'burger revolution',
#  'burger zone',
#  'burrito  and  tequila',
#  'by chloe.',
#  'cafe aina',
#  'caffe concerto',
#  'caloroso pizza',
#  'cannons fish and chips',
#  'caprinos ',
#  'caprinos pizza ',
#  'carmona steak  and  tapas ',
#  'casa do frango',
#  'catch fish and chips',
#  'chandini fine indian restaurant',
#  'chao chao takeaways',
#  'chestersway chicken',
#  'chicago chicken',
#  'chickanos',
#  'chicken club ',
#  'chicken corner',
#  'chicken land',
#  'chicken village',
#  'chicken world',
#  'chicks',
#  'chikoos',
#  'chilli hut',
#  'chillichicks',
#  'china express',
#  'chuck burgers',
#  'city kebab house',
#  'city pizza',
#  'city spice',
#  'cpress',
#  'crave desserts',
#  'cridos restaurant',
#  'crispy chicken',
#  'crunch munch',
#  'crust',
#  'cube desserts',
#  'curry cottage',
#  'curry curry',
#  'curry king',
#  'curry queen',
#  'daisuki poke',
#  'daisuki sushi',
#  'dallas chicken and pizza',
#  'deluxe pizza',
#  'dirty bones',
#  'dodo pizza',
#  'donburi  and  co japanese and korean',
#  'dope burger',
#  'dough and co artisan pasta',
#  'drinksstore',
#  'e.mono',
#  'eat fresh',
#  'eat street',
#  'eatfan',
#  'eatkatsu',
#  'ecco pizza ',
#  'edens kitchen',
#  'enish nigerian restaurant',
#  'epic chicken ',
#  'euro cafe',
#  'everest spice',
#  'family shopper',
#  'farm house pizza',
#  'favorita gourmet kitchen',
#  'favorite chicken  and  ribs ',
#  'fernandez grillhouse',
#  'fireaway pizza',
#  'five lads ',
#  'flames',
#  'flavours by kumar',
#  'flavours of brazil',
#  'fortune cat',
#  'four seasons',
#  'frangos peri peri',
#  'freshers',
#  'frurt',
#  'fusion',
#  'fusion gelato',
#  'gelato passion',
#  'get stuffed cafe',
#  'godo',
#  'going greek',
#  'golden chicken',
#  'golden pizza',
#  'good pizza',
#  'grande wines',
#  'grill town',
#  'grillaz',
#  'grindsmith',
#  'habaneros',
#  'halo burger',
#  'hanoi pho',
#  'harbour fish bar',
#  'haute dolci',
#  'heavenly desserts ',
#  'hello burger',
#  'hollywood pizza',
#  'hot stuff pizza ',
#  'house of spice',
#  'ice scoop gelato',
#  'il michelangelo',
#  'inazal',
#  'incrediburger',
#  'india garden',
#  'indian grill',
#  'indiano pizza',
#  'izgara restaurant',
#  'jaros grill',
#  'jasmine garden',
#  'jerkpit deliveries',
#  'jjs desi kitchen',
#  'johnny custard',
#  'jrk bros',
#  'jungle grill',
#  'kalamaki',
#  'kanto',
#  'kaspas desserts ',
#  'kathmandu valley',
#  'kebabish ',
#  'kens kebab and speedy pizza',
#  'kennedys',
#  'kens peri peri and gourmet burgers ',
#  'kens peri peri and gourmet burgers',
#  'khans',
#  'kings',
#  'ko grill',
#  'koi ramen bar',
#  'krunchy fried chicken',
#  'la parma pizzeria',
#  'la piccola deli ',
#  'lahore spices',
#  'lea  and  sandeman wine merchants',
#  'lebanese kitchen',
#  'lebanese tasty grill  slough ',
#  'loco',
#  'londis ',
#  'london fresco',
#  'lotus',
#  'love balti ',
#  'madina grill',
#  'makiyaki',
#  'mamma mia',
#  'mamos',
#  'mango tree',
#  'manjaros ',
#  'marinara woodfire oven pizzeria',
#  'marios pizza',
#  'marmaris',
#  'maryland chicken',
#  'masala zone ',
#  'masala zone',
#  'masgouf ',
#  'maya',
#  'meaty buns',
#  'mega bite',
#  'melt chocolates',
#  'memsaab',
#  'mermaid fish bar',
#  'mexican taco',
#  'milano pizza',
#  'milanos pizzeria',
#  'mooboo',
#  'moorish caribbean grill',
#  'morleys ',
#  'mr fish',
#  'mr pizza',
#  'mr sushi',
#  'mr tasty',
#  'mulberry street new york pizza',
#  'mumbai local',
#  'murger hanhan Xi An Han Ji Liang Pi Rou Jia Mo ',
#  'nanna mexico',
#  'napoli pizzeria',
#  'niazi',
#  'nisa ',
#  'nisa local ',
#  'nonnos pizza',
#  'okome',
#  'olivia pizza',
#  'one more chinese takeaway',
#  'only jerkin',
#  'oregano leaf pizzeria',
#  'oriental express',
#  'padrinos',
#  'papas burritos',
#  'papas pizza',
#  'pappa ciccia',
#  'paprika',
#  'pasta',
#  'pasta fresca',
#  'patri artisan street food and drinks',
#  'paya',
#  'peri peri',
#  'philglas  and  swiggot',
#  'pho ta',
#  'piccolos',
#  'piri fino',
#  'pix pizza',
#  'pizza 1889',
#  'pizza 45',
#  'pizza di legno',
#  'pizza di rocca',
#  'pizza factory',
#  'pizza haven',
#  'pizza hot',
#  'pizza hot 4 you ',
#  'pizza house express',
#  'pizza italia',
#  'pizza king buy one get one free',
#  'pizza klub grill house',
#  'pizza land',
#  'pizza man',
#  'pizza mania',
#  'pizza napoli',
#  'pizza on demand',
#  'pizza oro',
#  'pizza pan express',
#  'pizza parlour',
#  'pizza pazza',
#  'pizza pizza',
#  'pizza planet',
#  'pizza pronto',
#  'pizza punks',
#  'pizza world',
#  'pizzaface',
#  'pizzaiolo',
#  'pizzarelli',
#  'pizzeria roma ',
#  'poblanos',
#  'poke box',
#  'portobello juice  and  all day breakfast ',
#  'premier',
#  'premier express ',
#  'prime pizza',
#  'pronto pizza',
#  'punjab grill',
#  'pure gym meal',
#  'pure pizza',
#  'pylos greek',
#  'quaff wines',
#  'qwok chinese',
#  'rainbow smoothies',
#  'rajah',
#  'rajas pizza bar',
#  'ranoush',
#  'rassams creamery',
#  'rice n spice',
#  'rico sabor takeaway',
#  'rios gourmet grill',
#  'rios piri piri ',
#  'roccos desserts',
#  'roccos pizza',
#  'rooster hut',
#  'royal fried chicken',
#  'royal india',
#  'royal rooster',
#  'royal spice',
#  'sake sushi',
#  'samis',
#  'samrat',
#  'santa maria pizzeria',
#  'scoops',
#  'select  and  save',
#  'selekt chicken ',
#  'shahi tandoori',
#  'shake  and  go',
#  'shakes n cakes',
#  'shampan',
#  'shapla indian takeaway',
#  'shawarma grill',
#  'siam brasserie',
#  'sizzlers',
#  'slammin ramen',
#  'slice',
#  'slumdog',
#  'smoky boys',
#  'snog frozen yogurt',
#  'soor restaurant',
#  'southern fried chicken',
#  'speedo pizza',
#  'spice box',
#  'spice city',
#  'spice cottage',
#  'spice hut',
#  'spice klub',
#  'spice of india ',
#  'spice rack',
#  'spice village',
#  'square pizza co',
#  'star of india',
#  'suito japanese',
#  'super pizza ',
#  'superb pizza',
#  'sushi express',
#  'sushi54',
#  't g f pizza co',
#  't4',
#  'take-out-thai by taster',
#  'taro',
#  'taste of asia',
#  'tasty bites',
#  'tasty house',
#  'taya sushi',
#  'tennessee express',
#  'tennessee fried chicken',
#  'thai garden',
#  'the bake one',
#  'the best kebab',
#  'the big fish ',
#  'the chickpea',
#  'the fish house',
#  'the good life eatery',
#  'the great british cheesecake company ',
#  'the house authentic thai',
#  'the indian dining club',
#  'the joint',
#  'the kebab shop',
#  'the mac factory ',
#  'the master fryer',
#  'the pizza co.',
#  'theatre of wine',
#  'ting thai caravan',
#  'todays extra',
#  'tokyo sushi ',
#  'tomis kitchen',
#  'tootoomoo',
#  'top pizza',
#  'toscana pizzeria',
#  'treatz ',
#  'tuk tuk',
#  'turkish grill',
#  'turkish shawarma',
#  'uncle sams hamburger express',
#  'vagabond wines',
#  'valentina',
#  'vegan kitchen @ portobello juice',
#  'vegan lovers',
#  'veggie master',
#  'veri peri',
#  'wafflemeister',
#  'walnuts cafe ',
#  'warrens bakery',
#  'welcome',
#  'what the fish',
#  'what the pitta',
#  'wing wing',
#  'wingmans',
#  'wings world',
#  'wok express',
#  'wok to walk',
#  'woky ko',
#  'wood fired pizzeria',
#  'woody grill',
#  'woodys burgers chicken ribs',
#  'wrap lovers',
#  'wrapito',
#  'wraps pittas  and  buns',
#  'yak  and  yeti',
#  'yamas',
#  'yifang fruit tea',
#  'yum sing',
#  'yummie pizza',
#  'yun restaurant Yun ',
#  'zeera restaurant',
#  'zitti',
#  'zus']

# %%
for chain in to_trim_down:
    to_drop = df[df.ascii_name_fix.str.contains(chain, regex= True, na=False)]
    df = df[~df.ascii_name_fix.isin(to_drop.ascii_name_fix.tolist())]
    to_append = {'ascii_name_fix' : chain, 'trim':chain, 'trim2':chain}
    labels = ['label','label2','label3']
    for l in labels:
        mode_l = to_drop[l].mode()
        if len(mode_l) > 0:
            to_append[l] = mode_l[0]
        else:
            to_append[l] = 'None'
    df = df.append(to_append, ignore_index=True)
    
# warning because of brackets in gbk

# %%
df = df.drop(columns=['trim', 'trim2', 'label3'])

# %%
df[df.ascii_name_fix.str.contains("shell", regex= True, na=False)]
# Out:
#          label   label2 ascii_name_fix
# 26911  Grocery  Alcohol          shell
# 26934     None     None         shell
# 26947     None     None   shell select

# %% [markdown]
# ## Check for duplicates

# %% [markdown]
# These are remaining duplicates with different classes

# %%
name_classes = df.\
  groupby('ascii_name_fix').size().reset_index(name='counts')

# %% [markdown]
# Use similar logic to removing chains to take the most popular labels

# %%
to_dedupe = name_classes[name_classes['counts'] > 1]['ascii_name_fix'].to_list()

# %%
to_dedupe
# Out:
# ['10 to 10 in delhi',
#  '1st class pizza',
#  '2-4-1 pizza',
#  '241 pizza',
#  '7 spices',
#  'a mano',
#  'a touch of spice',
#  'abbey fish bar',
#  'abduls',
#  'aburi japanese restaurant',
#  'acropolis',
#  'adams',
#  'adams pizza',
#  'adams pizzeria',
#  'adils pizzeria',
#  'agra',
#  'ahi poke',
#  'akash',
#  'akash restaurant',
#  'akash tandoori',
#  'akash tandoori restaurant',
#  'american fried chicken',
#  'amigo',
#  'amigo pizza',
#  'amigos',
#  'amigos pizza',
#  'amore pizza',
#  'amran tandoori',
#  'andys greek taverna',
#  'angelos fish bar',
#  'angelos pizza',
#  'anglo pizza',
#  'anise',
#  'anoki',
#  'antep pizza',
#  'antonios pizza',
#  'apadana',
#  'apna lahore',
#  'ariana restaurant',
#  'asha',
#  'ashiana',
#  'asia villa',
#  'asian tandoori',
#  'asiana',
#  'athena',
#  'atlantic fish bar',
#  'atlantis fish bar',
#  'authentic chinese',
#  'av-a-pizza',
#  'avon spice',
#  'aya lebanese cuisine',
#  'aziz khan',
#  'baan thai',
#  'baburchi',
#  'babylon',
#  'babylon grill',
#  'bad boy burgers',
#  'bagel bite',
#  'baguette express',
#  'bake station',
#  'bamboo chinese takeaway',
#  'bamboo garden',
#  'banana leaf',
#  'bar-b-q house',
#  'barakah',
#  'barbican pizza',
#  'barneys diner',
#  'barnis',
#  'bawarchi',
#  'bay leaf',
#  'bayleaf',
#  'bayleaf indian takeaway',
#  'bbq hut',
#  'beef belly',
#  'beer  and  burger store',
#  'beijing chef',
#  'beijing chinese restaurant',
#  'beijing city',
#  'beijing express',
#  'beijing house',
#  'beijing noodles',
#  'beirut',
#  'beirut lounge',
#  'beirut mezze',
#  'bekash tandoori',
#  'belash tandoori',
#  'bella house',
#  'bella napoli',
#  'bella pizza',
#  'bellillo pizzeria',
#  'bellissimo',
#  'belly busters',
#  'belmont tandoori',
#  'benes fish  and  chips',
#  'bento',
#  'berries bagels  and  shakes',
#  'best fish  and  chips',
#  'best grill',
#  'best in town',
#  'best pizza',
#  'best pizza  and  kebab',
#  'best pizza express',
#  'bfc',
#  'bhaji',
#  'bhajis',
#  'bhajis takeaway',
#  'big brother',
#  'big chef',
#  'big fat gourmet',
#  'big fish',
#  'big mamas',
#  'big moes diner',
#  'big papas',
#  'big portion',
#  'big singhs pizza',
#  'bikash tandoori',
#  'biryani express',
#  'bite',
#  'biters',
#  'bits n pizzas',
#  'black lab',
#  'blacks burgers',
#  'blaze',
#  'blue ginger',
#  'blue india',
#  'blue lagoon',
#  'blue lagoon fish  and  chips',
#  'blue ocean',
#  'blue orchid',
#  'blue spice',
#  'blue star',
#  'bobbys',
#  'bodrum',
#  'bodrum express',
#  'bodrum grill',
#  'bodrum kebab',
#  'bodrum kebab  and  pizza',
#  'bodrum kebab house',
#  'bodrum pizza  and  kebab',
#  'bodrum pizza  and  kebab house',
#  'bollywood',
#  'bollywood lounge',
#  'bollywood spice',
#  'bombay',
#  'bombay bicycle chef',
#  'bombay blues',
#  'bombay brasserie',
#  'bombay express',
#  'bombay grill',
#  'bombay indian takeaway',
#  'bombay inn',
#  'bombay kitchen',
#  'bombay lounge',
#  'bombay mix',
#  'bombay nights',
#  'bombay spice',
#  'bombay spices',
#  'bon appetit',
#  'boo',
#  'bosphorus',
#  'boston pizza',
#  'bravissimi!',
#  'bravo pizza',
#  'bravos',
#  'brendas pizzeria',
#  'bristol kebab house',
#  'britannia fish bar',
#  'britannia spice',
#  'british raj',
#  'british raj express',
#  'broadway chippy',
#  'brooklyn pizza',
#  'broskis',
#  'brothers kebab  and  burgers',
#  'bruce burgers',
#  'brunch',
#  'brunch cafe',
#  'bulls burgers',
#  'bun  and  bar',
#  'buon appetito',
#  'buonasera',
#  'burger  and  bun',
#  'burger 7',
#  'burger bar',
#  'burger base',
#  'burgitzza',
#  'burrito n shake',
#  'burrito picante',
#  'buttylicious',
#  'buzz bar shakes  and  desserts',
#  'byblos harbour',
#  'caesars',
#  'cafe 55',
#  'cafe express',
#  'cafe india',
#  'cafe istanbul',
#  'cafe on the corner',
#  'cafe rose',
#  'cafe spice',
#  'caffe mamma',
#  'caffe rapido',
#  'cake  and  shakes indulgence',
#  'cakes  and  shakes',
#  'cambridge wine merchants',
#  'camel one',
#  'canada grill',
#  'candy crush',
#  'canton',
#  'canton chef',
#  'canton chef chinese takeaway',
#  'canton chinese takeaway',
#  'cappadocia',
#  'caprinos',
#  'cardamom',
#  'cardamon',
#  'carlitos pizza',
#  'carlos pizza',
#  'carlton lounge',
#  'carolina pizza',
#  'casa mia',
#  'casa pizza',
#  'casa rica',
#  'casablanca',
#  'caspian',
#  'castle kebab house',
#  'castle pizza',
#  'catch fish  and  chips',
#  'cathay cuisine',
#  'cedars lebanese restaurant',
#  'celebz',
#  'cha chas',
#  'cha chaz',
#  'champions pizza',
#  'chanda cottage',
#  'chans',
#  'chapati club',
#  'char grill',
#  'chargrill',
#  'charlies chicken',
#  'charlies fish bar',
#  'chatkhara',
#  'chayada thai',
#  'cheeky chicken',
#  'chefs pizza',
#  'cheung wing',
#  'chez vous',
#  'chicagos',
#  'chicagos pizza',
#  'chick inn',
#  'chick king',
#  'chick-o-land',
#  'chicken  and  blues',
#  'chicken  and  pizza point',
#  'chicken city',
#  'chicken club',
#  'chicken house',
#  'chicken king',
#  'chicken spot',
#  'chicken stop',
#  'chicken.com',
#  'chicketos',
#  'chickoland',
#  'chicos',
#  'chilli',
#  'chilli banana thai street food',
#  'chilli express',
#  'chilli garlic',
#  'chilli jacks',
#  'chilli lounge',
#  'chilli padi',
#  'chilli pepper',
#  'chilli peppers',
#  'chilli pickle',
#  'chilli spice',
#  'chilli tonight',
#  'chillies',
#  'chillies indian restaurant',
#  'chillies indian takeaway',
#  'chillies takeaway',
#  'chillies tandoori',
#  'chillis',
#  'china chef',
#  'china china',
#  'china city',
#  'china cottage',
#  'china cuisine',
#  'china delight',
#  'china diner',
#  'china flavour',
#  'china house',
#  'china inn',
#  'china kitchen',
#  'china panda',
#  'china red',
#  'china rose',
#  'china spice',
#  'china star',
#  'china town',
#  'china village',
#  'china wok',
#  'chinatown',
#  'chinese chef',
#  'chinese express',
#  'chinese garden',
#  'chinese kitchen',
#  'chinos',
#  'chip stop',
#  'chit chaat chai',
#  'chop suey house',
#  'chopstick house',
#  'chopsticks',
#  'chopstix',
#  'chosen bun',
#  'chows chinese',
#  'chunky chick-inn',
#  'chunkys',
#  'chutney',
#  'chutney blue',
#  'chutney express',
#  'chutney tandoori',
#  'chutneys',
#  'ciao bella',
#  'cibo',
#  'city grill',
#  'cjs cafe',
#  'classic fish bar  and  kebab house',
#  'classic pizza',
#  'classic sushi',
#  'clay oven',
#  'clay oven tandoori',
#  'clove',
#  'cocotte ',
#  'codfather',
#  'colbeh persian kitchen  and  bar',
#  'coriander',
#  'corner plaice',
#  'crave 4 desserts',
#  'cravings',
#  'crispy bites',
#  'crispy cod',
#  'crollas gelateria',
#  'crown cafe',
#  'crunchy chicken',
#  'cummin up',
#  'curry 2 night',
#  'curry chef',
#  'curry club',
#  'curry corner',
#  'curry counter',
#  'curry delight',
#  'curry express',
#  'curry flame',
#  'curry garden',
#  'curry house',
#  'curry hut',
#  'curry in a hurry',
#  'curry inn',
#  'curry junction',
#  'curry leaf',
#  'curry leaves',
#  'curry lounge',
#  'curry master',
#  'curry night',
#  'curry nights',
#  'curry pot',
#  'curry station',
#  'curry time',
#  'curry zone',
#  'cyprus garden',
#  'cyprus kebab',
#  'da vinci',
#  'daawat',
#  'dario pizzeria',
#  'darios',
#  'darios fish  and  chips',
#  'dawat',
#  'de niros',
#  'de roma',
#  'decaprios',
#  'delhi darbar',
#  'delhi lounge',
#  'delhi spice',
#  'deli chez',
#  'deli fuego',
#  'deli-licious',
#  'delicious',
#  'delicious chinese takeaway',
#  'delicious house',
#  'delicious pizza',
#  'delight',
#  'delightz',
#  'deliveroos invisible easter eggs',
#  'deniz kebab',
#  'deshi spice',
#  'desi cafe',
#  'desi indian dining club',
#  'desi spice',
#  'dessert corner',
#  'dessert express',
#  'dessert king',
#  'dessert shack',
#  'dfc',
#  'dfc chicken',
#  'diamond kebab  and  pizza',
#  'diamond pizza',
#  'diamond pizza  and  kebab',
#  'diba restaurant',
#  'dil raj',
#  'dil se',
#  'dil tandoori',
#  'dilan kebab house',
#  'dilli haat',
#  'dilraj',
#  'dilshad',
#  'dine at home',
#  'dine india',
#  'dinner box',
#  'dinos',
#  'dinos pizzeria',
#  'dinos takeaway',
#  'dirty burgerz',
#  'dixi chicken  and  pizza',
#  'dixy pizza',
#  'dixyland chicken  and  ribs',
#  'dolce  and  gelato',
#  'dolphin fish bar',
#  'dominic pizza',
#  'dominics',
#  'dominics pizza',
#  'don mario',
#  'don vitos',
#  'donburi  and  co',
#  'doner  and  gyros',
#  'donnellis pizzeria',
#  'donner 24',
#  'double luck chinese',
#  'dough and co woodfired pizza',
#  'dough-wood fired pizza',
#  'downtown pizza',
#  'drayton tandoori',
#  'duet cuisine',
#  'dynasty',
#  'east meets west',
#  'east ocean',
#  'eastern delight',
#  'eastern delights',
#  'eastern paradise',
#  'eastern promise',
#  'eastern spice',
#  'eastern star',
#  'eastzeast',
#  'eat pho',
#  'eat well',
#  'eatza pizza',
#  'ecklee grill',
#  'efes grill',
#  'efes kebab  and  pizza house',
#  'elachi',
#  'els gourmet',
#  'emparo pizza',
#  'empire tandoori',
#  'empress of india',
#  'ephesus',
#  'ephesus restaurant',
#  'espresso pizza',
#  'essex grill',
#  'everest indian takeaway',
#  'everest inn',
#  'everest kitchen',
#  'everest noodle house',
#  'everest tandoori',
#  'evergreen',
#  'express kebab',
#  'express kebab house',
#  'express pizza',
#  'express pizza  and  chicken',
#  'express pizza  and  kebab',
#  'expresso pizza',
#  'family kebab',
#  'family kebab  and  pizza',
#  'family kebab house',
#  'famous chef',
#  'famous pizza',
#  'fancy chicken n pizza',
#  'fancy pizza',
#  'fanoosh the indian',
#  'far east',
#  'far east chinese takeaway',
#  'farm pizza',
#  'fast one pizza',
#  'fat boys',
#  'fat desserts',
#  'fat joes',
#  'fat tonis',
#  'fattoush',
#  'favourite grill',
#  'favourite pizza',
#  'fellas takeaway',
#  'fennec  and  parsley',
#  'figaro pizza',
#  'finchley kitchen',
#  'finesse desserts',
#  'firecracker',
#  'firehouse grill',
#  'fish inn',
#  'five star fish bar',
#  'flame',
#  'flame  and  grill',
#  'flame grill',
#  'flamez',
#  'flava',
#  'flavaz',
#  'flavours',
#  'flavours gelato',
#  'flavours of india',
#  'flavourz',
#  'florentinos pizza',
#  'food station',
#  'food stop',
#  'foodisan',
#  'forest tandoori',
#  'fort raj',
#  'fortune cookie',
#  'fortune garden',
#  'fortune house',
#  'fortune inn',
#  'four in one',
#  'four pound shop',
#  'francescos',
#  'frankies',
#  'frankies burgers',
#  'frankies chicken  and  pizza',
#  'frankies chicken  and  pizza bar',
#  'franks',
#  'frankyz',
#  'freaky shakes',
#  'freddys',
#  'freddys chicken',
#  'freddys chicken and pizza',
#  'fresco',
#  'fresh fitness food to go',
#  'fresh fry',
#  'friends',
#  'friends pizza house',
#  'frozen moments',
#  'fry inn',
#  'frydays',
#  'frydays fish  and  chips',
#  'frydays fish bar',
#  'fryers delight',
#  'fu house',
#  'fu lam',
#  'fu wing',
#  'full house',
#  'furama',
#  'gah shing',
#  'gandhi',
#  'gandhi tandoori',
#  'ganges',
#  'garden house',
#  'gate of india',
#  'gattusos trattoria pizzeria',
#  'georges takeaway',
#  'get stuffed',
#  'ggs caribbean takeaway',
#  'giannis',
#  'gills fish  and  chips',
#  'gills fry fry',
#  'gills golden takeaway',
#  'ginos',
#  'ginos fish  and  chip shop',
#  'gios',
#  'go peri',
#  'goa indian restaurant',
#  'godfather',
#  'godfather pizza',
#  'godfathers pizza house',
#  'golden bamboo',
#  'golden bowl',
#  'golden bridge',
#  'golden castle',
#  'golden chef',
#  'golden chippy',
#  'golden city',
#  'golden crown',
#  'golden curry',
#  'golden delight',
#  'golden eagle',
#  'golden fish',
#  'golden fish inn',
#  'golden fry',
#  'golden garden',
#  'golden hill',
#  'golden horse',
#  'golden house',
#  'golden kebab house',
#  'golden kitchen',
#  'golden lion chinese',
#  'golden orient',
#  'golden phoenix',
#  'golden plaice',
#  'golden rice',
#  'golden rice bowl',
#  'golden sea',
#  'golden spice',
#  'golden star',
#  'golden tandoori',
#  'golden wok',
#  'good burger',
#  'good chef',
#  'good choice',
#  'good food',
#  'good friend',
#  'good luck',
#  'good taste',
#  'goodfellas pizza',
#  'gourmet grill',
#  'gourmet house',
#  'gourmet kitchen',
#  'gourmet sushi',
#  'grameen spice',
#  'grange fish bar',
#  'green chilli',
#  'green chillies',
#  'grill',
#  'grill  and  chill',
#  'grill box',
#  'grill cottage',
#  'grill guru',
#  'grill it',
#  'grill n chill',
#  'grill on the hill',
#  'grillish',
#  'grillos pizza',
#  'grillz',
#  'gulshan',
#  'gulshan tandoori',
#  'gurkha chef',
#  'gurkha express',
#  'gurkha grill',
#  'gurkha junction',
#  'gurkha oven',
#  'gurkha spice',
#  'gurkha square',
#  'gurkhas inn',
#  'ha noi pho',
#  'hai loi tang',
#  'hamzas',
#  'hana sushi',
#  'happy chef',
#  'happy chinese takeaway',
#  'happy days',
#  'happy family',
#  'happy garden',
#  'happy home',
#  'happy house',
#  'happy inn',
#  'happy kitchen',
#  'happy meeting',
#  'happy samurai',
#  'happy seasons',
#  'happy wok',
#  'harlequin',
#  'harlequins',
#  'harrys',
#  'harrys chicken  and  pizza',
#  'hayaku sushi cafe',
#  'hazara',
#  'hennie pennys chicken',
#  'herbs  and  spice',
#  'herbs  and  spices',
#  'hfc',
#  'hiba street',
#  'ho ho',
#  'home taste',
#  'hong kong',
#  'hong kong chef',
#  'hong kong express',
#  'hong kong garden',
#  'hong kong house',
#  'hong kong kitchen',
#  'hong kong takeaway',
#  'honi poke',
#  'hoo wah',
#  'hooked fish  and  chips',
#  'hooked fish  and  grill',
#  'hot  and  spicy',
#  'hot kebab',
#  'hot n spicy',
#  'hot pizza',
#  'hot rocks',
#  'hot spot',
#  'hot stuff',
#  'hot stuff pizza',
#  'hot wok',
#  'hungry herb',
#  'hungry hut',
#  'hungry jacks',
#  'hungry shack',
#  'hungrydo',
#  'i am doner',
#  'i grill',
#  'icco pizza',
#  'ice pan',
#  'icestone gelato',
#  'ichiban',
#  'iglu desserts',
#  'ikigai sushi',
#  'il bacio express',
#  'il bebos',
#  'il funghetto',
#  'il gusto',
#  'il padrino',
#  'imaan restaurant',
#  'imli',
#  'imrans',
#  'india village',
#  'indian brasserie',
#  'indian chef',
#  'indian cottage',
#  'indian delight',
#  'indian express',
#  'indian garden',
#  'indian lounge',
#  'indian nights',
#  'indian spice',
#  'indian summer',
#  'indian village',
#  'indiana',
#  'indianos',
#  'indigo',
#  'indulge',
#  'indus indian takeaway',
#  'ing thai restaurant',
#  'iso sushi wok  and  grill',
#  'istanbul',
#  'istanbul chef',
#  'istanbul grill',
#  'istanbul kebab',
#  'istanbul kebab  and  pizza house',
#  'istanbul kebab house',
#  'istanbul pizza',
#  'istanbul pizza house',
#  'istanbul restaurant',
#  'istanbul takeaway',
#  'jade',
#  'jade garden',
#  'jade house',
#  'jaflong',
#  'jaflong tandoori',
#  'jaipur',
#  'jaipur indian cuisine',
#  'jakes',
#  'jakobs kitchen',
#  'jamuna',
#  'japas sushi',
#  'jarern street foods',
#  'jasmine',
#  'jasmine house',
#  'jaspers',
#  'jazs fish bar',
#  'jeera',
#  'jeera indian restaurant  and  takeaway',
#  'jennys cafe  and  restaurant',
#  'jerk island grill',
#  'jfc',
#  'jimmys',
#  'jimmys plaice',
#  'jinnah',
#  'jjs',
#  'joe  and  za',
#  'joes fish bar',
#  'joes pizza company',
#  'joes plaice',
#  'joeys',
#  'jojos chicken',
#  'jrk kitchen',
#  'jubo raj',
#  'judes ice cream',
#  'juici sushi',
#  'jumbo',
#  'jumbo house',
#  'just pizza',
#  'just pizza uk.com',
#  'just wings',
#  'k2 taj chippery',
#  'kadai  and  naan',
#  'kamran tandoori',
#  'kapadokya fish  and  chips',
#  'karachi tandoori',
#  'karikana',
#  'karma',
#  'kashmir cottage',
#  'kashmir restaurant',
#  'kashmir tandoori',
#  'kaya',
#  'kebab centre',
#  'kebab city',
#  'kebab delight',
#  'kebab express',
#  'kebab house',
#  'kebab hut',
#  'kebab king',
#  'kebab land',
#  'kebab master',
#  'kebab plus',
#  'kebab rush',
#  'kebab world',
#  'kebab ye',
#  'kebabs r us',
#  'kemp thai',
#  'kennington tandoori',
#  'kens',
#  'kens kebab house',
#  'kens kebab house  and  speedy pizza',
#  'kens speedy pizza',
#  'kervan saray',
#  'khushboo',
#  'khyber',
#  'khyber pass',
#  'kichn',
#  'kilikya',
#  'kimchi',
#  'king chef',
#  'king cod',
#  'king grill',
#  'king karahi',
#  'king pizza',
#  'king pizza  and  kebab',
#  'king rooster',
#  'kiplings restaurant',
#  'kismat',
#  'kismat tandoori',
#  'kismet',
#  'kismet tandoori',
#  'kitchen at parks edge',
#  'kome',
#  'korean barbecue',
#  'krazy chef',
#  'krazy pizza',
#  'krispy fried chicken',
#  'kurk grilled chicken',
#  'kurry hut',
#  'kusadasi',
#  'kushi',
#  'la casa del burrito',
#  'la dolce vita',
#  'la friends pizzeria',
#  'la lombarda',
#  'la luna',
#  'la luna di luca',
#  'la mama acasa',
#  'la pizza',
#  'la pizzaria',
#  'la saporita',
#  'la spezia pizzeria',
#  'la unica',
#  'la vera',
#  'la vera pizza',
#  'la zara',
#  'lahore kebab london',
#  'lahore restaurant',
#  'lahori chaska',
#  'lahori tawa',
#  'lantica pizzeria',
#  'laughing buddha',
#  'lazeez',
#  'lazio pizza',
#  'le raj',
#  'lee garden',
#  'lees chinese takeaway',
#  'lees kitchen',
#  'legends',
#  'legends kebab house',
#  'leila',
#  'lemon tree',
#  'leos fish bar',
#  'leos grill',
#  'lets eat',
#  'lets munch',
#  'levant',
#  'lfc',
#  'light of india',
#  'lime pickle',
#  'lime tree',
#  'limoncello',
#  'lisas cafe',
#  'little china',
#  'loaded gourmet burgers  and  fries',
#  'london kebab house',
#  'loon hing',
#  'loro di napoli',
#  'los cardos',
#  'lounge india',
#  'love curry',
#  'lovely house',
#  'lower east side  new york style pizza',
#  'luciano pizzeria',
#  'lucianos',
#  'lucky chen',
#  'lucky chopsticks',
#  'lucky garden',
#  'lucky house',
#  'lucky inn',
#  'luckys',
#  'luigis',
#  'luigis pizza',
#  'm and m kebab  and  pizza',
#  'mac n cheese',
#  'macdonners',
#  'madihahs',
#  'madras',
#  'madras cottage',
#  'magic grill',
#  'magic wok',
#  'maharaja',
#  'maharani',
#  'mahi tandoori',
#  'maks',
#  'mama janes pizza',
#  'mama mia',
#  'mama pizza',
#  'mamas',
#  'mamas food xpress',
#  'mamas grill',
#  'mamas kitchen',
#  'mamas pizza',
#  'mamas pizzeria',
#  'mammas',
#  'mammas pizza',
#  'man lee',
#  'man v food',
#  'mandarin chef',
#  'mandarin chinese takeaway',
#  'mandarin garden',
#  'manhattan',
#  'mantra',
#  'manzil',
#  'manzil tandoori',
#  'marco polo',
#  'marcos',
#  'marcos fish  and  chips',
#  'marcos pizza',
#  'marhaba',
#  'marhaba express',
#  'mariners fish  and  chips',
#  'marinis',
#  'marinos fish bar',
#  'mario pizza',
#  'marios',
#  'marios fast food',
#  'marios pizzeria',
#  'marios takeaway',
#  'marius',
#  'market cafe',
#  'marrakech',
#  'marrakesh',
#  'master pizza  and  kebab',
#  'master wok',
#  'masterchef',
#  'maxim',
#  'maxs pizza',
#  'mayflower',
#  'mays chinese cuisine',
#  'mc noodle king',
#  'mega munch',
#  'megabite',
#  'meghna',
#  'mei wei',
#  'mela',
#  'melanzana',
#  'mella pizza',
#  'memories of india',
#  'metros',
#  'mexican grill',
#  'mexican house',
#  'meza',
#  'mezze',
#  'mi cocina es tuya',
#  'miahs kitchen',
#  'miahs takeaway',
#  'miami chicken  and  pizza',
#  'miami pizza',
#  'mian gees grill',
#  'mickleover spice',
#  'mickys fish  and  chips',
#  'midland kebab',
#  'midland kebabs',
#  'mighty bite',
#  'milan indian cuisine',
#  'milano',
#  'milano express',
#  'milano pizzeria',
#  'milano takeaway',
#  'milanos',
#  'milanos pizza',
#  'millennium pizza',
#  'millennium tandoori',
#  'mings',
#  'ministry of chicken',
#  ...]

# %%
for chain in to_dedupe:
    to_drop = df[df['ascii_name_fix'] == chain]
    df = df[df['ascii_name_fix'] != chain]
    to_append = {'ascii_name_fix' : chain}
    labels = ['label','label2']
    for l in labels:
        mode_l = to_drop[l].mode()
        if len(mode_l) > 0:
            to_append[l] = mode_l[0]
        else:
            to_append[l] = None
    df = df.append(to_append, ignore_index=True)

# %%
df[['label','label2']] = df[['label','label2']].astype(str)

# %% [markdown]
# check for duplicate name label combinations

# %%
counts = df.assign(n=1).groupby(['ascii_name_fix', 'label', 'label2']).count().sort_values('n', ascending=False)
counts.tail(n=20)
# Out:
#                                                                               n
# ascii_name_fix                                     label         label2
# grannys caribbean                                  Caribbean     Jamaican     1
# granny macs - plasnewydd                           American      Sandwiches   1
# granny macs                                        Burgers       Breakfast    1
# granny grapes                                      Curry         Burgers      1
# granier bakery coffee shop - brighton              Spanish       Vegetarian   1
# grangetown tandoori - seaham                       Indian        Kebab        1
# grange wok                                         Chinese       Oriental     1
# grange town tandoori                               Indian        Curry        1
# grange park tandoori                               Indian        Bangladeshi  1
# grange fish bar                                    Fish & Chips  Burgers      1
# grandma buggins  and  burger, pizza  and  kebab... Pizza         Turkish      1
# grande wines                                       Alcohol       Alcohol      1
# grande                                             Pizza         Italian      1
# grand sultan  - bristol                            Indian        Curry        1
# grand pizza  and  grill                            Kebab         Pizza        1
# grand kitchen                                      Chinese       Oriental     1
# grand kebabs - leicester city centre               Burgers       Turkish      1
# grand indian restaurant                            Indian        Curry        1
# grand grill - staines                              Mediterranean Halal        1
# zzetta soul fired pizza                            Pizza         Italian      1

# %%
df.to_csv('/home/trpb2/takeaways/data/28_05_2020_combined_words.csv', index=False)

# %% [markdown]
# ### Distribution by Cuisine
#
# The dataset is very unbalanced.

# %%
label_count = df.groupby('label').ascii_name_fix.count().sort_values(ascending=False)

# %%
len(label_count)
# Out:
# 165

# %%
label_count[0:150]
# Out:
# label
# Indian            4236
# Pizza             2840
# Chinese           2212
# Fish & Chips      1265
# Italian           1225
# Kebab             1172
# Chicken           1088
# Burgers            768
# American           738
# British            706
# Breakfast          572
# Desserts           533
# Curry              426
# Turkish            425
# Caribbean          386
# Thai               384
# Lebanese           229
# Japanese           228
# Grill              189
# Sushi              188
# Dessert            172
# Alcohol            171
# Café               156
# Mexican            155
# Grocery            153
# Sandwiches         141
# Greek              141
# Peri Peri          140
# Vegan              125
# Mediterranean      124
#                   ...
# Tea                  3
# Donuts               3
# Pies                 3
# Filipino             3
# Peruvian             3
# Asian Fusion         3
# Sweets               3
# Panini's             3
# Organic              3
# Tex Mex              3
# Pub Food             2
# Baguettes            2
# South American       2
# Retro Sweets         2
# Kurdish              2
# Bulgarian            2
# Dinner               2
# Sichuan              2
# Hot Dogs             2
# Sri Lankan           2
# Coffee               2
# Colombian            2
# Hungarian            2
# Soup                 1
# Groceries            1
# West African         1
# Ghanaian             1
# Falafel              1
# Street Food          1
# Hot Pot              1
# Name: ascii_name_fix, Length: 150, dtype: int64

# %%
label_count2 = df.groupby('label2').ascii_name_fix.count().sort_values(ascending=False)

# %%
len(label_count2)
# Out:
# 172

# %%
label_count2[0:50]
# Out:
# label2
# Curry             2856
# Pizza             2593
# Kebab             2189
# Burgers           1573
# Oriental          1361
# Chicken            855
# Italian            836
# Indian             529
# American           463
# British            443
# Halal              442
# Grill              396
# Bangladeshi        391
# Breakfast          384
# Noodles            333
# Vegetarian         325
# nan                293
# Desserts           290
# Fish & Chips       281
# Japanese           262
# Vegan              261
# Thai               258
# Mediterranean      254
# Sandwiches         253
# Chinese            237
# English            233
# Ice Cream          226
# Drinks             216
# Asian              207
# Dessert            200
# Milkshakes         193
# Pasta              191
# Turkish            178
# Peri Peri          163
# Café               156
# Alcohol            151
# Fast Food          149
# Sushi              142
# Jamaican           140
# Fish And Chips     135
# Caribbean          131
# Gluten Free        128
# Cakes              124
# Lunch              116
# None               111
# Grocery            105
# Salads              98
# Middle Eastern      91
# Healthy             89
# Seafood             77
# Name: ascii_name_fix, dtype: int64

# %%
df2 = pd.DataFrame(np.sort(df[['label', 'label2']], axis=1), index=df.index)
df2.columns = ['label', 'label2']
combos = df2.groupby(['label', 'label2']).size().reset_index(name='counts')

# %%
combos
# Out:
#             label          label2  counts
# 0           *NEW*        Desserts       1
# 1            Acai         British       1
# 2            Acai          Brunch       1
# 3            Acai          Juices       1
# 4            Acai           Vegan       2
# 5          Afghan           Asian       1
# 6          Afghan             BBQ       1
# 7          Afghan             Bbq       1
# 8          Afghan           Curry       2
# 9          Afghan           Greek       1
# 10         Afghan           Grill       3
# 11         Afghan           Halal       2
# 12         Afghan          Indian       6
# 13         Afghan           Kebab       4
# 14         Afghan  Middle Eastern       3
# 15         Afghan       Pakistani       7
# 16         Afghan         Persian       4
# 17         Afghan           Pizza       1
# 18        African         African       1
# 19        African       Breakfast       3
# 20        African         British       1
# 21        African         Burgers       1
# 22        African            Café       2
# 23        African       Caribbean      49
# 24        African         Chicken      33
# 25        African           Curry       8
# 26        African        Desserts       1
# 27        African       Dumplings       1
# 28        African         English       1
# 29        African       Ethiopian       2
# ...           ...             ...     ...
# 1654        Steak         Turkish       1
# 1655  Street Food            Thai       2
# 1656  Street Food         Turkish       1
# 1657        Sushi            Thai       2
# 1658        Sushi           Vegan       1
# 1659        Sushi      Vegetarian       1
# 1660        Tapas            Thai       4
# 1661        Tapas           Wraps       1
# 1662         Thai           Vegan       9
# 1663         Thai      Vegetarian      36
# 1664         Thai             nan       5
# 1665      Turkish         Turkish       1
# 1666      Turkish           Vegan       8
# 1667      Turkish      Vegetarian      15
# 1668      Turkish           Wings       1
# 1669      Turkish           Wraps       4
# 1670      Turkish             nan       6
# 1671        Vegan           Vegan       1
# 1672        Vegan      Vegetarian      41
# 1673        Vegan      Vietnamese       2
# 1674        Vegan           Wraps       1
# 1675        Vegan             nan       2
# 1676   Vegetarian      Vegetarian       1
# 1677   Vegetarian      Vietnamese       3
# 1678   Vegetarian           Wraps       3
# 1679   Vegetarian             nan       1
# 1680   Vietnamese             nan       3
# 1681        Wings           Wraps       1
# 1682        Wings             nan       1
# 1683          nan             nan      64
#
# [1684 rows x 3 columns]

# %%
combos.to_csv('/home/trpb2/takeaways/data/28_05_2020_combos.csv', index=False)

# %%
combos_10 = combos[combos['counts']>10]
combos[combos['label']=='Indian'],combos[combos['label2']=='Indian']
# Out:
# (       label               label2  counts
#  1288  Indian               Indian      14
#  1289  Indian  Indo-Chinese Fusion       6
#  1290  Indian              Italian      51
#  1291  Indian             Japanese       2
#  1292  Indian                Kebab     190
#  1293  Indian             Lebanese       1
#  1294  Indian                Lunch       4
#  1295  Indian        Mediterranean       1
#  1296  Indian              Mexican       4
#  1297  Indian       Middle Eastern       5
#  1298  Indian           Milkshakes       2
#  1299  Indian             Nepalese      91
#  1300  Indian              Noodles       1
#  1301  Indian             Oriental       3
#  1302  Indian            Pakistani      58
#  1303  Indian            Peri Peri       8
#  1304  Indian                Pizza     270
#  1305  Indian           Portuguese       1
#  1306  Indian             Pub Food       1
#  1307  Indian              Punjabi       7
#  1308  Indian               Salads       1
#  1309  Indian           Sandwiches       2
#  1310  Indian              Seafood      11
#  1311  Indian        South African       1
#  1312  Indian         South Indian      30
#  1313  Indian              Spanish       1
#  1314  Indian           Sri-lankan      13
#  1315  Indian                Steak       2
#  1316  Indian          Street Food      10
#  1317  Indian               Sweets       1
#  1318  Indian                 Thai      12
#  1319  Indian              Turkish       6
#  1320  Indian                Vegan      39
#  1321  Indian           Vegetarian      98
#  1322  Indian                Wraps       3
#  1323  Indian                  nan      27,
#                  label  label2  counts
#  12             Afghan  Indian       6
#  37            African  Indian       3
#  69            Alcohol  Indian       5
#  122          American  Indian      24
#  185             Asian  Indian      30
#  224               BBQ  Indian       3
#  254             Balti  Indian       6
#  257       Bangladeshi  Indian     416
#  267               Bbq  Indian       2
#  279           Biryani  Indian       7
#  320         Breakfast  Indian       4
#  383           British  Indian       8
#  432            Brunch  Indian       1
#  494           Burgers  Indian      34
#  546          Burritos  Indian       1
#  601             Cakes  Indian       1
#  631         Caribbean  Indian       2
#  681           Chicken  Indian     104
#  740           Chinese  Indian      45
#  769       Continental  Indian       2
#  792             Curry  Indian    2721
#  826              Deli  Indian       1
#  847           Dessert  Indian       6
#  889          Desserts  Indian      18
#  924            Dinner  Indian       1
#  934            Drinks  Indian       5
#  975           English  Indian      25
#  1000         European  Indian      10
#  1021        Fast Food  Indian      16
#  1045     Fish & Chips  Indian      36
#  1064   Fish And Chips  Indian       1
#  1099           Fusion  Indian       8
#  1119      Gluten Free  Indian       8
#  1143          Gourmet  Indian       4
#  1149  Gourmet Burgers  Indian       1
#  1183            Grill  Indian      64
#  1215            Halal  Indian     134
#  1249          Healthy  Indian      10
#  1280        Ice Cream  Indian       1
#  1288           Indian  Indian      14)

# %% [markdown]
# ## Crafting the mappings
#
# Here we generate the mappings

# %%
#remove s on burger for scannign later

dead_certain = {'Curry':'Indian', 'Bangladeshi':'Indian', 'Nepalese':'Indian', 'Pakistani':'Indian', 'South Indian':'Indian', 'Sri Lankan':'Indian',
                'Ice Cream':'Desserts', 'Cakes':'Desserts', 'Milkshakes':'Desserts', 'Crepes':'Desserts', 'Waffles':'Desserts',
                 'Dessert':'Desserts','CrÃªpe':'Desserts',
                'Italian':'Pizza', 'Italian Pizza':'Pizza',
                'Oriental':'Chinese', 'Cantonese':'Chinese', 'Dim Sum':'Chinese', 'Singapore':'Chinese', 'Dumplings':'Chinese',
                'Taiwanese':'Chinese',
                'Fried Chicken':'Chicken', 'Wings':'Chicken',
                'Fish And Chips':'Fish & Chips',
                'Thai':'Asian', 'Japanese':'Asian', 'Sushi':'Asian', 'Korean':'Asian', 'Vietnamese':'Asian',
                'Bubble Tea':'Asian', 'Filipino':'Asian', 'Indonesian':'Asian', 'Noodles':'Asian', 'Malaysian':'Asian',
                'Ramen':'Asian', 'Pho':'Asian', 'Poke':'Asian',
                'Turkish':'MedMid', 'Lebanese':'MedMid', 'Mediterranean':'MedMid', 'Greek':'MedMid', 'Middle Eastern':'MedMid',
                'Persian':'MedMid', 'Afghan':'MedMid', 'Moroccan':'MedMid', 'Arabic':'MedMid', 'Syrian':'MedMid', 'Iranian':'MedMid',
                'Iraqi':'MedMid','Falafel':'MedMid', 'Mezze':'MedMid',
                'Tex Mex':'Latam', 'Tex Mex':'Latam',
                'Brazilian food':'Latam', 'South American':'Latam', 'Burritos':'Latam', 'Mexican':'Latam',
                 'Latin American':'Latam', 'Colombian':'Latam',
                'Peruvian':'Latam', 'Tex-Mex':'Latam', 'Tacos':'Latam', 'Cuban':'Latam',
                'African':'AfroCarib','Caribbean':'AfroCarib', 'Jamaican':'AfroCarib', 'Nigerian':'AfroCarib', 'Jerk':'AfroCarib',
                 'West African':'AfroCarib', 'Ethiopian':'AfroCarib', 'Ghanaian':'AfroCarib', 'North African':'AfroCarib',
                'Gourmet Burgers':'Burger', 'Burgers':'Burger',
                'Café':'Sand/Caf/Bake', 'Sandwiches':'Sand/Caf/Bake', 'Wraps':'Sand/Caf/Bake', 'Bagels':'Sand/Caf/Bake', "Panini's":'Sand/Caf/Bake',
                "Salads":'Sand/Caf/Bake', "Baguettes":'Sand/Caf/Bake', "Deli":'Sand/Caf/Bake', "Bakery":'Sand/Caf/Bake',
                'Breakfast':'Sand/Caf/Bake', 'Coffee':'Sand/Caf/Bake', 'Tea':'Sand/Caf/Bake', 'CafÃ©':'Sand/Caf/Bake', 'English Breakfast':'Sand/Caf/Bake',
                'Steak':'Burger', 'Burgers':'Burger','Gourmet Burgers':'Burger', 'Steak':'Burger', 'American':'Burger'

 }
key_list = ['Indian', 'Chinese', 'Fish & Chips']

# %%
df2 = df.replace({"label": dead_certain})
df3 = df2.replace({"label2": dead_certain})

# %%
df3['label_final'] = np.where((df3['label2'].isin(key_list)), df3['label2'], 'no')
df3['label_final'] = np.where((df3['label'].isin(key_list)), df3['label'], df3['label_final'])

# %%
#Chinese places serving fish and chips are Chinese
df3['label_final'] = np.where(((df3['label'] == 'Fish & Chips') & (df3['label2'] == 'Chinese')), df3['label2'], df3['label_final'])

# %%
# this section for scanning names
name_scan = ['Burger', 'Chicken', 'Kebab', 'Pizza', 'Fast Food']

for name in name_scan:
    df3[name] = 0
    df3[name] = np.where(df3.ascii_name_fix.str.contains(name.lower(), regex= True, na=False), 1, 0)
    df3['label_final'] = np.where(df3.ascii_name_fix.str.contains(name.lower(), regex= True, na=False), name, df3['label_final'])

    
df3['label_final'] = np.where(df3[name_scan].sum(axis = 1) > 1, 'Fast Food', df3['label_final'])

# %%
fast_foods = ['Fast Food', 'Pizza', 'Burger', 'Kebab', 'Chicken']

# %%
#option for fast food category separately
#
df3['label_final'] = np.where((df3['label'].isin(fast_foods)) & (df3['label2'].isin(fast_foods)) & 
                              (df3['label'] != df3['label2']) & (df3['label_final'] == 'no'), 'Fast Food', df3['label_final'])

# %%
df3[df3['ascii_name_fix']=='cibo']
# Out:
#         label   label2 ascii_name_fix label_final  Burger  Chicken  Kebab  \
# 22385  Burger  Chicken           cibo   Fast Food       0        0      0
#
#        Pizza  Fast Food
# 22385      0          0

# %%
#burger can be in here but taken out later or converted to fast food
my_cuisines =  ['Pizza', 'Burger', 'Kebab', 'Chicken', 'Chinese', 'Indian', 'Fish & Chips', 'Desserts', 'Fast Food']
#my_cuisines =  ['Pizza', 'Kebab', 'Chicken', 'Chinese', 'Indian', 'Fish & Chips', 'Fast Food']
#my_cuisines =  ['Pizza', 'Kebab', 'Chicken', 'Chinese', 'Indian', 'Fish & Chips', 'Fast Food', 'Desserts']
df3['label_final'] = np.where((df3['label'].isin(my_cuisines) & (df3['label_final'] == 'no')), df3['label'], df3['label_final'])
df3['label_final'] = np.where((df3['label2'].isin(my_cuisines) & (df3['label_final'] == 'no')), df3['label2'], df3['label_final'])

# %%
#special section to convert all of 'Fast Food', 'Pizza', 'Burger', 'Kebab', 'Chicken' into fast food
# can be commented out
#df3['label_final'] = np.where(df3['label_final'].isin(fast_foods), 'Fast Food', df3['label_final'])

# %%
cafe =  ['Sand/Caf/Bake']
df3['label_final'] = np.where((df3['label'].isin(cafe) & (df3['label_final'] == 'no')), df3['label'], df3['label_final'])
df3['label_final'] = np.where((df3['label2'].isin(cafe) & (df3['label_final'] == 'no')), df3['label2'], df3['label_final'])

# %%
df3 = df3[df3['label_final']!='no']

# %%
# either take out left over burgers, or convert to fast food
#df3 = df3[df3['label_final']!='Burger']
df3['label_final'] = np.where(df3['label_final'] == "Burger", 'Fast Food', df3['label_final'])

# %%
df3
# Out:
#                label        label2                      ascii_name_fix  \
# 0              Kebab        MedMid                     j  and  d kebab
# 1             Indian        Indian             maharani indian cuisine
# 2          AfroCarib     Fast Food                       sweet jamrock
# 3             Indian        Indian                             zaafran
# 4             Indian        Indian                arifa tandoori house
# 5             Indian         Pizza                  charghas fast food
# 6             Indian    Vegetarian                stoneleigh brasserie
# 7             Indian        Indian                   manha spice house
# 8              Pizza         Kebab                      robertos pizza
# 9       Fish & Chips         Kebab                              pop in
# 10             Pizza         Kebab                   varietys takeaway
# 11             Pizza        Fusion                            das kino
# 12             Pasta         Pizza  a mano coffee bar  and  restaurant
# 13            Burger         Kebab                         hot express
# 15      Fish & Chips         Pizza                    pauls fish grill
# 16             Kebab         Pizza         family kebab  and  pizzaria
# 17             Kebab         Pizza                  rams kebab limited
# 18           Chinese       Chinese                         jasmine inn
# 19            Indian        Indian                      tandoori haven
# 20            Indian        Indian           the spice indian takeaway
# 21           Chicken         Pizza                           cafe zeus
# 22            Indian      European                jahangir st. andrews
# 23           British        Burger                      scruffy duffys
# 24            Indian        Indian           rangoli indian restaurant
# 26             Pizza         Kebab                        manton pizza
# 27            Indian        Indian                      rayleigh spicy
# 28             Kebab         Pizza                     surf  and  turf
# 29            Burger         Pizza                      b and n kebabs
# 30             Pizza        Indian                    volcano takeaway
# 31            Burger         Pizza                   taste  and  smile
# ...              ...           ...                                 ...
# 23919          Pizza        Burger                       yum yum pizza
# 23920          Kebab         Pizza                             yummies
# 23921          Kebab         Pizza                       yummies kebab
# 23922        Chinese       Chinese                               yummy
# 23923        Chinese       Chinese                        yummy garden
# 23924        Chinese       Chinese                         yummy house
# 23925        Chinese  Fish & Chips                       yummy kitchen
# 23926          Pizza         Pizza                         yummy pizza
# 23927        Chinese       Chinese                         yummy yummy
# 23928          Pizza         Kebab                        yummys pizza
# 23929        Chinese         Asian                      yun restaurant
# 23930         Indian        Indian                             zaffran
# 23931        Chinese        Indian                               zaika
# 23932         Indian        Indian                               zaiqa
# 23933         Indian        Indian                                zaks
# 23934          Grill     Fast Food                             zam zam
# 23935          Pizza         Kebab                                zara
# 23936         Indian        Indian                zara indian takeaway
# 23937         Indian        Indian                          zara spice
# 23938          Grill        Burger                               zatar
# 23940          Pizza         Pizza                          zaza pizza
# 23941         Indian        Indian                               zeera
# 23942         Indian        Indian                         zeera spice
# 23943         Indian        Indian                      zeera tandoori
# 23944        Chinese         Asian                                 zen
# 23945  Sand/Caf/Bake       British                          zenas cafe
# 23946       Desserts      Desserts             zidanes indulgence york
# 23947         Burger       Chicken                                zing
# 23948         Burger         Kebab                              zorbas
# 23949         MedMid         Kebab                         zouk lounge
#
#          label_final  Burger  Chicken  Kebab  Pizza  Fast Food
# 0              Kebab       0        0      1      0          0
# 1             Indian       0        0      0      0          0
# 2          Fast Food       0        0      0      0          0
# 3             Indian       0        0      0      0          0
# 4             Indian       0        0      0      0          0
# 5          Fast Food       0        0      0      0          1
# 6             Indian       0        0      0      0          0
# 7             Indian       0        0      0      0          0
# 8              Pizza       0        0      0      1          0
# 9       Fish & Chips       0        0      0      0          0
# 10         Fast Food       0        0      0      0          0
# 11             Pizza       0        0      0      0          0
# 12             Pizza       0        0      0      0          0
# 13         Fast Food       0        0      0      0          0
# 15      Fish & Chips       0        0      0      0          0
# 16         Fast Food       0        0      1      1          0
# 17             Kebab       0        0      1      0          0
# 18           Chinese       0        0      0      0          0
# 19            Indian       0        0      0      0          0
# 20            Indian       0        0      0      0          0
# 21         Fast Food       0        0      0      0          0
# 22            Indian       0        0      0      0          0
# 23         Fast Food       0        0      0      0          0
# 24            Indian       0        0      0      0          0
# 26             Pizza       0        0      0      1          0
# 27            Indian       0        0      0      0          0
# 28         Fast Food       0        0      0      0          0
# 29             Kebab       0        0      1      0          0
# 30            Indian       0        0      0      0          0
# 31         Fast Food       0        0      0      0          0
# ...              ...     ...      ...    ...    ...        ...
# 23919          Pizza       0        0      0      1          0
# 23920      Fast Food       0        0      0      0          0
# 23921          Kebab       0        0      1      0          0
# 23922        Chinese       0        0      0      0          0
# 23923        Chinese       0        0      0      0          0
# 23924        Chinese       0        0      0      0          0
# 23925        Chinese       0        0      0      0          0
# 23926          Pizza       0        0      0      1          0
# 23927        Chinese       0        0      0      0          0
# 23928          Pizza       0        0      0      1          0
# 23929        Chinese       0        0      0      0          0
# 23930         Indian       0        0      0      0          0
# 23931        Chinese       0        0      0      0          0
# 23932         Indian       0        0      0      0          0
# 23933         Indian       0        0      0      0          0
# 23934      Fast Food       0        0      0      0          0
# 23935      Fast Food       0        0      0      0          0
# 23936         Indian       0        0      0      0          0
# 23937         Indian       0        0      0      0          0
# 23938      Fast Food       0        0      0      0          0
# 23940          Pizza       0        0      0      1          0
# 23941         Indian       0        0      0      0          0
# 23942         Indian       0        0      0      0          0
# 23943         Indian       0        0      0      0          0
# 23944        Chinese       0        0      0      0          0
# 23945  Sand/Caf/Bake       0        0      0      0          0
# 23946       Desserts       0        0      0      0          0
# 23947      Fast Food       0        0      0      0          0
# 23948      Fast Food       0        0      0      0          0
# 23949          Kebab       0        0      0      0          0
#
# [20745 rows x 9 columns]

# %% [markdown]
# ## Create Validation and Training Sets
#
# We want our final model to work well on any language.
#
# But if we pick our validation set uniformly at random from the data we're likely to get many Indian and not many African, which isn't a good test of this.
#
# So instead we'll take our validation set from an equal number from each subclass.

# %%
df3 = df3.reset_index().drop('index', 1)

# %%
counts = df3.groupby('label_final').ascii_name_fix.count().sort_values(ascending=False)
counts
# Out:
# label_final
# Indian           5152
# Fast Food        4027
# Pizza            3273
# Chinese          2561
# Fish & Chips     1462
# Sand/Caf/Bake    1121
# Chicken          1074
# Desserts         1040
# Kebab            1035
# Name: ascii_name_fix, dtype: int64

# %%
valid_size = 500 # We'll pick 30 at random from each subclass
train_size = 2000 # For a balanced training set we'll pick 500 at random with replacement

# %%
np.random.seed(6011)
valid_idx = []
for label in counts.keys():
    # Random sample of size "valid_size" for each class
    valid_idx += list(df3[df3.label_final == label].sample(valid_size).index)

# %%
df3['valid'] = False
df3.loc[valid_idx, 'valid'] = True

# %%
np.random.seed(7012)
balanced_idx = []
for label in counts.keys():
    # Random sample of size "train_size" for each class from the data outside of the validation set
    balanced_idx += list(df3[(df3.label_final == label) & ~df3.valid].sample(train_size, replace=True).index)

# %%
#aims to maximise training data by oversampling smaller classes

np.random.seed(7012)
balanced_idx = []
for label in counts.keys():
    # Random sample of size "train_size" for each class from the data outside of the validation set
    balanced_idx += list(df3[(df3.label_final == label) & ~df3.valid].sample(counts[label]-valid_size).index)
    if counts[label] < train_size:
        balanced_idx += list(df3[(df3.label_final == label) & ~df3.valid].sample(train_size -(counts[label]-valid_size), replace=True).index)

# %%
df3.loc[balanced_idx].groupby('label_final').nunique().sort_values('ascii_name_fix', ascending=False)
# Out:
#                label  label2  ascii_name_fix  label_final  Burger  Chicken  \
# label_final
# Indian            32      47            4652            1       1        1
# Fast Food         46      51            3527            1       2        2
# Pizza             34      46            2773            1       1        1
# Chinese           17      32            2061            1       1        1
# Fish & Chips      14      27             962            1       1        1
# Sand/Caf/Bake     28      29             621            1       1        1
# Chicken           33      31             574            1       1        2
# Desserts          25      34             540            1       1        1
# Kebab             23      28             535            1       1        1
#
#                Kebab  Pizza  Fast Food  valid
# label_final
# Indian             1      1          1      1
# Fast Food          2      2          2      1
# Pizza              1      2          1      1
# Chinese            1      1          1      1
# Fish & Chips       1      1          1      1
# Sand/Caf/Bake      1      1          1      1
# Chicken            1      1          1      1
# Desserts           1      1          1      1
# Kebab              2      1          1      1

# %% [markdown]
# Let's record our balanced set in the dataframe: this will make it easy to reload at a later point.

# %%
df3['bal'] = 0
for k, v in Counter(balanced_idx).items():
    df3.loc[k, 'bal'] += v

# %%
df3.to_csv('28_05_2020_deliveroo_basic.csv', index=False)

# %%
df3
# Out:
#                label        label2                      ascii_name_fix  \
# 0              Kebab        MedMid                     j  and  d kebab
# 1             Indian        Indian             maharani indian cuisine
# 2          AfroCarib     Fast Food                       sweet jamrock
# 3             Indian        Indian                             zaafran
# 4             Indian        Indian                arifa tandoori house
# 5             Indian         Pizza                  charghas fast food
# 6             Indian    Vegetarian                stoneleigh brasserie
# 7             Indian        Indian                   manha spice house
# 8              Pizza         Kebab                      robertos pizza
# 9       Fish & Chips         Kebab                              pop in
# 10             Pizza         Kebab                   varietys takeaway
# 11             Pizza        Fusion                            das kino
# 12             Pasta         Pizza  a mano coffee bar  and  restaurant
# 13            Burger         Kebab                         hot express
# 14      Fish & Chips         Pizza                    pauls fish grill
# 15             Kebab         Pizza         family kebab  and  pizzaria
# 16             Kebab         Pizza                  rams kebab limited
# 17           Chinese       Chinese                         jasmine inn
# 18            Indian        Indian                      tandoori haven
# 19            Indian        Indian           the spice indian takeaway
# 20           Chicken         Pizza                           cafe zeus
# 21            Indian      European                jahangir st. andrews
# 22           British        Burger                      scruffy duffys
# 23            Indian        Indian           rangoli indian restaurant
# 24             Pizza         Kebab                        manton pizza
# 25            Indian        Indian                      rayleigh spicy
# 26             Kebab         Pizza                     surf  and  turf
# 27            Burger         Pizza                      b and n kebabs
# 28             Pizza        Indian                    volcano takeaway
# 29            Burger         Pizza                   taste  and  smile
# ...              ...           ...                                 ...
# 20715          Pizza        Burger                       yum yum pizza
# 20716          Kebab         Pizza                             yummies
# 20717          Kebab         Pizza                       yummies kebab
# 20718        Chinese       Chinese                               yummy
# 20719        Chinese       Chinese                        yummy garden
# 20720        Chinese       Chinese                         yummy house
# 20721        Chinese  Fish & Chips                       yummy kitchen
# 20722          Pizza         Pizza                         yummy pizza
# 20723        Chinese       Chinese                         yummy yummy
# 20724          Pizza         Kebab                        yummys pizza
# 20725        Chinese         Asian                      yun restaurant
# 20726         Indian        Indian                             zaffran
# 20727        Chinese        Indian                               zaika
# 20728         Indian        Indian                               zaiqa
# 20729         Indian        Indian                                zaks
# 20730          Grill     Fast Food                             zam zam
# 20731          Pizza         Kebab                                zara
# 20732         Indian        Indian                zara indian takeaway
# 20733         Indian        Indian                          zara spice
# 20734          Grill        Burger                               zatar
# 20735          Pizza         Pizza                          zaza pizza
# 20736         Indian        Indian                               zeera
# 20737         Indian        Indian                         zeera spice
# 20738         Indian        Indian                      zeera tandoori
# 20739        Chinese         Asian                                 zen
# 20740  Sand/Caf/Bake       British                          zenas cafe
# 20741       Desserts      Desserts             zidanes indulgence york
# 20742         Burger       Chicken                                zing
# 20743         Burger         Kebab                              zorbas
# 20744         MedMid         Kebab                         zouk lounge
#
#          label_final  Burger  Chicken  Kebab  Pizza  Fast Food  valid  bal
# 0              Kebab       0        0      1      0          0  False    5
# 1             Indian       0        0      0      0          0  False    1
# 2          Fast Food       0        0      0      0          0  False    1
# 3             Indian       0        0      0      0          0  False    1
# 4             Indian       0        0      0      0          0   True    0
# 5          Fast Food       0        0      0      0          1  False    1
# 6             Indian       0        0      0      0          0   True    0
# 7             Indian       0        0      0      0          0  False    1
# 8              Pizza       0        0      0      1          0  False    1
# 9       Fish & Chips       0        0      0      0          0  False    4
# 10         Fast Food       0        0      0      0          0  False    1
# 11             Pizza       0        0      0      0          0  False    1
# 12             Pizza       0        0      0      0          0  False    1
# 13         Fast Food       0        0      0      0          0  False    1
# 14      Fish & Chips       0        0      0      0          0   True    0
# 15         Fast Food       0        0      1      1          0  False    1
# 16             Kebab       0        0      1      0          0   True    0
# 17           Chinese       0        0      0      0          0   True    0
# 18            Indian       0        0      0      0          0  False    1
# 19            Indian       0        0      0      0          0  False    1
# 20         Fast Food       0        0      0      0          0  False    1
# 21            Indian       0        0      0      0          0  False    1
# 22         Fast Food       0        0      0      0          0  False    1
# 23            Indian       0        0      0      0          0  False    1
# 24             Pizza       0        0      0      1          0   True    0
# 25            Indian       0        0      0      0          0  False    1
# 26         Fast Food       0        0      0      0          0  False    1
# 27             Kebab       0        0      1      0          0   True    0
# 28            Indian       0        0      0      0          0  False    1
# 29         Fast Food       0        0      0      0          0  False    1
# ...              ...     ...      ...    ...    ...        ...    ...  ...
# 20715          Pizza       0        0      0      1          0  False    1
# 20716      Fast Food       0        0      0      0          0  False    1
# 20717          Kebab       0        0      1      0          0  False    4
# 20718        Chinese       0        0      0      0          0  False    1
# 20719        Chinese       0        0      0      0          0  False    1
# 20720        Chinese       0        0      0      0          0  False    1
# 20721        Chinese       0        0      0      0          0   True    0
# 20722          Pizza       0        0      0      1          0   True    0
# 20723        Chinese       0        0      0      0          0  False    1
# 20724          Pizza       0        0      0      1          0  False    1
# 20725        Chinese       0        0      0      0          0  False    1
# 20726         Indian       0        0      0      0          0  False    1
# 20727        Chinese       0        0      0      0          0   True    0
# 20728         Indian       0        0      0      0          0  False    1
# 20729         Indian       0        0      0      0          0  False    1
# 20730      Fast Food       0        0      0      0          0   True    0
# 20731      Fast Food       0        0      0      0          0   True    0
# 20732         Indian       0        0      0      0          0   True    0
# 20733         Indian       0        0      0      0          0  False    1
# 20734      Fast Food       0        0      0      0          0  False    1
# 20735          Pizza       0        0      0      1          0  False    1
# 20736         Indian       0        0      0      0          0  False    1
# 20737         Indian       0        0      0      0          0  False    1
# 20738         Indian       0        0      0      0          0  False    1
# 20739        Chinese       0        0      0      0          0   True    0
# 20740  Sand/Caf/Bake       0        0      0      0          0  False    3
# 20741       Desserts       0        0      0      0          0   True    0
# 20742      Fast Food       0        0      0      0          0  False    1
# 20743      Fast Food       0        0      0      0          0  False    1
# 20744          Kebab       0        0      0      0          0   True    0
#
# [20745 rows x 11 columns]

# %% [markdown]
# ## Build a Fastai Data Loader
#
# Load in the dataframe and extract indexes for training, validation and balanced trainings.

# %%
df = pd.read_csv('28_05_2020_deliveroo_basic.csv')
#df = pd.read_csv('27_01_2020_use_name_no_burg.csv')

valid_idx = df[df.valid].index
train_idx = df[~df.valid].index

bal_idx = []
for k, v in zip(df.index, df.bal):
    bal_idx += [k]*v

# %%
df[df['label_final']=='Chicken']
# Out:
#               label        label2                      ascii_name_fix  \
# 89          Chicken     Fast Food               hussain fried chicken
# 141       Peri Peri       Chicken                janith fried chicken
# 170       Peri Peri       Chicken                           everydays
# 181         Chicken         Pizza                norton fried chicken
# 207         Chicken        Burger           new orlando fried chicken
# 268         Chicken         Grill                       bonfire grill
# 271           Latam       Chicken             zaps burrito bar durham
# 279       Peri Peri       Chicken                         rooster run
# 315         Chicken        Burger                      goodys chicken
# 328          MedMid       Chicken               south quay streetfood
# 401         Chicken     Peri Peri                        chicken time
# 426       Peri Peri       Chicken                       perios oxford
# 511         Chicken        Burger                   yfc fried chicken
# 562         Chicken     Peri Peri                            roasterz
# 578         Chicken     AfroCarib                   chickos caribbean
# 611         Chicken         Grill             chicken roast hot grill
# 692         Chicken     Fast Food                   herne bay chicken
# 809         Chicken        Burger              crownchy fried chicken
# 816         Chicken        Burger                      chicken choice
# 854    Fish & Chips         Kebab          pauls fish and chicken bar
# 883         Chicken        Burger                   dfc fried chicken
# 1010          Latam       Chicken                              wrapik
# 1058        Chicken        Burger                      munchy chicken
# 1085        Chicken         Grill                        frango grill
# 1127        Chicken  Fish & Chips              chatteris chicken shop
# 1220         Burger       Chicken       champs american fried chicken
# 1223        Chicken     Peri Peri               taunton fried chicken
# 1280        Chicken        Burger                      chicken lickin
# 1297      AfroCarib       Chicken                    sa janes kitchen
# 1299        Chicken     Peri Peri                      delish chicken
# ...             ...           ...                                 ...
# 19909       Chicken        Burger                 ministry of chicken
# 19916         Asian       Chicken            mission saigon by taster
# 19971       Chicken         Pizza                      nevada chicken
# 19995       Chicken     Peri Peri                            nom noms
# 19996         Asian       Chicken                         nomi katsu
# 19998       Chicken         Halal                        noodle house
# 20025       Chicken     Peri Peri                       omore rosters
# 20056        Burger        Burger                       papas chicken
# 20071        Burger       Chicken               peachs fried chicken
# 20083       Chicken       Chicken                        peri cottage
# 20100       Chicken     Peri Peri                    piri piri corner
# 20101     Peri Peri       Chicken                   piri piri express
# 20260       British       Chicken            reliance fish restaurant
# 20282       Chicken       Chicken                             roostas
# 20302       Chicken         Grill  sahara fried  and  grilled chicken
# 20313       Chicken       Chicken                              sangam
# 20341       Chicken       Chicken                      sheen fish bar
# 20356       Chicken        Burger         simpsons chicken  and  ribs
# 20379         Grill       Chicken                           spice bay
# 20427       Chicken         Pizza                  star fried chicken
# 20441       Chicken           Bbq                      sultan sofrasi
# 20482       Chicken       English                          taste buds
# 20495       Chicken         Asian                               tasty
# 20525       Chicken        Burger                   the chicken place
# 20546       Chicken         Grill                  the flamin chicken
# 20547         Latam       Chicken                        the flavours
# 20643       Chicken        Burger                    uk fried chicken
# 20655       Chicken         Kebab                         usa chicken
# 20656       Chicken         Pizza                   usa fried chicken
# 20686       Chicken       Chicken                             wing it
#
#       label_final  Burger  Chicken  Kebab  Pizza  Fast Food  valid  bal
# 89        Chicken       0        1      0      0          0  False    3
# 141       Chicken       0        1      0      0          0  False    2
# 170       Chicken       0        0      0      0          0  False    3
# 181       Chicken       0        1      0      0          0   True    0
# 207       Chicken       0        1      0      0          0  False    2
# 268       Chicken       0        0      0      0          0   True    0
# 271       Chicken       0        0      0      0          0   True    0
# 279       Chicken       0        0      0      0          0   True    0
# 315       Chicken       0        1      0      0          0  False    7
# 328       Chicken       0        0      0      0          0  False    3
# 401       Chicken       0        1      0      0          0  False    7
# 426       Chicken       0        0      0      0          0   True    0
# 511       Chicken       0        1      0      0          0   True    0
# 562       Chicken       0        0      0      0          0  False    4
# 578       Chicken       0        0      0      0          0  False    1
# 611       Chicken       0        1      0      0          0   True    0
# 692       Chicken       0        1      0      0          0   True    0
# 809       Chicken       0        1      0      0          0   True    0
# 816       Chicken       0        1      0      0          0  False    1
# 854       Chicken       0        1      0      0          0  False    3
# 883       Chicken       0        1      0      0          0   True    0
# 1010      Chicken       0        0      0      0          0   True    0
# 1058      Chicken       0        1      0      0          0   True    0
# 1085      Chicken       0        0      0      0          0  False    2
# 1127      Chicken       0        1      0      0          0  False    2
# 1220      Chicken       0        1      0      0          0   True    0
# 1223      Chicken       0        1      0      0          0  False    5
# 1280      Chicken       0        1      0      0          0  False    1
# 1297      Chicken       0        0      0      0          0  False    2
# 1299      Chicken       0        1      0      0          0   True    0
# ...           ...     ...      ...    ...    ...        ...    ...  ...
# 19909     Chicken       0        1      0      0          0  False    3
# 19916     Chicken       0        0      0      0          0  False    4
# 19971     Chicken       0        1      0      0          0  False    3
# 19995     Chicken       0        0      0      0          0   True    0
# 19996     Chicken       0        0      0      0          0   True    0
# 19998     Chicken       0        0      0      0          0  False    3
# 20025     Chicken       0        0      0      0          0  False    2
# 20056     Chicken       0        1      0      0          0   True    0
# 20071     Chicken       0        1      0      0          0  False    3
# 20083     Chicken       0        0      0      0          0  False    3
# 20100     Chicken       0        0      0      0          0  False    6
# 20101     Chicken       0        0      0      0          0  False    2
# 20260     Chicken       0        0      0      0          0  False    4
# 20282     Chicken       0        0      0      0          0  False    2
# 20302     Chicken       0        1      0      0          0  False    3
# 20313     Chicken       0        0      0      0          0   True    0
# 20341     Chicken       0        0      0      0          0   True    0
# 20356     Chicken       0        1      0      0          0   True    0
# 20379     Chicken       0        0      0      0          0  False    6
# 20427     Chicken       0        1      0      0          0   True    0
# 20441     Chicken       0        0      0      0          0   True    0
# 20482     Chicken       0        0      0      0          0   True    0
# 20495     Chicken       0        0      0      0          0  False    3
# 20525     Chicken       0        1      0      0          0   True    0
# 20546     Chicken       0        1      0      0          0   True    0
# 20547     Chicken       0        0      0      0          0  False    3
# 20643     Chicken       0        1      0      0          0  False    4
# 20655     Chicken       0        1      0      0          0  False    2
# 20656     Chicken       0        1      0      0          0  False    2
# 20686     Chicken       0        0      0      0          0   True    0
#
# [1074 rows x 11 columns]

# %%
class LetterTokenizer(BaseTokenizer):
    "Character level tokenizer function."
    def __init__(self, lang): pass
    def tokenizer(self, t:str) -> List[str]:
        out = []
        i = 0
        while i < len(t):
            if t[i:].startswith(BOS):
                out.append(BOS)
                i += len(BOS)
            else:
                out.append(t[i])
                i += 1
        return out
            
    def add_special_cases(self, toks:Collection[str]): pass

# %%
itos = [UNK, BOS] + list(string.ascii_lowercase + " -'@&)(." +"0123456789")

# %%
vocab=Vocab(itos)
tokenizer=Tokenizer(LetterTokenizer, pre_rules=[], post_rules=[])

# %%
train_df = df.iloc[train_idx, [3,2]]
bal_df = df.iloc[bal_idx, [3,2]]
valid_df = df.iloc[valid_idx, [3,2]]

# %%
df.bal.max()
# Out:
# 10

# %% [markdown]
# ## Language model
#
# Language model with Just Eat data only

# %%
data = TextClasDataBunch.from_df(path='.', train_df=bal_df, valid_df=valid_df,
                         tokenizer=tokenizer, vocab=vocab,
                         mark_fields=False, bs=128)

# %%
learn = text_classifier_learner(data, AWD_LSTM,drop_mult=1.0)

# %%
learn.load_encoder('just_eat_enc_bs128_2')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
# lr = 1e-2
# moms = (0.7,0.8)
# scale = (1**4)
# cycles = 20
lr = 1e-2
moms = (0.7,0.8)
scale = (1**4)
cycles = 20

# %%
learn.fit_one_cycle(cycles, lr, moms=moms)
# Out:
# Total time: 04:47 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>1.747387</th>
#     <th>1.424509</th>
#     <th>0.537111</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.402833</th>
#     <th>1.185237</th>
#     <th>0.609778</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.248747</th>
#     <th>1.089328</th>
#     <th>0.645333</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.160108</th>
#     <th>1.054102</th>
#     <th>0.666000</th>
#     <th>00:15</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.108055</th>
#     <th>1.044920</th>
#     <th>0.667778</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>1.102929</th>
#     <th>1.034766</th>
#     <th>0.670444</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>1.069504</th>
#     <th>1.016322</th>
#     <th>0.674667</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>1.025151</th>
#     <th>1.009889</th>
#     <th>0.679556</th>
#     <th>00:15</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>1.029754</th>
#     <th>1.016232</th>
#     <th>0.678444</th>
#     <th>00:15</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.966687</th>
#     <th>1.001233</th>
#     <th>0.689556</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.957384</th>
#     <th>1.017725</th>
#     <th>0.682667</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.883001</th>
#     <th>0.990013</th>
#     <th>0.698444</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.845331</th>
#     <th>0.996355</th>
#     <th>0.700667</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.822312</th>
#     <th>1.016178</th>
#     <th>0.695111</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.791646</th>
#     <th>1.022749</th>
#     <th>0.700667</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.759880</th>
#     <th>1.019222</th>
#     <th>0.702444</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.689709</th>
#     <th>1.046279</th>
#     <th>0.697778</th>
#     <th>00:15</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.709248</th>
#     <th>1.031776</th>
#     <th>0.702889</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.694561</th>
#     <th>1.047394</th>
#     <th>0.702444</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.680508</th>
#     <th>1.036042</th>
#     <th>0.705556</th>
#     <th>00:14</th>
#   </tr>
# </table>

# %%
learn.fit_one_cycle(cycles, lr, moms=moms)
# Out:
# Total time: 04:48 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>0.713958</th>
#     <th>1.030561</th>
#     <th>0.702000</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.705804</th>
#     <th>1.052981</th>
#     <th>0.702000</th>
#     <th>00:15</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.725887</th>
#     <th>1.042494</th>
#     <th>0.697333</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.781903</th>
#     <th>1.095455</th>
#     <th>0.694889</th>
#     <th>00:15</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.808036</th>
#     <th>1.046224</th>
#     <th>0.692222</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.823693</th>
#     <th>1.062594</th>
#     <th>0.694444</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.793236</th>
#     <th>1.067742</th>
#     <th>0.693778</th>
#     <th>00:15</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.889750</th>
#     <th>0.992011</th>
#     <th>0.699778</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.780182</th>
#     <th>1.064211</th>
#     <th>0.702222</th>
#     <th>00:15</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.773837</th>
#     <th>1.060557</th>
#     <th>0.702222</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.771681</th>
#     <th>1.058639</th>
#     <th>0.699333</th>
#     <th>00:15</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.712552</th>
#     <th>1.054676</th>
#     <th>0.702889</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.710781</th>
#     <th>1.113409</th>
#     <th>0.697333</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.662281</th>
#     <th>1.142197</th>
#     <th>0.700222</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.634540</th>
#     <th>1.146876</th>
#     <th>0.705111</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.624731</th>
#     <th>1.164247</th>
#     <th>0.704444</th>
#     <th>00:15</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.599488</th>
#     <th>1.151952</th>
#     <th>0.701111</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.578912</th>
#     <th>1.172817</th>
#     <th>0.703111</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.598512</th>
#     <th>1.169527</th>
#     <th>0.702667</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.562375</th>
#     <th>1.179190</th>
#     <th>0.702889</th>
#     <th>00:13</th>
#   </tr>
# </table>

# %%
learn.fit_one_cycle(cycles, lr, moms=moms)
# Out:
# Total time: 04:34 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>0.590527</th>
#     <th>1.090141</th>
#     <th>0.703889</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.603216</th>
#     <th>1.088254</th>
#     <th>0.706111</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.634155</th>
#     <th>1.090154</th>
#     <th>0.703611</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.683408</th>
#     <th>1.100006</th>
#     <th>0.702222</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.717303</th>
#     <th>1.066090</th>
#     <th>0.693889</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.775787</th>
#     <th>1.045997</th>
#     <th>0.698333</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.768379</th>
#     <th>1.061563</th>
#     <th>0.698889</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.761997</th>
#     <th>1.045723</th>
#     <th>0.703611</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.722673</th>
#     <th>1.084102</th>
#     <th>0.697778</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.704453</th>
#     <th>1.045970</th>
#     <th>0.703333</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.666681</th>
#     <th>1.075786</th>
#     <th>0.700556</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.659827</th>
#     <th>1.075129</th>
#     <th>0.697500</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.635574</th>
#     <th>1.092781</th>
#     <th>0.699722</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.602363</th>
#     <th>1.115567</th>
#     <th>0.706667</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.571252</th>
#     <th>1.113574</th>
#     <th>0.702222</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.568855</th>
#     <th>1.133212</th>
#     <th>0.704167</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.538146</th>
#     <th>1.154962</th>
#     <th>0.703333</th>
#     <th>00:14</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.521120</th>
#     <th>1.153882</th>
#     <th>0.701667</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.528653</th>
#     <th>1.177574</th>
#     <th>0.700833</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.522333</th>
#     <th>1.147255</th>
#     <th>0.704444</th>
#     <th>00:13</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('2020_04_28_use_name_ff_ind')

# %%
learn.freeze_to(-2)

# %%
learn.fit_one_cycle(cycles, slice((lr/2)/scale,(lr/2)), moms=moms)
#learn.fit_one_cycle(5, slice(5e-3/(2.6**4),5e-3), moms=(0.2,0.1))
# Out:
# Total time: 00:58 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>1.302489</th>
#     <th>1.210643</th>
#     <th>0.608889</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.147067</th>
#     <th>1.205897</th>
#     <th>0.625079</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.043286</th>
#     <th>1.198088</th>
#     <th>0.634921</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.959284</th>
#     <th>1.212335</th>
#     <th>0.638730</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.937127</th>
#     <th>1.237250</th>
#     <th>0.638095</th>
#     <th>00:11</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.freeze_to(-3)
#learn.fit_one_cycle(5, slice(1e-4 / (2.6 ** 4), 1e-4), moms=(0.2, 0.1))
learn.fit_one_cycle(cycles, slice((lr/10)/scale,(lr/10)), moms=moms)
# Out:
# Total time: 01:32 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>0.895113</th>
#     <th>1.222485</th>
#     <th>0.637778</th>
#     <th>00:17</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.889085</th>
#     <th>1.226429</th>
#     <th>0.636825</th>
#     <th>00:18</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.881259</th>
#     <th>1.236015</th>
#     <th>0.634286</th>
#     <th>00:20</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.881231</th>
#     <th>1.257907</th>
#     <th>0.636190</th>
#     <th>00:17</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.855727</th>
#     <th>1.272891</th>
#     <th>0.634286</th>
#     <th>00:18</th>
#   </tr>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(5, slice(5e-5 / (2.6 ** 4), 5e-5), moms=(0.2, 0.1))

# %%
    def confusion_matrix(self):
        "Confusion matrix as an `np.ndarray`"
        x=torch.arange(0,data.c)
        cm = ((self.pred_class==x[:,None]) & (self.y_true==x[:,None,None])).sum(2)
        return cm.cpu().numpy()

    def plot_confusion_matrix(self, normalize:bool=False, title:str='Confusion matrix', cmap:Any="Blues", figsize:tuple=None):
        "Plot the confusion matrix"
        # This function is copied from the scikit docs
        cm = self.confusion_matrix()
        plt.figure(figsize=figsize)
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, self.data.classes, rotation=45)
        plt.yticks(tick_marks, self.data.classes)

        if normalize: cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

# %%
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)

# %%
interp.plot_confusion_matrix(figsize=(10,10))

# %%
interp.plot_confusion_matrix(figsize=(10,10))

# %%
interp.plot_confusion_matrix(figsize=(10,10))

# %%
interp.plot_confusion_matrix(figsize=(10,10))

# %%
#txt_ci = TextClassificationInterpretation.from_learner(learn)
interp2 = TextClassificationInterpretation(learn, *learn.get_preds(with_loss=True, ordered=True))

# %%
#txt_ci.show_top_losses(20)
blah = interp2.show_top_losses(10000)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Text</th>
#       <th>Prediction</th>
#       <th>Actual</th>
#       <th>Loss</th>
#       <th>Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos   g r i l l   6 6</td>
#       <td>Fast Food</td>
#       <td>Fish &amp; Chips</td>
#       <td>16.49</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p u n j a b i   c o n n e c t i o n</td>
#       <td>Indian</td>
#       <td>Fish &amp; Chips</td>
#       <td>15.08</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   i b r a h i m s</td>
#       <td>Indian</td>
#       <td>Desserts</td>
#       <td>15.04</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   m o x i e s   f i s h   b a r</td>
#       <td>Fish &amp; Chips</td>
#       <td>Sand/Caf/Bake</td>
#       <td>14.66</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   f i n o s</td>
#       <td>Fast Food</td>
#       <td>Kebab</td>
#       <td>13.28</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   b e l m o n t   t a n d o o r i   r e s t a u r a n t   -   h a r r o w</td>
#       <td>Indian</td>
#       <td>Chicken</td>
#       <td>12.43</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   n o v e l l i n o</td>
#       <td>Pizza</td>
#       <td>Sand/Caf/Bake</td>
#       <td>12.32</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   o r s i n o   -   h o v e</td>
#       <td>Pizza</td>
#       <td>Desserts</td>
#       <td>12.15</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   f l a m e   p i r i   p i r i</td>
#       <td>Chicken</td>
#       <td>Kebab</td>
#       <td>11.99</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   w i n t h o r p e   f i s h   b a r</td>
#       <td>Fish &amp; Chips</td>
#       <td>Sand/Caf/Bake</td>
#       <td>11.83</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   b a s h a   f o o d</td>
#       <td>Fast Food</td>
#       <td>Kebab</td>
#       <td>11.65</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   e c c o   p i z z e r i a   -   h e a d i n g l e y</td>
#       <td>Pizza</td>
#       <td>Desserts</td>
#       <td>11.60</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   t o n y s   t a n d o o r i   t a k e a w a y</td>
#       <td>Indian</td>
#       <td>Fish &amp; Chips</td>
#       <td>11.60</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p i z z e r i a   d i   n a p o l i   -   r o m f o r d</td>
#       <td>Pizza</td>
#       <td>Desserts</td>
#       <td>11.51</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s u g a r   k i n g</td>
#       <td>Desserts</td>
#       <td>Fish &amp; Chips</td>
#       <td>11.30</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   m a r h a b a   -   b l a c k b u r n</td>
#       <td>Indian</td>
#       <td>Desserts</td>
#       <td>11.21</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   w o k   i n n   -   t i m p e r l e y</td>
#       <td>Chinese</td>
#       <td>Chicken</td>
#       <td>11.09</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   b r u n c h   b a r</td>
#       <td>Sand/Caf/Bake</td>
#       <td>Kebab</td>
#       <td>10.95</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   t a s   f i r i n   -   b r i c k   l a n e</td>
#       <td>Fast Food</td>
#       <td>Kebab</td>
#       <td>10.84</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   v i t t o   p i z z e r i a</td>
#       <td>Pizza</td>
#       <td>Kebab</td>
#       <td>10.63</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   b a r o n s</td>
#       <td>Desserts</td>
#       <td>Kebab</td>
#       <td>10.47</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s h e e n   f i s h   b a r</td>
#       <td>Fish &amp; Chips</td>
#       <td>Chicken</td>
#       <td>10.32</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   r o b s   f i s h   b a r</td>
#       <td>Fish &amp; Chips</td>
#       <td>Kebab</td>
#       <td>10.10</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   l i m e   c u i s i n e</td>
#       <td>Chinese</td>
#       <td>Desserts</td>
#       <td>10.05</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   h o l y   s m o k e   b a r - b - q u e</td>
#       <td>Fast Food</td>
#       <td>Chicken</td>
#       <td>9.98</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s u g a r   l u m p</td>
#       <td>Desserts</td>
#       <td>Sand/Caf/Bake</td>
#       <td>9.96</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   b o b a   t i m e   xxunk o   xxunk a   xxunk h i   xxunk i a n     -   c a r d i f f</td>
#       <td>Chinese</td>
#       <td>Desserts</td>
#       <td>9.94</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   b u e n o s</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>9.90</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p e p i n o</td>
#       <td>Pizza</td>
#       <td>Desserts</td>
#       <td>9.88</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   c h i m n e y s</td>
#       <td>Indian</td>
#       <td>Desserts</td>
#       <td>9.80</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s o u v l a k i</td>
#       <td>Kebab</td>
#       <td>Sand/Caf/Bake</td>
#       <td>9.73</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   h a r m a n   t u r k i s h   r e s t a u r a n t   -   i l f o r d</td>
#       <td>Kebab</td>
#       <td>Pizza</td>
#       <td>9.64</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s p i c y w a v e s</td>
#       <td>Indian</td>
#       <td>Pizza</td>
#       <td>9.57</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   f u n   f i l l i n g s</td>
#       <td>Chinese</td>
#       <td>Sand/Caf/Bake</td>
#       <td>9.55</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s u n s h i n e   d e l i</td>
#       <td>Sand/Caf/Bake</td>
#       <td>Chicken</td>
#       <td>9.50</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s t a n l e y s</td>
#       <td>Fish &amp; Chips</td>
#       <td>Desserts</td>
#       <td>9.47</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p i r i   b i t e</td>
#       <td>Chicken</td>
#       <td>Kebab</td>
#       <td>9.42</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   b e s t   i n   t o w n</td>
#       <td>Indian</td>
#       <td>Kebab</td>
#       <td>9.40</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   b o m b a y   w o k</td>
#       <td>Indian</td>
#       <td>Chinese</td>
#       <td>9.40</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p e r i o s   o x f o r d   -   c o w l e y</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>9.39</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p i c k e t t s</td>
#       <td>Sand/Caf/Bake</td>
#       <td>Fish &amp; Chips</td>
#       <td>9.28</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   b e r r i e s   b a g e l s     a n d     s h a k e s</td>
#       <td>Desserts</td>
#       <td>Sand/Caf/Bake</td>
#       <td>9.28</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   e . m o n o</td>
#       <td>Pizza</td>
#       <td>Kebab</td>
#       <td>9.17</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   t i k i s</td>
#       <td>Indian</td>
#       <td>Desserts</td>
#       <td>9.16</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   c h i c h i n i</td>
#       <td>Fast Food</td>
#       <td>Sand/Caf/Bake</td>
#       <td>9.14</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p e r i   h u t</td>
#       <td>Chicken</td>
#       <td>Kebab</td>
#       <td>9.13</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   j j s</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>9.12</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   i l   v i c o l o</td>
#       <td>Pizza</td>
#       <td>Fish &amp; Chips</td>
#       <td>9.10</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   t h e   m a s t e r   f r y e r</td>
#       <td>Fish &amp; Chips</td>
#       <td>Ch

# %%
interp2.
# Out:
# TextClasDataBunch;
#
# Train: LabelList (45000 items)
# x: TextList
# xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a,xxbos   m a h a r a n i   i n d i a n   c u i s i n e,xxbos   s w e e t   j a m r o c k,xxbos   s w e e t   j a m r o c k,xxbos   z a a f r a n
# y: CategoryList
# Fast Food,Indian,Fast Food,Fast Food,Indian
# Path: .;
#
# Valid: LabelList (3600 items)
# x: TextList
# xxbos   j     a n d     d   k e b a b,xxbos   v a r i e t y s   t a k e a w a y,xxbos   h o t   e x p r e s s,xxbos   f a m i l y   k e b a b     a n d     p i z z a r i a,xxbos   s u r f     a n d     t u r f
# y: CategoryList
# Kebab,Fast Food,Kebab,Fast Food,Fast Food
# Path: .;
#
# Test: None

# %%
my_top_losses = interp2.top_losses()
my_ds = interp2.data.dl('Valid').dataset
my_classes = interp2.data.valid_ds.classes
my_preds_class = interp2.pred_class
tl_val,tl_idx = my_top_losses


items = []
for idx in tl_idx:
    tx,cl = interp2.data.valid_ds[idx]
    cl = cl.data
    txt =  ' '.join([''.join(i.split()) for i in re.split(r' {2,}',tx.text)])[6:]
    tmp = [txt, f'{my_classes[my_preds_class[idx]]}', f'{my_classes[cl]}']
    items.append(tmp)
items = np.array(items)
names = ['Text', 'Prediction', 'Actual']
df = pd.DataFrame({n:items[:,i] for i,n in enumerate(names)}, columns=names)

# %%
df.to_csv('13_01_2020_errors.csv', index=False)

# %%
cm = interp2.confusion_matrix()

# %%
plt.rcParams.update({'font.size': 14})
interp2.plot_confusion_matrix(figsize=(8,8))

# %%
#Precision = tp / tp + fp
recall = np.diag(cm) / np.sum(cm, axis = 1)
precision = np.diag(cm) / np.sum(cm, axis = 0)

# %%
recall
# Out:
# array([0.62 , 0.81 , 0.622, 0.652, 0.762, 0.838, 0.71 , 0.764, 0.548])

# %%
precision
# Out:
# array([0.824468, 0.808383, 0.803618, 0.415816, 0.824675, 0.631024, 0.859564, 0.786008, 0.641686])

# %%
precision.mean()
# Out:
# 0.7328048016735114

# %%
recall.mean()
# Out:
# 0.7028888888888889

# %%
learn.predict("mamoods mirch")
# Out:
# (Category Desserts,
#  tensor(2),
#  tensor([0.1397, 0.0117, 0.3502, 0.1343, 0.0332, 0.0265, 0.0559, 0.1784, 0.0701]))

# %%
learn.predict("fryer tuck")
# Out:
# (Category Fish & Chips,
#  tensor(4),
#  tensor([3.3629e-07, 1.2309e-03, 3.5925e-06, 8.1342e-04, 9.9777e-01, 9.5526e-05,
#          4.4523e-06, 3.9081e-05, 4.0542e-05]))

# %%
learn.predict("jade garden")
# Out:
# (Category Chinese,
#  tensor(1),
#  tensor([2.3990e-07, 9.9865e-01, 2.2686e-07, 2.7119e-04, 5.1614e-05, 9.7042e-04,
#          1.6681e-06, 3.7176e-05, 1.4342e-05]))

# %%
learn.predict("jerk house")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([0.2168, 0.0406, 0.6402, 0.0161, 0.0781, 0.0083]))

# %%
learn.predict("abra kebabra")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([2.4363e-05, 9.9402e-07, 9.9972e-01, 2.5463e-07, 2.4918e-04, 2.0597e-07]))

# %%
learn.predict("mcdoner")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([3.2807e-03, 5.0873e-04, 9.7921e-01, 6.8078e-03, 9.9109e-03, 2.7945e-04]))

# %%
learn.predict("southern fried rooster")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([1.2324e-02, 4.9889e-04, 9.6919e-01, 4.4617e-03, 1.1890e-02, 1.6323e-03]))

# %%
learn.predict("luigis pizza parlour")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([1.8512e-04, 1.0966e-05, 9.9935e-01, 4.0324e-05, 3.8692e-04, 2.2607e-05]))

# %%
learn.predict("mrs boggins sandwich shop")
# Out:
# (Category Sand/Caf/Bake,
#  tensor(5),
#  tensor([1.2056e-05, 4.1230e-05, 2.2578e-04, 1.1115e-05, 3.0048e-06, 9.9971e-01]))

# %%
learn.predict("codfather")
# Out:
# (Category Fish & Chips,
#  tensor(3),
#  tensor([5.8303e-05, 7.2931e-06, 5.3680e-03, 9.9445e-01, 4.3550e-05, 7.2614e-05]))

# %%
learn.predict("top chef")
# Out:
# (Category Chinese,
#  tensor(0),
#  tensor([7.6555e-01, 1.6182e-03, 1.3469e-01, 5.7949e-03, 9.1621e-02, 7.2157e-04]))

# %%
learn.predict("doner cha want me")
# Out:
# (Category Indian,
#  tensor(4),
#  tensor([0.1948, 0.0015, 0.3805, 0.0207, 0.3818, 0.0207]))

# %%
learn.predict("kebabs r us")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([3.2910e-05, 6.0077e-08, 9.9990e-01, 9.7345e-08, 6.6743e-05, 2.0561e-07]))

# %%
learn.predict("sapna")
# Out:
# (Category Indian,
#  tensor(4),
#  tensor([2.1046e-02, 7.7136e-05, 2.6818e-01, 1.6395e-03, 7.0792e-01, 1.1401e-03]))

# %%
learn.predict("cocum")
# Out:
# (Category Indian,
#  tensor(4),
#  tensor([1.2241e-02, 2.1769e-04, 9.6867e-02, 6.4483e-04, 8.8962e-01, 4.1378e-04]))

# %%
learn.predict("uncle sam")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([0.0388, 0.1145, 0.4139, 0.1552, 0.2734, 0.0042]))
