# %% [markdown]
# Using:
#     https://gist.github.com/EdwardJRoss/86b31848a7951411de56f10f55e9de4e
#     https://forums.fast.ai/t/character-level-language-model/31379
#
# Lesson 3 RNN
#
# Offline steps:
#
# 1. Combine scraped files
# 2. Use Notepad++ to convert encoding to UTF8
# 3. sort out carriage returns etc.
# 4. End up with rawest_just_eat.csv
#
# Long story:
# 1. Get raw scraped files
# 2. Open them in Notepad++ and choose Encode in UTF8
# 3. This didn't work for #7 which had to be saved as unicode text and then saved as UTF 8
# 4. Then knit them together in Python

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.text import *
import string
from unidecode import unidecode

# %%
df = pd.read_csv('/home/trpb2/data/takeaway/rawest_just_eat.csv')

# %%
my_dir = '/home/trpb2/takeaways/data/scraped/'

# %%
df_temp = pd.concat([pd.read_csv(my_dir+f) for f in os.listdir(my_dir)], ignore_index = True)

# %%
df = df_temp[['Name','Cuisines']]

# %%
df = pd.concat([df['Name'], df['Cuisines'].str.split(', ', expand=True)], axis=1)

# %%
df.columns = ['text','label','label2','label3']

# %%
df[df.label2.isna()]
# Out:
#                                                  text          label label2  \
# 2                        KFC Derby - Westfield Centre        Chicken   None
# 17                                 Bucky's Restaurant        African   None
# 26                           KFC Barnsley Peel Street        Chicken   None
# 27                                          The Balti         Indian   None
# 31                  Chiquito - Nottingham Cornerhouse        Mexican   None
# 43                              Chiquito - Trowbridge        Tex Mex   None
# 44                                      KFC Cippenham        Chicken   None
# 52                       Birdbox - Edinburgh The Gyle        Chicken   None
# 59                                        Cheung Sing        Chinese   None
# 64                            Abertillery Kebab House          Kebab   None
# 105             KFC Northampton - Nene Park Sixfields        Chicken   None
# 138                           Richfields Deli & Grill      Breakfast   None
# 142         Frankie & Benny's - Street Clarks Village       American   None
# 157                        KFC Darlington Albert Road        Chicken   None
# 171                                       We're sorry            NaN    NaN
# 176                The Pizza Brothers @ The 19TH Hole          Pizza   None
# 182                               Subway - New Street     Sandwiches   None
# 184                                      Phoenix Chef        Chinese   None
# 196                                   Bistro Italiano        Italian   None
# 204                         KFC - Dover Market Square        Chicken   None
# 206                                   The Cherry Tree          Pizza   None
# 217                                Stacks - Camberley        Burgers   None
# 219                                      Spaccanapoli        Italian   None
# 221                                   Stacks - Dundee        Burgers   None
# 227                                      The Seashell   Fish & Chips   None
# 230                                  Stacks - Bromley        Burgers   None
# 236                                       Upton Spice          Pizza   None
# 251                       KFC Doncaster - Thorne Road        Chicken   None
# 259    Kick Ass Burrito - Peterborough Pavilions West        Mexican   None
# 262                                      Chippy Chips   Fish & Chips   None
# ...                                               ...            ...    ...
# 32637                                 Gnosall Kitchen        Chinese   None
# 32646                             Birdbox - Stonedale        Chicken   None
# 32660                            Armadillo Restaurant  Mediterranean   None
# 32665                                       Chip Stop        English   None
# 32671                        Nehir Turkish Restaurant        Turkish   None
# 32687                                             NaN            NaN    NaN
# 32767                               Wimpy - Portslade       American   None
# 32794                                       Primavera        Italian   None
# 32803                                        Ying Xin        Chinese   None
# 32810                                Raggas Caribbean      Caribbean   None
# 32835                        Birdbox - Kirkstall Road        Chicken   None
# 32865                                    Hull Sashimi       Japanese   None
# 32882                                     Herbivorous          Vegan   None
# 32883                                Pepe’s Piri Piri        Chicken   None
# 32895                      Chicken Cottage - Coventry        Chicken   None
# 32907                                Moonlight Indian         Indian   None
# 32925                    Subway® - West Auckland Road     Sandwiches   None
# 32938                               Kaspa's - Bristol       Desserts   None
# 32957                                     KFC Margate        Chicken   None
# 32958                                   KFC Chingford        Chicken   None
# 32983                   Stacks - Greenwich Bugsby Way        Burgers   None
# 33015                                 Stacks - Durham        Burgers   None
# 33085                Mannofield Pizza Grill and Kebab          Kebab   None
# 33102                         Tennessee Fried Chicken        Chicken   None
# 33103                        Stacks - Leeds The Light        Burgers   None
# 33113              Subway® - West Bromwich New Square     Sandwiches   None
# 33165                                   Beijing House        Chinese   None
# 33176                               Birdbox - Croydon        Burgers   None
# 33200                                          Chowki         Indian   None
# 33207                         Stacks - Coventry Arena        Burgers   None
#
#       label3
# 2       None
# 17      None
# 26      None
# 27      None
# 31      None
# 43      None
# 44      None
# 52      None
# 59      None
# 64      None
# 105     None
# 138     None
# 142     None
# 157     None
# 171      NaN
# 176     None
# 182     None
# 184     None
# 196     None
# 204     None
# 206     None
# 217     None
# 219     None
# 221     None
# 227     None
# 230     None
# 236     None
# 251     None
# 259     None
# 262     None
# ...      ...
# 32637   None
# 32646   None
# 32660   None
# 32665   None
# 32671   None
# 32687    NaN
# 32767   None
# 32794   None
# 32803   None
# 32810   None
# 32835   None
# 32865   None
# 32882   None
# 32883   None
# 32895   None
# 32907   None
# 32925   None
# 32938   None
# 32957   None
# 32958   None
# 32983   None
# 33015   None
# 33085   None
# 33102   None
# 33103   None
# 33113   None
# 33165   None
# 33176   None
# 33200   None
# 33207   None
#
# [2175 rows x 4 columns]

# %%
df.dropna(thresh=3, inplace=True)

# %%
df['text'] = df.text.str.lower()

# %% [markdown]
# ## Character Set
#
# What letters outside of ASCII are in the names?

# %%
foreign_chars = Counter(_ for _ in ''.join(str(list(df.text))) if _ not in string.ascii_letters)
foreign_chars.most_common()
# Out:
# [(' ', 84450),
#  ("'", 58978),
#  (',', 31157),
#  ('"', 6346),
#  ('&', 2867),
#  ('-', 2409),
#  ('®', 579),
#  ('(', 366),
#  (')', 366),
#  ('1', 274),
#  ('2', 273),
#  ('’', 250),
#  ('.', 215),
#  ('@', 195),
#  ('4', 141),
#  ('3', 119),
#  ('0', 119),
#  ('8', 84),
#  ('6', 81),
#  ('9', 80),
#  ('7', 79),
#  ('5', 73),
#  ('!', 68),
#  ('é', 28),
#  ('`', 23),
#  ('´', 19),
#  ('/', 18),
#  ('#', 7),
#  ('‘', 7),
#  ('+', 6),
#  (':', 4),
#  ('?', 4),
#  ('–', 3),
#  ('*', 3),
#  ('ó', 2),
#  ('%', 2),
#  ('ê', 2),
#  ('ö', 2),
#  ('è', 2),
#  ('[', 1),
#  ('á', 1),
#  ('\\', 1),
#  ('ä', 1),
#  ('~', 1),
#  ('ü', 1),
#  ('°', 1),
#  (']', 1)]

# %%
df['ascii_name'] = df.text.apply(lambda x: unidecode(str(x)))
df[df.text != df.ascii_name]
# Out:
#                                      text         label         label2 label3  \
# 66          subway® - 7 wellmeadow street    Sandwiches          Lunch  Halal
# 103                           café  bagel        Bagels          Vegan   None
# 110         ollie’s kebab ye / fish&chips         Kebab   Fish & Chips   None
# 121         subway® gravesend high street       Subways     Sandwiches   None
# 129                hennie penny’s chicken       Chicken       American   None
# 213                 subway® - london road    Sandwiches          Halal   None
# 241                  subway® - charon way    Sandwiches          Lunch   None
# 336          subway® wakefield drive thru       Subways     Sandwiches   None
# 387        subway® - coventry high street    Sandwiches          Lunch   None
# 392             subway®- 9/11 high street    Sandwiches          Lunch   None
# 397                 subway® - turner rise    Sandwiches          Lunch   None
# 398                subway® - hull station    Sandwiches          Lunch  Halal
# 411              subway® chatham dockside    Sandwiches          Lunch   None
# 495                  subway® passey place       Subways     Sandwiches   None
# 500           subway® - st. peters street    Sandwiches          Lunch   None
# 506                               subway®    Sandwiches         Salads   None
# 530                subway® - whitton road    Sandwiches          Lunch   None
# 536                          subway® bury       Subways     Sandwiches   None
# 543                         lily’s bistro     Breakfast     Sandwiches   None
# 560                           kaviné cafe       English       European   None
# 585                   subway® walton vale       Subways     Sandwiches   None
# 640      subway® - north road, darlington       Subways          Lunch   None
# 641                               subway®    Sandwiches         Salads   None
# 686              subway® - 39 high street    Sandwiches          Lunch   None
# 688           subway® - framwellgate moor    Sandwiches          Lunch   None
# 690               subway® - quarry street    Sandwiches         Salads   None
# 715                               subway®    Sandwiches        English   None
# 726      subway® midland way (nottingham)       Subways     Sandwiches   None
# 771                     subway® chingford       Subways     Sandwiches  Halal
# 773                subway® moulsford mews       Subways     Sandwiches  Halal
# ...                                   ...           ...            ...    ...
# 31871              subway® - bramall lane    Sandwiches          Lunch  Halal
# 31898              stuart’s sandwich shop     Breakfast     Sandwiches   None
# 31917            subway® holdenhurst road       Subways     Sandwiches   None
# 31959             wayne’s coffee - ilford     Breakfast        Healthy   None
# 32042          subway® great homer street       Subways     Sandwiches   None
# 32048                    george´s curries        Indian          Curry   None
# 32107                              rion’s      Lebanese  Mediterranean   None
# 32195            harvester – horwich park       Burgers          Grill   None
# 32297                 subway® - malpas rd    Sandwiches          Lunch   None
# 32318                  subway® wallington       Subways     Sandwiches   None
# 32355                    subway® the moor       Subways     Sandwiches   None
# 32632        maureen’s caribbean takeaway     Caribbean        Chicken  Halal
# 32668         subway® great howard street       Subways     Sandwiches   None
# 32729            subway® - broadway plaza    Sandwiches          Lunch   None
# 32733    subway® - the shires retail park    Sandwiches          Lunch   None
# 32738           k2® of wimbledon est 1991        Indian          Curry  Halal
# 32789                subway® - ocean park    Sandwiches          Lunch   None
# 32815              subway® shepherds bush       Subways     Sandwiches   None
# 32845           let’s buffet sandwich bar    Sandwiches      Fast Food   None
# 32857        subway® - great western road    Sandwiches          Lunch   None
# 32864                 subway® - horsforth    Sandwiches          Lunch   None
# 32899                         bey’s diner         Kebab        Burgers  Halal
# 32931                             subway®    Sandwiches         Salads   None
# 33036      subway® gillingham high street    Sandwiches        Healthy   None
# 33041         subway® borough high street       Subways     Sandwiches   None
# 33046                 subway® - 8 swan st    Sandwiches          Lunch   None
# 33056    subway® northfield avenue branch    Sandwiches      Breakfast   None
# 33089          michael´s chinese takeaway       Chinese       Oriental   None
# 33133  sunny and dee’s traditional chippy  Fish & Chips      Fast Food   None
# 33190                          aj’s grill       Burgers        Chicken  Halal
#
#                                ascii_name
# 66        subway(r) - 7 wellmeadow street
# 103                           cafe  bagel
# 110         ollie's kebab ye / fish&chips
# 121       subway(r) gravesend high street
# 129                hennie penny's chicken
# 213               subway(r) - london road
# 241                subway(r) - charon way
# 336        subway(r) wakefield drive thru
# 387      subway(r) - coventry high street
# 392           subway(r)- 9/11 high street
# 397               subway(r) - turner rise
# 398              subway(r) - hull station
# 411            subway(r) chatham dockside
# 495                subway(r) passey place
# 500         subway(r) - st. peters street
# 506                             subway(r)
# 530              subway(r) - whitton road
# 536                        subway(r) bury
# 543                         lily's bistro
# 560                           kavine cafe
# 585                 subway(r) walton vale
# 640    subway(r) - north road, darlington
# 641                             subway(r)
# 686            subway(r) - 39 high street
# 688         subway(r) - framwellgate moor
# 690             subway(r) - quarry street
# 715                             subway(r)
# 726    subway(r) midland way (nottingham)
# 771                   subway(r) chingford
# 773              subway(r) moulsford mews
# ...                                   ...
# 31871            subway(r) - bramall lane
# 31898              stuart's sandwich shop
# 31917          subway(r) holdenhurst road
# 31959             wayne's coffee - ilford
# 32042        subway(r) great homer street
# 32048                    george's curries
# 32107                              rion's
# 32195            harvester - horwich park
# 32297               subway(r) - malpas rd
# 32318                subway(r) wallington
# 32355                  subway(r) the moor
# 32632        maureen's caribbean takeaway
# 32668       subway(r) great howard street
# 32729          subway(r) - broadway plaza
# 32733  subway(r) - the shires retail park
# 32738         k2(r) of wimbledon est 1991
# 32789              subway(r) - ocean park
# 32815            subway(r) shepherds bush
# 32845           let's buffet sandwich bar
# 32857      subway(r) - great western road
# 32864               subway(r) - horsforth
# 32899                         bey's diner
# 32931                           subway(r)
# 33036    subway(r) gillingham high street
# 33041       subway(r) borough high street
# 33046               subway(r) - 8 swan st
# 33056  subway(r) northfield avenue branch
# 33089          michael's chinese takeaway
# 33133  sunny and dee's traditional chippy
# 33190                          aj's grill
#
# [884 rows x 5 columns]

# %%
foreign_chars = Counter(_ for _ in ''.join(str(list(df.ascii_name))) if _ not in string.ascii_letters)
foreign_chars.most_common()
# Out:
# [(' ', 84450),
#  ("'", 58728),
#  (',', 31157),
#  ('"', 6872),
#  ('&', 2867),
#  ('-', 2412),
#  ('(', 945),
#  (')', 945),
#  ('1', 274),
#  ('2', 273),
#  ('.', 215),
#  ('@', 195),
#  ('4', 141),
#  ('3', 119),
#  ('0', 119),
#  ('8', 84),
#  ('6', 81),
#  ('9', 80),
#  ('7', 79),
#  ('5', 73),
#  ('!', 68),
#  ('`', 23),
#  ('/', 18),
#  ('#', 7),
#  ('+', 6),
#  (':', 4),
#  ('?', 4),
#  ('*', 3),
#  ('%', 2),
#  ('[', 1),
#  ('\\', 1),
#  ('~', 1),
#  (']', 1)]

# %%
df['ascii_name_fix'] = df.ascii_name.str.replace('`',"'")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('~'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace(']'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('['," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('\\'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('%'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('*'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace(':'," ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('+'," and ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('&'," and ")
df['ascii_name_fix'] = df.ascii_name_fix.str.replace('/'," ")
suss_chars = ['`',']','%','&']
df[df.ascii_name_fix.str.contains('|'.join(suss_chars))]
# Out:
# Empty DataFrame
# Columns: [text, label, label2, label3, ascii_name, ascii_name_fix]
# Index: []

# %%
df = df.drop(columns=['text', 'ascii_name'])

# %%
df
# Out:
#               label       label2 label3  \
# 0           Chicken        Pizza  Halal
# 1             Pizza       Salads   None
# 3            Indian  Bangladeshi  Halal
# 4             Kebab      Turkish   None
# 5           Chicken    Peri Peri   None
# 6            Indian        Curry   None
# 7         Caribbean    Fast Food   None
# 8            Indian        Curry   None
# 9             Kebab       Indian  Halal
# 10            Pizza      Chicken   None
# 11            Pizza        Curry   None
# 12          Chinese         Thai   None
# 13           Indian        Curry   None
# 14        Caribbean     Jamaican   None
# 15           Indian        Curry   None
# 16           Indian      Italian  Halal
# 18          Italian        Pasta   None
# 19           Indian        Curry  Halal
# 20           Indian        Pizza  Halal
# 21          Burgers      Chicken   None
# 22           Indian   Vegetarian  Halal
# 23            Pizza    Ice Cream   None
# 24     Fish & Chips      English   None
# 25           Indian        Curry  Halal
# 28            Pizza        Kebab   None
# 29            Kebab        Pizza   None
# 30            Pizza        Kebab   None
# 32            Pizza      Chicken  Halal
# 33         Desserts    Ice Cream   None
# 34     Fish & Chips        Kebab   None
# ...             ...          ...    ...
# 33178        Indian        Curry   None
# 33179       Burgers        Pizza   None
# 33180       Chicken      British   None
# 33181         Kebab        Pizza  Halal
# 33182       Italian        Pizza  Halal
# 33183        Indian        Curry  Halal
# 33184       Burgers    Breakfast   None
# 33185       Chicken    Peri Peri   None
# 33186         Pizza      Italian   None
# 33187         Sushi     Japanese   None
# 33188         Pizza       Indian   None
# 33189         Pizza     American   None
# 33190       Burgers      Chicken  Halal
# 33191     Caribbean    Breakfast   None
# 33192  Fish & Chips        Kebab  Halal
# 33193         Steak        Grill   None
# 33194         Pizza    Fast Food   None
# 33195        Indian        Curry   None
# 33196         Pizza    Fast Food   None
# 33197        Indian        Curry   None
# 33198   Bangladeshi       Indian  Halal
# 33199       Mexican      Burgers   None
# 33201       Italian        Pizza   None
# 33202      American      Burgers   None
# 33203      Desserts    Ice Cream   None
# 33204        Indian        Curry  Halal
# 33205         Pizza        Kebab   None
# 33206        Indian        Curry   None
# 33208     Breakfast     Oriental   None
# 33209  Fish & Chips      British   None
#
#                                     ascii_name_fix
# 0               southern fried chicken  and  pizza
# 1                  pizza hut delivery - cambuslang
# 3                                 the curry garden
# 4                                  j  and  d kebab
# 5                                 pepe's piri piri
# 6                          maharani indian cuisine
# 7                                    sweet jamrock
# 8                                          zaafran
# 9                                     omar sharifs
# 10                                      pizza home
# 11                                        al badar
# 12                  royal plaza chinese restaurant
# 13                            arifa tandoori house
# 14                            turtle bay - croydon
# 15                                 massala express
# 16                                        munchees
# 18                    bella italia - east kilbride
# 19                                          ashoka
# 20                              charghas fast food
# 21                                     the grill-o
# 22                            stoneleigh brasserie
# 23                  asda kitchen - gillingham pier
# 24                       harry ramsden - playhouse
# 25                               manha spice house
# 28                                 roberto's pizza
# 29                               yalpa kebab house
# 30                                 tartan tandoori
# 32                                     chicken.com
# 33                                 icestone gelato
# 34                                          pop in
# ...                                            ...
# 33178                                   okra green
# 33179                               istanbul kebab
# 33180                                    graze inn
# 33181                super kebab  and  pizza house
# 33182                                prestos pizza
# 33183                                 fusion spice
# 33184          runnymede catering @ the crouch oak
# 33185                            nando's - paisley
# 33186                                 little milan
# 33187                                  sushi stars
# 33188                                  spice grill
# 33189                    pizza hut delivery eltham
# 33190                                   aj's grill
# 33191                    variety diner southampton
# 33192                     bluewater fish and chips
# 33193                   abm palace - grill sisters
# 33194                                   pizza-nite
# 33195  red rose indian takeaway @ the old ship inn
# 33196                                   papa pizza
# 33197                                  curry mount
# 33198                          gatley tikka masala
# 33199                         dos amigos sombreros
# 33201                                       luckys
# 33202         frankie  and  benny's - peterborough
# 33203                             finesse desserts
# 33204                   indigo - indian food to go
# 33205                              alis kebab shop
# 33206                                cardamom club
# 33208                                 tasty smiles
# 33209                          trafalgar fisheries
#
# [31035 rows x 4 columns]

# %% [markdown]
# ## Get rid of some key chains
# we just take their most common tag in each column

# %%
hard_coded_chains = ["asda kitchen", "basilico", "bella italia", "birdbox", "blazing bird", "burger king", "caspian pizza", "chicken cottage", "chiquito", "firezza", "frankie & benny's", "gbk", "greggs", "harvester", "itsu", "kfc", "kick ass", "las iguanas", "papa john", "pizza hut", "stack & grill", "stacks", "subway", "tim horton", "toby carvery", "tortilla -", "turtle bay", "wimpy", "yo!"]
for chain in hard_coded_chains:
    to_drop = df[df.ascii_name_fix.str.contains(chain, regex= True, na=False)]
    df = df[~df.ascii_name_fix.isin(to_drop.ascii_name_fix.tolist())]
    to_append = {'ascii_name_fix' : chain, 'trim':chain, 'trim2':chain}
    labels = ['label','label2','label3']
    for l in labels:
        mode_l = to_drop[l].mode()
        if len(mode_l) > 0:
            to_append[l] = mode_l[0]
        else:
            #to_append[l] = np.nan
            to_append[l] = 'None'
    df = df.append(to_append, ignore_index=True)
    
# warning because of brackets in gbk

# %%
df['trim'] = df['ascii_name_fix'].str.split(r' - ').str.get(0)
df['trim2'] = df['ascii_name_fix'].str.split(" \(").str.get(0)

# %%
# name_classes1 = df.groupby(df.trim).size().reset_index(name='count')
# name_classes2 = df.groupby(df.trim2).size().reset_index(name='count')

# %%
sus_chains = df[(df['trim']!=df['ascii_name_fix'])|(df['trim2']!=df['ascii_name_fix'])]
print([sus_chains[col].str.len().min() for col in ['trim','trim2']])
# Out:
# [2, 3]

# %%
sus_chains = df[(df['trim']!=df['ascii_name_fix'])]['trim'].to_list()
sus_chains2 = df[(df['trim2']!=df['ascii_name_fix'])]['trim2'].to_list()
sus_chains_list = sus_chains + sus_chains2
len(sus_chains)
# Out:
# 834

# %%
my_count = Counter(sus_chains_list)
counts = pd.DataFrame(my_count.most_common(), columns=['ascii_name_fix', 'count'])

# %%
counts[counts['count']>1]
# Out:
#                       ascii_name_fix  count
# 0              frankie  and  benny's     79
# 1                      harry ramsden     41
# 2        favorite chicken  and  ribs     34
# 3                 roosters piri piri     31
# 4                  the ice cream hub     28
# 5                           wenzel's     27
# 6                          cluxxx it     24
# 7    stack  and  grill by cafe rouge     22
# 8                        pieminister     20
# 9                       dixy chicken     20
# 10                           kaspa's     19
# 11                            creams     19
# 12                        big john's     15
# 13               chopstix noodle bar     14
# 14                    coast to coast     12
# 15               little dessert shop     10
# 16                      wok  and  go     10
# 17                        tops pizza     10
# 18                  pepe's piri piri      9
# 19                           nando's      9
# 20                     king of wings      8
# 21       miss millie's fried chicken      7
# 22                          wrapchic      7
# 23                       tikka twins      7
# 24                           giraffe      7
# 25                    chop  and  wok      7
# 26                   cornstar taco's      6
# 27                    oodles chinese      6
# 28                     auntie anne's      5
# 29                  sprinkles gelato      5
# ..                               ...    ...
# 89                          chesters      2
# 90                        pizza gogo      2
# 91                 mooboo bubble tea      2
# 92                        feng sushi      2
# 93                            dragon      2
# 94                            treatz      2
# 95                           wingo's      2
# 96                  kaspa's desserts      2
# 97                      dessert rush      2
# 98                    wayne's coffee      2
# 99                        chilli hut      2
# 100                      the emperor      2
# 101       chunky chicken  and  pizza      2
# 102                flavours by kumar      2
# 103     roosters piri piri - reading      2
# 104                          regency      2
# 105                        chaiiwala      2
# 106         dixy chicken  and  pizza      2
# 107             steakhouse leicester      2
# 108                   taste of china      2
# 109                     xpress pizza      2
# 110                    asia tandoori      2
# 111                      chai street      2
# 112                     bombay bites      2
# 113         billy's fish  and  chips      2
# 114       sea birds fish  and  chips      2
# 115             peppers city takeout      2
# 116                   golden phoenix      2
# 117                   cathay cuisine      2
# 118                 chunky chick-inn      2
#
# [119 rows x 2 columns]

# %%
# leave at 10 to catch chains not duplicates - need to review by eye
# chain_dupe1 = name_classes1.loc[name_classes1['count']> 10,['trim']].trim.to_list()
# chain_dupe2 = name_classes2.loc[name_classes2['count']> 10,['trim2']].trim2.to_list()
# to_trim_down = list(set().union(chain_dupe1,chain_dupe2))
to_trim_down = counts.loc[counts['count']> 1,['ascii_name_fix']].ascii_name_fix.to_list()

# %%
to_trim_down
# Out:
# ["frankie  and  benny's",
#  'harry ramsden',
#  'favorite chicken  and  ribs',
#  'roosters piri piri',
#  'the ice cream hub',
#  "wenzel's",
#  'cluxxx it',
#  'stack  and  grill by cafe rouge',
#  'pieminister',
#  'dixy chicken',
#  "kaspa's",
#  'creams',
#  "big john's",
#  'chopstix noodle bar',
#  'coast to coast',
#  'little dessert shop',
#  'wok  and  go',
#  'tops pizza',
#  "pepe's piri piri",
#  "nando's",
#  'king of wings',
#  "miss millie's fried chicken",
#  'wrapchic',
#  'tikka twins',
#  'giraffe',
#  'chop  and  wok',
#  "cornstar taco's",
#  'oodles chinese',
#  "auntie anne's",
#  'sprinkles gelato',
#  'bella napoli pizzeria',
#  'marco  and  carl',
#  "drake's fish  and  chips",
#  'ultimate cafe',
#  'deep blue',
#  "ed's easy diner",
#  'burrito kitchen',
#  'zabardast',
#  'the pizza room',
#  "garfunkel's",
#  'clucks burger',
#  'the urban chocolatier',
#  'aspendos',
#  'oriental express',
#  'delightful desserts',
#  'buddies usa',
#  "joe's kitchen",
#  'cream curls',
#  'the good earth express',
#  'fast break',
#  'streetcube',
#  'mylahore',
#  'burger plus',
#  'pizza king',
#  'pizza magic',
#  'bangla lounge',
#  'stonehouse',
#  "fish'n'chick'n",
#  'firejacks',
#  'asda groceries',
#  "freddy's chicken  and  pizza",
#  'the codfather',
#  'favorite chicken',
#  'happy house',
#  'al',
#  'go pho',
#  'five lads',
#  'the coffee room',
#  "the fisherman's wife",
#  "sam's chicken",
#  'planet pizza',
#  'filling station',
#  'pizza republic',
#  'al-safa grill',
#  "toro's steakhouse",
#  'doorstep desserts',
#  'out fry',
#  'the pizza company',
#  "chop'd",
#  'taka taka',
#  "rio's piri piri",
#  'the ramen company',
#  'tasty chicken',
#  "jenny's jerk chicken",
#  'robin hood',
#  'chicago rib shack',
#  "zak's fish bar",
#  'chick chicken',
#  "valentino's",
#  'chesters',
#  'pizza gogo',
#  'mooboo bubble tea',
#  'feng sushi',
#  'dragon',
#  'treatz',
#  "wingo's",
#  "kaspa's desserts",
#  'dessert rush',
#  "wayne's coffee",
#  'chilli hut',
#  'the emperor',
#  'chunky chicken  and  pizza',
#  'flavours by kumar',
#  'roosters piri piri - reading',
#  'regency',
#  'chaiiwala',
#  'dixy chicken  and  pizza',
#  'steakhouse leicester',
#  'taste of china',
#  'xpress pizza',
#  'asia tandoori',
#  'chai street',
#  'bombay bites',
#  "billy's fish  and  chips",
#  'sea birds fish  and  chips',
#  'peppers city takeout',
#  'golden phoenix',
#  'cathay cuisine',
#  'chunky chick-inn']

# %%
# for chain in chain_dupe1:
#     to_drop = df[df['trim'] == chain]
#     df = df[df['trim'] != chain] 
#     to_append = {'text' : chain, 'trim':chain, 'trim2':chain}
#     labels = ['label','label2','label3']
#     for l in labels:
#         mode_l = to_drop[l].mode()
#         if len(mode_l) > 0:
#             to_append[l] = mode_l[0]
#         else:
#             to_append[l] = np.nan
#     df = df.append(to_append, ignore_index=True)

# %%
# for chain in chain_dupe2:
#     to_drop = df[df['trim2'] == chain]
#     df = df[df['trim2'] != chain] 
#     to_append = {'text' : chain, 'trim':chain, 'trim2':chain}
#     labels = ['label','label2','label3']
#     for l in labels:
#         mode_l = to_drop[l].mode()
#         if len(mode_l) > 0:
#             to_append[l] = mode_l[0]
#         else:
#             to_append[l] = np.nan
#     df = df.append(to_append, ignore_index=True)

# %%
for chain in to_trim_down:
    to_drop = df[df.ascii_name_fix.str.contains(chain, regex= True, na=False)]
    df = df[~df.ascii_name_fix.isin(to_drop.ascii_name_fix.tolist())]
    to_append = {'ascii_name_fix' : chain, 'trim':chain, 'trim2':chain}
    labels = ['label','label2','label3']
    for l in labels:
        mode_l = to_drop[l].mode()
        if len(mode_l) > 0:
            to_append[l] = mode_l[0]
        else:
            to_append[l] = 'None'
    df = df.append(to_append, ignore_index=True)
    
# warning because of brackets in gbk

# %%
df = df.drop(columns=['trim', 'trim2', 'label3'])

# %%
df[df.ascii_name_fix.str.contains("ibrahim", regex= True, na=False)]
# Out:
#         label    label2        ascii_name_fix
# 634      Café  Desserts              ibrahims
# 14618  Indian     Kebab  ibrahim's tasty bite

# %% [markdown]
# ## Check for duplicates

# %% [markdown]
# These are remaining duplicates with different classes

# %%
name_classes = df.\
  groupby('ascii_name_fix').size().reset_index(name='counts')

# %% [markdown]
# Use similar logic to removing chains to take the most popular labels

# %%
to_dedupe = name_classes[name_classes['counts'] > 1]['ascii_name_fix'].to_list()

# %%
to_dedupe
# Out:
# ['1st class pizza',
#  '2-4-1 pizza',
#  '241 pizza',
#  '3 for 10 pizza',
#  '500 degrees pizzeria',
#  '7 spices',
#  'a mano',
#  'a taste of india',
#  'a touch of spice',
#  "a'la pizza  and  grill",
#  'abbey fish bar',
#  'abduls',
#  'aburi japanese restaurant',
#  'acropolis',
#  "adam's pizza",
#  "adam's pizzeria",
#  'adams',
#  'afc',
#  'agra',
#  'akash',
#  'akash restaurant',
#  'akash tandoori',
#  'akash tandoori restaurant',
#  'amaretto ristorante pizzeria',
#  'american fried chicken',
#  'american grill peri peri',
#  'american pizza',
#  'american pizza house',
#  'american slice',
#  'amigo',
#  'amigo pizza',
#  "amigo's",
#  "amigo's pizza",
#  'amigos',
#  'amigos pizza',
#  'amore pizza',
#  'amran tandoori',
#  "angelo's fish bar",
#  'anglo pizza',
#  'anise',
#  'antep pizza',
#  'antonios pizza',
#  'apna lahore',
#  'ariana restaurant',
#  'aroma',
#  'aroma indian takeaway',
#  'aroma kitchen',
#  'aroma pizza',
#  'aroma spice',
#  'asha',
#  'ashiana',
#  'ashoka',
#  'asia villa',
#  'asian tandoori',
#  'asiana',
#  'athena',
#  'atlantic fish bar',
#  'atlantis fish bar',
#  'authentic chinese',
#  'av-a-pizza',
#  'avon spice',
#  'aya lebanese cuisine',
#  'baan thai',
#  'baburchi',
#  'babylon',
#  'babylon grill',
#  'bad boy burgers',
#  'bagel bite',
#  'baguette express',
#  'bake station',
#  'bamboo chinese takeaway',
#  'bamboo garden',
#  'banana leaf',
#  'band of burgers',
#  'bangla kitchen',
#  'bangla spice',
#  'bar-b-q house',
#  'barakah',
#  'barbican pizza',
#  "barney's diner",
#  "barni's",
#  'basement browns',
#  'baskin robbins',
#  'bawarchi',
#  'bay leaf',
#  'bayleaf',
#  'bayleaf indian takeaway',
#  'bbq express',
#  'bbq hut',
#  'beef belly grill house',
#  'beijing chef',
#  'beijing chinese restaurant',
#  'beijing city',
#  'beijing express',
#  'beijing house',
#  'beijing noodles',
#  'beirut',
#  'beirut lounge',
#  'bekash tandoori',
#  'belash tandoori',
#  'bella house',
#  'bella napoli',
#  'bella pizza',
#  'bellissimo',
#  'belly busters',
#  'belmont tandoori',
#  "bene's fish  and  chips",
#  'bento',
#  'berries bagels  and  shakes',
#  'best fish  and  chips',
#  'best grill',
#  'best in town',
#  'best kebab',
#  'best kebab  and  pizza',
#  'best kebab  and  pizza house',
#  'best kebab and pizza',
#  'best kebab fish  and  chips',
#  'best kebab house',
#  'best kebabs',
#  'best pizza',
#  'best pizza  and  kebab',
#  'best pizza express',
#  'bfc',
#  'bhaji',
#  "bhaji's",
#  'big bite',
#  'big bites',
#  'big brother',
#  'big chef',
#  'big fat gourmet',
#  'big fish',
#  "big mama's",
#  "big papa's",
#  'big portion',
#  "big singh's pizza",
#  'bikash tandoori',
#  'biryani express',
#  'bite',
#  'black lab',
#  'blacks burgers',
#  'blaze',
#  'blue ginger',
#  'blue india',
#  'blue lagoon',
#  'blue lagoon fish  and  chips',
#  'blue ocean',
#  'blue orchid',
#  'blue spice',
#  'blue star',
#  "bobby's",
#  'bodrum',
#  'bodrum express',
#  'bodrum grill',
#  'bodrum kebab',
#  'bodrum kebab  and  pizza',
#  'bodrum kebab house',
#  'bodrum pizza  and  kebab',
#  'bodrum pizza  and  kebab house',
#  'bollywood',
#  'bollywood lounge',
#  'bollywood spice',
#  'bombay',
#  'bombay bicycle chef',
#  'bombay blues',
#  'bombay brasserie',
#  'bombay cuisine',
#  'bombay express',
#  'bombay grill',
#  'bombay indian takeaway',
#  'bombay kitchen',
#  'bombay lounge',
#  'bombay mix',
#  'bombay nights',
#  'bombay spice',
#  'bombay spices',
#  'bon appetit',
#  'bosphorus',
#  'boston pizza',
#  'bravo pizza',
#  "bravo's",
#  'brendas pizzeria',
#  'bristol kebab house',
#  'britannia fish bar',
#  'britannia spice',
#  'british raj',
#  'british raj express',
#  'broadway chippy',
#  'brooklyn pizza',
#  'brothers kebab  and  burgers',
#  'brunch',
#  'brunch cafe',
#  'bulls burgers',
#  'bun  and  bar',
#  'buns',
#  'buns  and  bao',
#  'buon appetito',
#  'burger  and  bun',
#  'burger 7',
#  'burger bang',
#  'burger base',
#  'burger revolution',
#  'burgitzza',
#  'burrito  and  tequila',
#  'burrito n shake',
#  'buttylicious',
#  'buzz bar shakes  and  desserts',
#  "caesar's",
#  'caesars',
#  'cafe 55',
#  'cafe express',
#  'cafe india',
#  'cafe istanbul',
#  'cafe on the corner',
#  'cafe rose',
#  'cafe spice',
#  'caffe rapido',
#  'cake  and  shakes indulgence',
#  'cakes  and  shakes',
#  'camel one',
#  'canada grill',
#  'candy crush',
#  'cannons fish and chips',
#  'canton',
#  'canton chef',
#  'canton chef chinese takeaway',
#  'canton chinese takeaway',
#  'cappadocia',
#  'caprinos',
#  'caprinos pizza',
#  'cardamom',
#  'cardamon',
#  'carlitos pizza',
#  'carlos pizza',
#  'carolina pizza',
#  'casa mia',
#  'casa pizza',
#  'casa rica',
#  'casablanca',
#  'caspian',
#  'castle kebab house',
#  'castle pizza',
#  'catch fish  and  chips',
#  'celebz',
#  "cha cha's",
#  "chan's",
#  'chanda cottage',
#  'char grill',
#  'chargrill',
#  "charlie's chicken",
#  'chatime',
#  'chatkhara',
#  'cheeky chicken',
#  "chef's pizza",
#  'chennai dosa',
#  "chester's grill",
#  'cheung wing',
#  'chicago pizza',
#  "chicago's",
#  "chicago's pizza",
#  'chicagos',
#  'chick inn',
#  'chick king',
#  'chick-o-land',
#  'chicken  and  blues',
#  'chicken  and  pizza point',
#  'chicken city',
#  'chicken club',
#  'chicken corner',
#  'chicken express',
#  'chicken house',
#  'chicken hut',
#  'chicken king',
#  'chicken shack',
#  'chicken spot',
#  'chicken stop',
#  'chicken village',
#  'chicken world',
#  'chicken world peri peri',
#  'chicken.com',
#  'chicking',
#  'chicks chicken  and  pizza',
#  'chicky peri peri',
#  'chilli',
#  'chilli chicks',
#  'chilli express',
#  'chilli flames',
#  'chilli jacks',
#  'chilli lounge',
#  'chilli padi',
#  'chilli pepper',
#  'chilli peppers',
#  'chilli pickle',
#  'chilli spice',
#  'chilli tonight',
#  "chilli's",
#  'chillies',
#  'chillies indian takeaway',
#  'chillies takeaway',
#  'chillies tandoori',
#  'chillis',
#  'china chef',
#  'china china',
#  'china city',
#  'china cottage',
#  'china cuisine',
#  'china delight',
#  'china diner',
#  'china express',
#  'china flavour',
#  'china garden',
#  'china house',
#  'china inn',
#  'china kitchen',
#  'china panda',
#  'china red',
#  'china rose',
#  'china spice',
#  'china star',
#  'china town',
#  'china village',
#  'china wok',
#  'chinatown',
#  'chinese chef',
#  'chinese express',
#  'chinese garden',
#  'chinese kitchen',
#  'chinos',
#  'chip stop',
#  'chop suey house',
#  'chopstick house',
#  'chopsticks',
#  'chopstix',
#  "chow's chinese",
#  'chunky chicken',
#  'chunkys',
#  'chutney',
#  'chutney blue',
#  'chutney express',
#  'chutney tandoori',
#  "chutney's",
#  'chutneys',
#  'ciao bella',
#  'cibo',
#  'cinnamon',
#  'cinnamon indian',
#  'cinnamon indian takeaway',
#  'cinnamon lounge',
#  'cinnamon spice',
#  'cinnamon tree',
#  'city grill',
#  'city kebab house',
#  'city pizza',
#  'city spice',
#  'classic fish bar  and  kebab house',
#  'classic pizza',
#  'clay oven',
#  'clay oven tandoori',
#  'clove',
#  'codfather',
#  'cookies  and  cream',
#  'coriander',
#  'corner plaice',
#  'crave 4 desserts',
#  'cravings',
#  'crispy bites',
#  'crispy cod',
#  'crown cafe',
#  'crunch munch',
#  'crunchy chicken',
#  'crust pizza',
#  'cube desserts',
#  'cummin up',
#  'curry 2 night',
#  'curry chef',
#  'curry club',
#  'curry corner',
#  'curry cottage',
#  'curry counter',
#  'curry delight',
#  'curry express',
#  'curry flame',
#  'curry garden',
#  'curry house',
#  'curry hut',
#  'curry in a hurry',
#  'curry inn',
#  'curry junction',
#  'curry king',
#  'curry leaf',
#  'curry leaves',
#  'curry lounge',
#  'curry master',
#  'curry night',
#  'curry nights',
#  'curry pot',
#  'curry queen',
#  'curry station',
#  'curry time',
#  'curry zone',
#  'cyprus garden',
#  'cyprus kebab',
#  'da vinci',
#  'daawat',
#  'dario pizzeria',
#  'darios',
#  'dawat',
#  "de niro's",
#  'de niros',
#  'de roma',
#  'delhi darbar',
#  'delhi lounge',
#  'delhi spice',
#  'deli chez',
#  'deli-licious',
#  'delice peri peri',
#  'delicious',
#  'delicious chinese takeaway',
#  'delicious house',
#  'delicious pizza',
#  'delight',
#  'delightz',
#  'deluxe pizza',
#  'deniz kebab',
#  'deshi spice',
#  'desi cafe',
#  'desi indian dining club',
#  'desi spice',
#  'dessert corner',
#  'dessert express',
#  'dessert island',
#  'dessert king',
#  'dessert shack',
#  'dfc',
#  'dfc chicken',
#  'diamond kebab  and  pizza',
#  'diamond pizza',
#  'diamond pizza  and  kebab',
#  'diba restaurant',
#  'dil raj',
#  'dil se',
#  'dil tandoori',
#  'dilan kebab house',
#  'dilli haat',
#  'dilraj',
#  'dilshad',
#  'dine at home',
#  'dine india',
#  'dinner box',
#  "dino's",
#  "dino's pizzeria",
#  "dino's takeaway",
#  'dinos',
#  'dirty bones',
#  'dirty burgerz',
#  'dixi chicken  and  pizza',
#  'dixy pizza',
#  'dixyland chicken  and  ribs',
#  'dolce  and  gelato',
#  'dolphin fish bar',
#  'dominic pizza',
#  'dominics',
#  'dominics pizza',
#  'don mario',
#  "don vito's",
#  'donburi  and  co',
#  'doner  and  gyros',
#  "donnelli's pizzeria",
#  'donner 24',
#  'dope burger',
#  'double luck chinese',
#  'dough and co woodfired pizza',
#  'dough-wood fired pizza',
#  'downtown pizza',
#  'dynasty',
#  'east meets west',
#  'east ocean',
#  'eastern delight',
#  'eastern delights',
#  'eastern eye',
#  'eastern paradise',
#  'eastern promise',
#  'eastern spice',
#  'eastern star',
#  'eastzeast',
#  'eat well',
#  'eatza pizza',
#  'efes grill',
#  'efes kebab  and  pizza house',
#  'elachi',
#  'emparo pizza',
#  'empire tandoori',
#  'empress of india',
#  'ephesus',
#  'ephesus restaurant',
#  'espresso pizza',
#  'essex grill',
#  'euro cafe',
#  'everest indian takeaway',
#  'everest inn',
#  'everest kitchen',
#  'everest noodle house',
#  'everest spice',
#  'everest tandoori',
#  'evergreen',
#  'express kebab',
#  'express kebab house',
#  'expresso pizza',
#  'family kebab',
#  'family kebab  and  pizza',
#  'family kebab house',
#  'famous chef',
#  'famous pizza',
#  'fancy pizza',
#  'far east',
#  'far east chinese takeaway',
#  'farm house pizza',
#  'farm pizza',
#  'farmhouse pizza',
#  'fast one pizza',
#  'fat boys',
#  "fat joe's",
#  "fat toni's",
#  'fattoush',
#  'favourite grill',
#  'favourite pizza',
#  'fellas takeaway',
#  'fernandez grillhouse',
#  'figaro pizza',
#  'finesse desserts',
#  'fireaway',
#  'fireaway designer pizza',
#  'firecracker',
#  'firehouse grill',
#  'fish inn',
#  'five star fish bar',
#  'flame',
#  'flame  and  grill',
#  'flame grill',
#  'flame grill house',
#  'flames',
#  'flames grill',
#  'flames kebab',
#  'flames kebab house',
#  'flames pizza  and  grill',
#  'flamez',
#  "flamin'go",
#  'flava',
#  'flavaz',
#  'flavours',
#  'flavours of india',
#  'flavourz',
#  'food station',
#  'food stop',
#  'foodisan',
#  'forest tandoori',
#  'forno pizza',
#  'fortune cat',
#  'fortune cookie',
#  'fortune garden',
#  'fortune house',
#  'fortune inn',
#  'four in one',
#  'four pound shop',
#  'four seasons',
#  "francesco's",
#  'frangos peri peri',
#  "frankie's burgers",
#  'frankies',
#  'frankies chicken  and  pizza',
#  'frankies chicken  and  pizza bar',
#  'franks',
#  'freaky shakes',
#  "freddy's",
#  "freddy's chicken and pizza",
#  'freddys chicken  and  pizza',
#  'fresco',
#  'fresh fry',
#  'friends',
#  'frozen moments',
#  'fry chicks',
#  'fry inn',
#  'frydays',
#  'frydays fish bar',
#  'fryers delight',
#  'fu house',
#  'fu lam',
#  'fu wing',
#  'full house',
#  'furama',
#  'fusion',
#  'fusion cuisine',
#  'fusion foods',
#  'fusion grill',
#  'fusion spice',
#  'gah shing',
#  'gandhi',
#  'gandhi tandoori',
#  'ganges',
#  'garden house',
#  'gate of india',
#  'gelato passion',
#  "george's fish bar",
#  'get stuffed',
#  "gg's caribbean takeaway",
#  "gianni's",
#  'gills fish  and  chips',
#  'gills fry fry',
#  'gills golden takeaway',
#  "gino's",
#  "gino's fish  and  chip shop",
#  "gio's",
#  'go peri',
#  'goa indian restaurant',
#  'godfather',
#  'godfather pizza',
#  "godfather's pizza house",
#  'golden bamboo',
#  'golden bowl',
#  'golden bridge',
#  'golden castle',
#  'golden chef',
#  'golden chicken',
#  'golden chippy',
#  'golden city',
#  'golden crown',
#  'golden curry',
#  'golden delight',
#  'golden eagle',
#  'golden fish',
#  'golden fish inn',
#  'golden fry',
#  'golden garden',
#  'golden grill',
#  'golden hill',
#  'golden horse',
#  'golden house',
#  'golden kebab house',
#  'golden kitchen',
#  'golden lion chinese',
#  'golden orient',
#  'golden pizza',
#  'golden plaice',
#  'golden rice',
#  'golden rice bowl',
#  'golden sea',
#  'golden spice',
#  'golden star',
#  'golden tandoori',
#  'golden wok',
#  'good burger',
#  'good chef',
#  'good choice',
#  'good food',
#  'good friend',
#  'good luck',
#  'good pizza',
#  'good taste',
#  'goodfellas pizza',
#  'gourmet grill',
#  'gourmet house',
#  'gourmet kitchen',
#  'grameen spice',
#  'grange fish bar',
#  'green chilli',
#  'green chillies',
#  'grill',
#  'grill  and  chill',
#  "grill 'n' chill",
#  'grill box',
#  'grill cottage',
#  'grill guru',
#  'grill house',
#  'grill it',
#  'grill on the hill',
#  'grill town',
#  'grillaz',
#  'griller',
#  'grillish',
#  "grillo's peri peri",
#  "grillo's pizza",
#  'grillz',
#  'gulshan',
#  'gulshan tandoori',
#  'gurkha chef',
#  'gurkha express',
#  'gurkha junction',
#  'gurkha oven',
#  'gurkha spice',
#  'gurkha square',
#  "gurkha's inn",
#  'ha noi pho',
#  'hai loi tang',
#  'hamzas',
#  'hana sushi',
#  'happy chef',
#  'happy chinese takeaway',
#  'happy days',
#  'happy family',
#  'happy garden',
#  'happy home',
#  'happy inn',
#  'happy kitchen',
#  'happy meeting',
#  'happy seasons',
#  'happy wok',
#  'harlequin',
#  'harlequins',
#  "harry's",
#  "harry's chicken  and  pizza",
#  "hennie penny's chicken",
#  'herbies pizza',
#  'herbs  and  spice',
#  'herbs  and  spices',
#  'hfc',
#  'ho ho',
#  'hollywood pizza',
#  'hollywood pizza  and  chicken',
#  'holy cow',
#  'home taste',
#  'hong kong',
#  'hong kong chef',
#  'hong kong express',
#  'hong kong garden',
#  'hong kong house',
#  'hong kong kitchen',
#  'hong kong takeaway',
#  'honi poke',
#  'hoo wah',
#  'hooked fish  and  grill',
#  'hot  and  spicy',
#  'hot kebab',
#  'hot pizza',
#  'hot rocks',
#  'hot rod burger',
#  'hot spot',
#  'hot stuff',
#  'hot stuff pizza',
#  'hot wok',
#  'house of peri peri',
#  'house of spice',
#  'huckleberry chicken',
#  'hungry herb',
#  'hungry hut',
#  "hungry jack's",
#  'hungry shack',
#  'i am doner',
#  'i grill',
#  'icco pizza',
#  'ice pan',
#  'ice scoop gelato',
#  'ice stone gelato',
#  'icestone gelato',
#  'ichiban',
#  'iglu desserts',
#  'il gusto',
#  'il padrino',
#  'imaan restaurant',
#  'imli',
#  'india garden',
#  'india village',
#  'indian chef',
#  'indian cottage',
#  'indian delight',
#  'indian express',
#  'indian fusion',
#  'indian garden',
#  'indian grill',
#  'indian kitchen',
#  'indian kitchen takeaway',
#  'indian lounge',
#  'indian nights',
#  'indian ocean',
#  'indian spice',
#  'indian summer',
#  'indian village',
#  'indiana',
#  'indiano pizza',
#  'indigo',
#  'indulge',
#  'indus indian takeaway',
#  'iro sushi',
#  'iso sushi wok  and  grill',
#  'istanbul',
#  'istanbul chef',
#  'istanbul grill',
#  'istanbul kebab',
#  'istanbul kebab  and  pizza house',
#  'istanbul kebab house',
#  'istanbul pizza',
#  'istanbul pizza house',
#  'istanbul restaurant',
#  'istanbul takeaway',
#  "it's pizza time",
#  'jade',
#  'jade garden',
#  'jade house',
#  'jaflong',
#  'jaflong tandoori',
#  'jaipur',
#  'jaipur indian cuisine',
#  'jakes',
#  'jamuna',
#  'jasmine',
#  'jasmine garden',
#  'jasmine house',
#  "jaz's fish bar",
#  'jeera',
#  'jeera indian restaurant  and  takeaway',
#  "jenny's cafe  and  restaurant",
#  'jfc',
#  "jimmy's",
#  "jj's",
#  "jj's desi kitchen",
#  "joe's fish bar",
#  "jojo's chicken",
#  'jrk kitchen',
#  'jubo raj',
#  'jumbo',
#  'jumbo house',
#  'jungle grill',
#  'just pizza',
#  'just pizza uk.com',
#  'just wings',
#  'k.o kebabish',
#  'k2 taj chippery',
#  "kami's peri peri",
#  'kamran tandoori',
#  'kapadokya fish  and  chips',
#  'karachi tandoori',
#  'karma',
#  'kashmir cottage',
#  'kashmir restaurant',
#  'kashmir tandoori',
#  'kasturi',
#  'kaya',
#  'kebab centre',
#  'kebab city',
#  'kebab delight',
#  'kebab express',
#  'kebab house',
#  'kebab hut',
#  'kebab king',
#  'kebab land',
#  'kebab master',
#  'kebab plus',
#  'kebab rush',
#  'kebab world',
#  'kebab ye',
#  'kebabish',
#  'kebabish peri peri',
#  'kebabish tandoori',
#  'kebabs r us',
#  'kemp thai',
#  "ken's",
#  "ken's fried chicken",
#  "ken's kebab house",
#  "ken's kebab house  and  speedy pizza",
#  'kennington tandoori',
#  'kens fried chicken',
#  'kervan saray',
#  "khan's",
#  'khans',
#  'khushboo',
#  'khyber',
#  'khyber pass',
#  'kilikya',
#  'kimchi',
#  'king chef',
#  'king cod',
#  'king grill',
#  'king karahi',
#  'king kebab',
#  'king kebab house',
#  'king of the grill',
#  'king pizza',
#  'king pizza  and  kebab',
#  'king rooster',
#  "king's garden",
#  "king's kitchen",
#  'kings',
#  'kings fried chicken',
#  'kings kebab',
#  'kings kebab  and  pizza',
#  'kings pizza',
#  'kings takeaway',
#  'kingston kebab centre',
#  'kiplings restaurant',
#  'kismat',
#  'kismat tandoori',
#  'kismet',
#  'kismet tandoori',
#  'kome',
#  'krazy chef',
#  'krazy pizza',
#  'krispy fried chicken',
#  'krunchy fried chicken',
#  'kurk grilled chicken',
#  'kurry hut',
#  'kushi',
#  'la dolce vita',
#  'la friends pizzeria',
#  'la luna',
#  'la parma pizzeria',
#  'la pizza',
#  'la pizzaria',
#  'la pizzeria',
#  'la spezia pizzeria',
#  'la unica',
#  'la vera',
#  'la vera pizza',
#  'lahore restaurant',
#  'lahori chaska',
#  'lahori tawa',
#  'laughing buddha',
#  'lazeez',
#  'lazio pizza',
#  'le raj',
#  'lebanese grill',
#  'lee garden',
#  "lee's chinese takeaway",
#  "lee's kitchen",
#  'legends',
#  'lemon tree',
#  "leo's fish bar",
#  "leo's grill",
#  "let's eat",
#  'lets munch',
#  'levant',
#  'lfc',
#  'light of india',
#  'lime pickle',
#  'lime tree',
#  "lisa's cafe",
#  'little china',
#  'little india',
#  'loaded gourmet burgers  and  fries',
#  'london kebab house',
#  'loon hing',
#  'lotus',
#  'lotus blossom',
#  'lotus chinese takeaway',
#  'lotus garden',
#  'lotus house',
#  'lounge india',
#  'love curry',
#  'love peri peri',
#  'lovely house',
#  'luciano pizzeria',
#  'lucky chen',
#  'lucky chopsticks',
#  'lucky garden',
#  'lucky house',
#  'lucky inn',
#  'lucky star',
#  'lucky star chinese takeaway',
#  'luckys',
#  "luigi's",
#  "luigi's pizza",
#  'm and m kebab  and  pizza',
#  "mac 'n' cheese",
#  'macdonners',
#  "madihah's",
#  'madina grill',
#  'madras',
#  'madras cottage',
#  'magic grill',
#  'magic wok',
#  'maharaja',
#  'maharani',
#  'mahi tandoori',
#  "mahmood's",
#  "mak's",
#  'mama mia',
#  'mama pizza',
#  "mama's food xpress",
#  "mama's grill",
#  "mama's kitchen",
#  "mama's pizza",
#  'mamma mia',
#  'mamma mia pizza',
#  "mamma's",
#  "mamma's pizza",
#  'mamos',
#  'man lee',
#  'man v food',
#  'mandarin chef',
#  'mandarin chinese takeaway',
#  'mandarin garden',
#  'mango tree',
#  'manhattan',
#  'manjaros',
#  'manjaros desserts',
#  'mantra',
#  'manzil',
#  'manzil tandoori',
#  'marco polo',
#  "marco's",
#  "marco's pizza",
#  'marhaba',
#  'mariners fish  and  chips',
#  ...]

# %%
for chain in to_dedupe:
    to_drop = df[df['ascii_name_fix'] == chain]
    df = df[df['ascii_name_fix'] != chain]
    to_append = {'ascii_name_fix' : chain}
    labels = ['label','label2']
    for l in labels:
        mode_l = to_drop[l].mode()
        if len(mode_l) > 0:
            to_append[l] = mode_l[0]
        else:
            to_append[l] = None
    df = df.append(to_append, ignore_index=True)

# %%
df[['label','label2']] = df[['label','label2']].astype(str)

# %% [markdown]
# check for duplicate name label combinations

# %%
counts = df.assign(n=1).groupby(['ascii_name_fix', 'label', 'label2']).count().sort_values('n', ascending=False)
counts.tail(n=20)
# Out:
#                                                                   n
# ascii_name_fix                        label        label2
# grill'ish                             Grill        Chicken        1
# grillicious mediterranean             Italian      Pizza          1
# grilliciouse                          Grill        Kebab          1
# grillish                              Grill        Chicken        1
# grillshack                            Grill        Burgers        1
# grimsby tandoori                      Indian       Curry          1
# grillzilla                            Peri Peri    Kebab          1
# grillzbase ltd                        Grill        BBQ            1
# grillz                                Grill        Chicken        1
# grillstow                             Burgers      Curry          1
# grillstop                             Burgers      Kebab          1
# grilloz fish  and  chips              Fish & Chips Kebab          1
# grillish peri peri chicken  and  ribs Peri Peri    Kebab          1
# grillout                              Burgers      Peri Peri      1
# grillo's pizza                        Italian      Italian Pizza  1
# grillo's peri peri                    Peri Peri    Chicken        1
# grillo's                              Kebab        Burgers        1
# grillo pizza                          Pizza        Italian        1
# grillishious                          Grill        Pizza          1
# zzetta soul fired pizza               Pizza        Italian        1

# %%
df.to_csv('/home/trpb2/takeaways/data/20_01_2020_just_eat_words.csv', index=False)

# %% [markdown]
# ### Distribution by Cuisine
#
# The dataset is very unbalanced.

# %%
label_count = df.groupby('label').ascii_name_fix.count().sort_values(ascending=False)

# %%
len(label_count)
# Out:
# 130

# %%
label_count[100:150]
# Out:
# label
# Pub Food          2
# Gluten Free       2
# Kurdish           2
# Frozen Yogurt     2
# Colombian         2
# Latin American    2
# Bulgarian         2
# Hungarian         2
# Argentinian       2
# Retro Sweets      2
# Baguettes         2
# Biryani           1
# Pancakes          1
# Street Food       1
# Roast Dinners     1
# Organic           1
# Peruvian          1
# Kosher            1
# West African      1
# Punjabi           1
# Iraqi             1
# Groceries         1
# South African     1
# Ghanaian          1
# German            1
# Scottish          1
# Singapore         1
# Soup              1
# Continental       1
# Salt & Pepper     1
# Name: ascii_name_fix, dtype: int64

# %%
label_count2 = df.groupby('label2').ascii_name_fix.count().sort_values(ascending=False)

# %%
len(label_count2)
# Out:
# 142

# %%
label_count2[100:150]
# Out:
# label2
# French              6
# Kurdish             6
# Hot Dogs            6
# Punjabi             6
# Pub Food            5
# Gourmet Burgers     5
# Romanian            5
# Syrian              4
# Brazilian food      4
# Alcohol             4
# Polish              4
# Soup                3
# Authentic Pizza     3
# Baguettes           2
# Egyptian            2
# North African       2
# Scottish            2
# Argentinian         2
# West African        2
# Pies                2
# Ethiopian           2
# Tex-Mex             1
# Ukrainian           1
# Belgian Waffles     1
# Best Bites          1
# Organic             1
# Taiwanese           1
# Bulgarian           1
# Subways             1
# Danish              1
# South African       1
# Sizzlers            1
# Filipino            1
# Singapore           1
# German              1
# Russian             1
# Rotisserie          1
# Retro Sweets        1
# Kosher              1
# Low-Carb            1
# Peruvian            1
# *NEW*               1
# Name: ascii_name_fix, dtype: int64

# %%
df2 = pd.DataFrame(np.sort(df[['label', 'label2']], axis=1), index=df.index)
df2.columns = ['label', 'label2']
combos = df2.groupby(['label', 'label2']).size().reset_index(name='counts')

# %%
combos
# Out:
#                label          label2  counts
# 0              *NEW*        Desserts       1
# 1             Afghan           Asian       1
# 2             Afghan             BBQ       1
# 3             Afghan           Curry       1
# 4             Afghan           Greek       1
# 5             Afghan           Grill       3
# 6             Afghan           Halal       1
# 7             Afghan          Indian       6
# 8             Afghan           Kebab       3
# 9             Afghan  Middle Eastern       3
# 10            Afghan       Pakistani       7
# 11            Afghan         Persian       4
# 12            Afghan           Pizza       1
# 13            Afghan         Turkish       1
# 14           African         African       1
# 15           African       Breakfast       2
# 16           African            Café       1
# 17           African       Caribbean      45
# 18           African         Chicken       5
# 19           African           Curry       2
# 20           African        Desserts       1
# 21           African         English       1
# 22           African       Ethiopian       2
# 23           African       Fast Food       1
# 24           African          Fusion       1
# 25           African        Ghanaian       1
# 26           African           Grill       2
# 27           African           Halal       3
# 28           African         Healthy       2
# 29           African          Indian       3
# ...              ...             ...     ...
# 1111      Sandwiches      Vietnamese       1
# 1112      Sandwiches           Wraps       2
# 1113         Seafood            Thai       4
# 1114         Seafood         Turkish       1
# 1115       Smoothies           Vegan       2
# 1116            Soup            Thai       1
# 1117  South American      Vegetarian       2
# 1118    South Indian      Sri-lankan       5
# 1119    South Indian      Vegetarian       3
# 1120         Spanish           Steak       1
# 1121         Spanish           Tapas       9
# 1122         Spanish            Thai       1
# 1123      Sri-lankan           Vegan       1
# 1124           Steak           Sushi       1
# 1125     Street Food            Thai       2
# 1126     Street Food         Turkish       1
# 1127           Sushi            Thai       1
# 1128           Sushi           Vegan       1
# 1129           Tapas            Thai       4
# 1130            Thai           Vegan       3
# 1131            Thai      Vegetarian       8
# 1132            Thai      Vietnamese       1
# 1133         Turkish         Turkish       1
# 1134         Turkish           Vegan       1
# 1135         Turkish      Vegetarian       2
# 1136         Turkish           Wraps       1
# 1137           Vegan           Vegan       1
# 1138           Vegan      Vegetarian      13
# 1139           Vegan      Vietnamese       1
# 1140      Vegetarian      Vegetarian       1
#
# [1141 rows x 3 columns]

# %%
combos.to_csv('/home/trpb2/takeaways/data/18_03_2020_combos.csv', index=False)

# %%
combos_10 = combos[combos['counts']>10]
combos[combos['label']=='Indian'],combos[combos['label2']=='Indian']
# Out:
# (      label               label2  counts
#  858  Indian               Indian      12
#  859  Indian  Indo-Chinese Fusion       6
#  860  Indian              Italian      54
#  861  Indian        Italian Pizza       2
#  862  Indian             Japanese       1
#  863  Indian                Kebab     191
#  864  Indian                Lunch       4
#  865  Indian        Mediterranean       1
#  866  Indian              Mexican       4
#  867  Indian       Middle Eastern       4
#  868  Indian           Milkshakes       3
#  869  Indian             Nepalese     105
#  870  Indian             Oriental       3
#  871  Indian            Pakistani      63
#  872  Indian                Pasta       1
#  873  Indian            Peri Peri      11
#  874  Indian                Pizza     274
#  875  Indian           Portuguese       1
#  876  Indian             Pub Food       1
#  877  Indian              Punjabi       7
#  878  Indian           Sandwiches       1
#  879  Indian              Seafood       5
#  880  Indian        South African       1
#  881  Indian         South Indian      34
#  882  Indian              Spanish       1
#  883  Indian           Sri-lankan      15
#  884  Indian                Steak       2
#  885  Indian          Street Food      12
#  886  Indian               Sweets       1
#  887  Indian                 Thai      10
#  888  Indian              Turkish       7
#  889  Indian                Vegan      16
#  890  Indian           Vegetarian      57
#  891  Indian                Wraps       2,                label  label2  counts
#  7             Afghan  Indian       6
#  29           African  Indian       3
#  68          American  Indian      28
#  113            Asian  Indian      25
#  143              BBQ  Indian       3
#  168            Balti  Indian       7
#  171      Bangladeshi  Indian     462
#  175          Biryani  Indian       7
#  210        Breakfast  Indian       4
#  258          British  Indian       5
#  322          Burgers  Indian      24
#  391            Cakes  Indian       1
#  414        Caribbean  Indian       2
#  449          Chicken  Indian      22
#  493          Chinese  Indian      45
#  516      Continental  Indian       2
#  531            Curry  Indian    2509
#  555             Deli  Indian       1
#  581         Desserts  Indian      21
#  611           Dinner  Indian       1
#  615           Drinks  Indian       4
#  641          English  Indian      28
#  666         European  Indian      10
#  685        Fast Food  Indian      17
#  708     Fish & Chips  Indian      37
#  737           Fusion  Indian       8
#  753          Gourmet  Indian       4
#  759  Gourmet Burgers  Indian       1
#  785            Grill  Indian      71
#  814            Halal  Indian      90
#  834          Healthy  Indian       7
#  858           Indian  Indian      12)

# %% [markdown]
# ## Crafting the mappings
#
# Here we generate the mappings

# %%
#remove s on burger for scannign later

dead_certain = {'Curry':'Indian', 'Bangladeshi':'Indian', 'Nepalese':'Indian', 'Pakistani':'Indian', 'South Indian':'Indian', 'Sri Lankan':'Indian',
                'Ice Cream':'Desserts', 'Cakes':'Desserts', 'Milkshakes':'Desserts', 'Crepes':'Desserts', 'Waffles':'Desserts',
                'Italian':'Pizza', 'Italian Pizza':'Pizza',
                'Noodles':'Chinese', 'Oriental':'Chinese', 'Cantonese':'Chinese', 'Dim Sum':'Chinese',
                'Persian':'Kebab',
                #'Turkish':'MedMid', 'Lebanese':'MedMid', 'Mediterranean':'MedMid', 'Greek':'MedMid', 'Middle Eastern':'MedMid', 'Persian':'MedMid', 'Afghan':'MedMid',
                #'African':'AfroCarib','Caribbean':'AfroCarib', 'Jamaican':'AfroCarib', 'Nigerian':'AfroCarib',
                'Gourmet Burgers':'Burger', 'Burgers':'Burger',
                'Café':'Sand/Caf/Bake', 'Sandwiches':'Sand/Caf/Bake', 'Wraps':'Sand/Caf/Bake', 'Bagels':'Sand/Caf/Bake', "Panini's":'Sand/Caf/Bake', "Salads":'Sand/Caf/Bake',
                'Breakfast':'Sand/Caf/Bake' #dubious
 }

key_list = ['Indian', 'Chinese', 'Fish & Chips']

yuck = ['Peri Peri', 'American', 'Breakfast', 'British', 'Grill', 'Turkish', 'Lebanese', 'English', 'African',
       'Caribbean', 'Jamaican', 'Mexican','Sushi', 'Japanese', 'Mediterranean', 'Greek', 'Persian', 'Middle Eastern',
       'Thai','Vietnamese']

# %%
df2 = df.replace({"label": dead_certain})
df3 = df2.replace({"label2": dead_certain})

# %%
df3['label_final'] = np.where((df3['label2'].isin(key_list)), df3['label2'], 'no')
df3['label_final'] = np.where((df3['label'].isin(key_list)), df3['label'], df3['label_final'])

# %%
df3
# Out:
#                label         label2                      ascii_name_fix  \
# 0            Chicken          Pizza  southern fried chicken  and  pizza
# 1              Kebab        Turkish                     j  and  d kebab
# 2             Indian         Indian             maharani indian cuisine
# 3          Caribbean      Fast Food                       sweet jamrock
# 4             Indian         Indian                             zaafran
# 5              Kebab         Indian                        omar sharifs
# 6             Indian         Indian                arifa tandoori house
# 7             Indian          Pizza                  charghas fast food
# 8             Burger        Chicken                         the grill-o
# 9             Indian     Vegetarian                stoneleigh brasserie
# 10            Indian         Indian                   manha spice house
# 11             Pizza          Kebab                     roberto's pizza
# 12      Fish & Chips          Kebab                              pop in
# 13             Pizza          Kebab                   varietys takeaway
# 14             Pizza         Fusion                            das kino
# 15             Pasta          Pizza  a mano coffee bar  and  restaurant
# 16          American          Kebab                         hot express
# 17           Turkish          Greek                the bosphorus bistro
# 18      Fish & Chips          Pizza                   paul's fish grill
# 19             Kebab          Pizza         family kebab  and  pizzaria
# 20             Kebab          Pizza                 ram's kebab limited
# 21           Chinese        Chinese                         jasmine inn
# 22            Indian         Indian                      tandoori haven
# 23            Indian         Indian           the spice indian takeaway
# 24           Chicken          Pizza                           cafe zeus
# 25            Indian       European                jahangir st. andrews
# 26           British         Burger                      scruffy duffys
# 27            Indian         Indian           rangoli indian restaurant
# 28         Smoothies        Healthy                              elixir
# 29             Pizza          Kebab                        manton pizza
# ...              ...            ...                                 ...
# 19311        Chinese          Pizza                             yum yum
# 19312          Pizza         Burger                       yum yum pizza
# 19313          Kebab          Pizza                             yummies
# 19314          Kebab          Pizza                       yummies kebab
# 19315        Chinese        Chinese                               yummy
# 19316        Chinese        Chinese                        yummy garden
# 19317        Chinese        Chinese                         yummy house
# 19318        Chinese   Fish & Chips                       yummy kitchen
# 19319          Pizza          Pizza                         yummy pizza
# 19320        Chinese        Chinese                         yummy yummy
# 19321          Pizza          Kebab                       yummy's pizza
# 19322         Indian         Indian                             zaffran
# 19323        Chinese         Indian                               zaika
# 19324         Indian         Indian                               zaiqa
# 19325          Grill      Fast Food                             zam zam
# 19326          Kebab          Grill          zanzibraai bbq grill house
# 19327         Indian         Indian                zara indian takeaway
# 19328         Indian         Indian                          zara spice
# 19329          Grill         Burger                               zatar
# 19330        Kurdish        Kurdish                   zaytun restaurant
# 19331          Pizza          Pizza                          zaza pizza
# 19332         Indian         Indian                               zeera
# 19333         Indian         Indian                         zeera spice
# 19334         Indian         Indian                      zeera tandoori
# 19335  Sand/Caf/Bake        British                         zena's cafe
# 19336       American        Chicken                                zing
# 19337        Chinese        Chinese                           zing zing
# 19338       American          Kebab                              zorbas
# 19339       Lebanese  Mediterranean                                zufa
# 19340          Grill          Grill                     zulus peri peri
#
#         label_final
# 0                no
# 1                no
# 2            Indian
# 3                no
# 4            Indian
# 5            Indian
# 6            Indian
# 7            Indian
# 8                no
# 9            Indian
# 10           Indian
# 11               no
# 12     Fish & Chips
# 13               no
# 14               no
# 15               no
# 16               no
# 17               no
# 18     Fish & Chips
# 19               no
# 20               no
# 21          Chinese
# 22           Indian
# 23           Indian
# 24               no
# 25           Indian
# 26               no
# 27           Indian
# 28               no
# 29               no
# ...             ...
# 19311       Chinese
# 19312            no
# 19313            no
# 19314            no
# 19315       Chinese
# 19316       Chinese
# 19317       Chinese
# 19318       Chinese
# 19319            no
# 19320       Chinese
# 19321            no
# 19322        Indian
# 19323       Chinese
# 19324        Indian
# 19325            no
# 19326            no
# 19327        Indian
# 19328        Indian
# 19329            no
# 19330            no
# 19331            no
# 19332        Indian
# 19333        Indian
# 19334        Indian
# 19335            no
# 19336            no
# 19337       Chinese
# 19338            no
# 19339            no
# 19340            no
#
# [19341 rows x 4 columns]

# %%
# this section for scanning names
name_scan = ['Burger', 'Chicken', 'Kebab', 'Pizza', 'Fast Food']

for name in name_scan:
    df3[name] = 0
    df3[name] = np.where(df3.ascii_name_fix.str.contains(name.lower(), regex= True, na=False), 1, 0)
    df3['label_final'] = np.where(df3.ascii_name_fix.str.contains(name.lower(), regex= True, na=False), name, df3['label_final'])

    
df3['label_final'] = np.where(df3[name_scan].sum(axis = 1) > 1, 'Fast Food', df3['label_final'])

# %%
label_count = df3.groupby('label').ascii_name_fix.count().sort_values(ascending=False)

# %%
label_count2 = df3.groupby('label2').ascii_name_fix.count().sort_values(ascending=False)

# %%
df4 = pd.DataFrame(np.sort(df3[['label', 'label2']], axis=1), index=df.index)
df4.columns = ['label', 'label2']
combos = df4.groupby(['label', 'label2']).size().reset_index(name='counts')

# %%
combos[combos['label']=='Fast Food'],combos[combos['label2']=='Fast Food']
# Out:
# (         label         label2  counts
#  475  Fast Food   Fish & Chips      12
#  476  Fast Food         French       1
#  477  Fast Food        Gourmet       1
#  478  Fast Food          Grill       7
#  479  Fast Food        Healthy       2
#  480  Fast Food       Hot Dogs       1
#  481  Fast Food         Indian      24
#  482  Fast Food       Jamaican       1
#  483  Fast Food          Kebab      19
#  484  Fast Food          Lunch       2
#  485  Fast Food        Mexican       3
#  486  Fast Food      Peri Peri       3
#  487  Fast Food          Pizza      51
#  488  Fast Food  Sand/Caf/Bake       2
#  489  Fast Food          Vegan       2,          label     label2  counts
#  17     African  Fast Food       1
#  49    American  Fast Food       7
#  156    British  Fast Food       4
#  209     Burger  Fast Food      15
#  253  Caribbean  Fast Food       6
#  285    Chicken  Fast Food      29
#  322    Chinese  Fast Food       1
#  376   Desserts  Fast Food       6
#  435    English  Fast Food       1)

# %%
label_count[:15],label_count2[:15]
# Out:
# (label
#  Indian           4314
#  Pizza            3628
#  Chinese          2117
#  Fish & Chips     1331
#  Kebab            1268
#  Sand/Caf/Bake     838
#  Chicken           828
#  Desserts          678
#  Burger            600
#  American          346
#  Caribbean         333
#  Turkish           317
#  Thai              268
#  Peri Peri         247
#  Grill             229
#  Name: ascii_name_fix, dtype: int64, label2
#  Indian           3582
#  Pizza            3284
#  Kebab            2229
#  Chinese          1805
#  Burger           1219
#  Desserts          824
#  Sand/Caf/Bake     712
#  Chicken           634
#  Grill             469
#  American          337
#  Fish & Chips      304
#  British           255
#  Thai              244
#  English           243
#  Peri Peri         233
#  Name: ascii_name_fix, dtype: int64)

# %% [markdown]
# Optionally add the the Fast Food tag with outlets selling more than 2 of pizza, kebab, chicken, burger, fast food
#
# Or, override these categories to Fast Food

# %%
fast_foods = ['Fast Food', 'Pizza', 'Burger', 'Kebab', 'Chicken']

# %%
#option for fast food category separately
#
df3['label_final'] = np.where((df3['label'].isin(fast_foods)) & (df3['label2'].isin(fast_foods)) & 
                              (df3['label'] != df3['label2']) & (df3['label_final'] == 'no'), 'Fast Food', df3['label_final'])

# %%
df3[df3['ascii_name_fix']=='ibrahims']
# Out:
#              label    label2 ascii_name_fix label_final  Burger  Chicken  \
# 439  Sand/Caf/Bake  Desserts       ibrahims          no       0        0
#
#      Kebab  Pizza  Fast Food
# 439      0      0          0

# %%
#Chinese places serving fish and chips are Chinese
df3['label_final'] = np.where(((df3['label'] == 'Fish & Chips') & (df3['label2'] == 'Chinese') & (df3['label_final'] == 'no')), df3['label2'], df3['label_final'])

# %%
#burger can be in here but taken out later or converted to fast food
my_cuisines =  ['Pizza', 'Burger', 'Kebab', 'Chicken', 'Chinese', 'Indian', 'Fish & Chips', 'Desserts', 'Fast Food','Sand/Caf/Bake']
#my_cuisines =  ['Pizza', 'Kebab', 'Chicken', 'Chinese', 'Indian', 'Fish & Chips', 'Fast Food']
#my_cuisines =  ['Pizza', 'Kebab', 'Chicken', 'Chinese', 'Indian', 'Fish & Chips', 'Fast Food', 'Desserts']
df3['label_final'] = np.where((df3['label'].isin(my_cuisines) & (df3['label_final'] == 'no')), df3['label'], df3['label_final'])
df3['label_final'] = np.where((df3['label2'].isin(my_cuisines) & (df3['label_final'] == 'no')), df3['label2'], df3['label_final'])

# %%
#special section to convert all of 'Fast Food', 'Pizza', 'Burger', 'Kebab', 'Chicken' into fast food
# can be commented out
#df3['label_final'] = np.where(df3['label_final'].isin(fast_foods), 'Fast Food', df3['label_final'])

# %%
# either take out left over burgers, or convert to fast food
#df3 = df3[df3['label_final']!='Burger']
df3['label_final'] = np.where(df3['label_final'] == "Burger", 'Fast Food', df3['label_final'])

# %%
# either take out left over outlets, or convert to other
#df3 = df3[df3['label_final']!='no']
df3['label_final'] = np.where(df3['label_final'] == "no", 'Other', df3['label_final'])

# %%
len(df3)
# Out:
# 19341

# %% [markdown]
# ## Create Validation and Training Sets
#
# We want our final model to work well on any language.
#
# But if we pick our validation set uniformly at random from the data we're likely to get many Indian and not many African, which isn't a good test of this.
#
# So instead we'll take our validation set from an equal number from each subclass.

# %%
df3 = df3.reset_index().drop('index', 1)

# %%
counts = df3.groupby('label_final').ascii_name_fix.count().sort_values(ascending=False)
counts
# Out:
# label_final
# Indian           4474
# Fast Food        2941
# Pizza            2841
# Chinese          2357
# Other            1821
# Fish & Chips     1354
# Kebab            1015
# Sand/Caf/Bake    1000
# Chicken           783
# Desserts          755
# Name: ascii_name_fix, dtype: int64

# %%
valid_size = 400 # We'll pick 30 at random from each subclass
train_size = 2000 # For a balanced training set we'll pick 500 at random with replacement

# %%
np.random.seed(6011)
valid_idx = []
for label in counts.keys():
    # Random sample of size "valid_size" for each class
    valid_idx += list(df3[df3.label_final == label].sample(valid_size).index)

# %%
df3['valid'] = False
df3.loc[valid_idx, 'valid'] = True

# %%
np.random.seed(7012)
balanced_idx = []
for label in counts.keys():
    # Random sample of size "train_size" for each class from the data outside of the validation set
    balanced_idx += list(df3[(df3.label_final == label) & ~df3.valid].sample(train_size, replace=True).index)

# %%
#aims to maximise training data by oversampling smaller classes

np.random.seed(7012)
balanced_idx = []
for label in counts.keys():
    # Random sample of size "train_size" for each class from the data outside of the validation set
    balanced_idx += list(df3[(df3.label_final == label) & ~df3.valid].sample(counts[label]-valid_size).index)
    if counts[label] < train_size:
        balanced_idx += list(df3[(df3.label_final == label) & ~df3.valid].sample(train_size -(counts[label]-valid_size), replace=True).index)

# %%
df3.loc[balanced_idx].groupby('label_final').nunique().sort_values('ascii_name_fix', ascending=False)
# Out:
#                label  label2  ascii_name_fix  label_final  Burger  Chicken  \
# label_final
# Indian            27      49            4074            1       1        1
# Fast Food         44      45            2541            1       2        2
# Pizza             37      53            2441            1       1        1
# Chinese           20      37            1957            1       1        1
# Other             79      83            1421            1       1        1
# Fish & Chips      14      27             954            1       1        1
# Kebab             23      29             615            1       1        1
# Sand/Caf/Bake     32      35             600            1       1        1
# Chicken           28      30             383            1       1        2
# Desserts          24      23             355            1       1        1
#
#                Kebab  Pizza  Fast Food  valid
# label_final
# Indian             1      1          1      1
# Fast Food          2      2          2      1
# Pizza              1      2          1      1
# Chinese            1      1          1      1
# Other              1      1          1      1
# Fish & Chips       1      1          1      1
# Kebab              2      1          1      1
# Sand/Caf/Bake      1      1          1      1
# Chicken            1      1          1      1
# Desserts           1      1          1      1

# %% [markdown]
# Let's record our balanced set in the dataframe: this will make it easy to reload at a later point.

# %%
df3['bal'] = 0
for k, v in Counter(balanced_idx).items():
    df3.loc[k, 'bal'] += v

# %%
df3.to_csv('24_03_2020_use_name_ff_ind_other.csv', index=False)

# %%
df3
# Out:
#                label         label2                      ascii_name_fix  \
# 0            Chicken          Pizza  southern fried chicken  and  pizza
# 1              Kebab        Turkish                     j  and  d kebab
# 2             Indian         Indian             maharani indian cuisine
# 3          Caribbean      Fast Food                       sweet jamrock
# 4             Indian         Indian                             zaafran
# 5              Kebab         Indian                        omar sharifs
# 6             Indian         Indian                arifa tandoori house
# 7             Indian          Pizza                  charghas fast food
# 8             Burger        Chicken                         the grill-o
# 9             Indian     Vegetarian                stoneleigh brasserie
# 10            Indian         Indian                   manha spice house
# 11             Pizza          Kebab                     roberto's pizza
# 12      Fish & Chips          Kebab                              pop in
# 13             Pizza          Kebab                   varietys takeaway
# 14             Pizza         Fusion                            das kino
# 15             Pasta          Pizza  a mano coffee bar  and  restaurant
# 16          American          Kebab                         hot express
# 17           Turkish          Greek                the bosphorus bistro
# 18      Fish & Chips          Pizza                   paul's fish grill
# 19             Kebab          Pizza         family kebab  and  pizzaria
# 20             Kebab          Pizza                 ram's kebab limited
# 21           Chinese        Chinese                         jasmine inn
# 22            Indian         Indian                      tandoori haven
# 23            Indian         Indian           the spice indian takeaway
# 24           Chicken          Pizza                           cafe zeus
# 25            Indian       European                jahangir st. andrews
# 26           British         Burger                      scruffy duffys
# 27            Indian         Indian           rangoli indian restaurant
# 28         Smoothies        Healthy                              elixir
# 29             Pizza          Kebab                        manton pizza
# ...              ...            ...                                 ...
# 19311        Chinese          Pizza                             yum yum
# 19312          Pizza         Burger                       yum yum pizza
# 19313          Kebab          Pizza                             yummies
# 19314          Kebab          Pizza                       yummies kebab
# 19315        Chinese        Chinese                               yummy
# 19316        Chinese        Chinese                        yummy garden
# 19317        Chinese        Chinese                         yummy house
# 19318        Chinese   Fish & Chips                       yummy kitchen
# 19319          Pizza          Pizza                         yummy pizza
# 19320        Chinese        Chinese                         yummy yummy
# 19321          Pizza          Kebab                       yummy's pizza
# 19322         Indian         Indian                             zaffran
# 19323        Chinese         Indian                               zaika
# 19324         Indian         Indian                               zaiqa
# 19325          Grill      Fast Food                             zam zam
# 19326          Kebab          Grill          zanzibraai bbq grill house
# 19327         Indian         Indian                zara indian takeaway
# 19328         Indian         Indian                          zara spice
# 19329          Grill         Burger                               zatar
# 19330        Kurdish        Kurdish                   zaytun restaurant
# 19331          Pizza          Pizza                          zaza pizza
# 19332         Indian         Indian                               zeera
# 19333         Indian         Indian                         zeera spice
# 19334         Indian         Indian                      zeera tandoori
# 19335  Sand/Caf/Bake        British                         zena's cafe
# 19336       American        Chicken                                zing
# 19337        Chinese        Chinese                           zing zing
# 19338       American          Kebab                              zorbas
# 19339       Lebanese  Mediterranean                                zufa
# 19340          Grill          Grill                     zulus peri peri
#
#          label_final  Burger  Chicken  Kebab  Pizza  Fast Food  valid  bal
# 0          Fast Food       0        1      0      1          0  False    1
# 1              Kebab       0        0      1      0          0   True    0
# 2             Indian       0        0      0      0          0  False    1
# 3          Fast Food       0        0      0      0          0  False    1
# 4             Indian       0        0      0      0          0  False    1
# 5             Indian       0        0      0      0          0  False    1
# 6             Indian       0        0      0      0          0  False    1
# 7          Fast Food       0        0      0      0          1  False    1
# 8          Fast Food       0        0      0      0          0  False    1
# 9             Indian       0        0      0      0          0  False    1
# 10            Indian       0        0      0      0          0  False    1
# 11             Pizza       0        0      0      1          0  False    1
# 12      Fish & Chips       0        0      0      0          0  False    4
# 13         Fast Food       0        0      0      0          0  False    1
# 14             Pizza       0        0      0      0          0  False    1
# 15             Pizza       0        0      0      0          0  False    1
# 16             Kebab       0        0      0      0          0  False    3
# 17             Other       0        0      0      0          0   True    0
# 18      Fish & Chips       0        0      0      0          0  False    1
# 19         Fast Food       0        0      1      1          0  False    1
# 20             Kebab       0        0      1      0          0   True    0
# 21           Chinese       0        0      0      0          0  False    1
# 22            Indian       0        0      0      0          0  False    1
# 23            Indian       0        0      0      0          0  False    1
# 24         Fast Food       0        0      0      0          0  False    1
# 25            Indian       0        0      0      0          0  False    1
# 26         Fast Food       0        0      0      0          0  False    1
# 27            Indian       0        0      0      0          0  False    1
# 28             Other       0        0      0      0          0   True    0
# 29             Pizza       0        0      0      1          0  False    1
# ...              ...     ...      ...    ...    ...        ...    ...  ...
# 19311        Chinese       0        0      0      0          0   True    0
# 19312          Pizza       0        0      0      1          0  False    1
# 19313      Fast Food       0        0      0      0          0   True    0
# 19314          Kebab       0        0      1      0          0  False    3
# 19315        Chinese       0        0      0      0          0  False    1
# 19316        Chinese       0        0      0      0          0  False    1
# 19317        Chinese       0        0      0      0          0  False    1
# 19318        Chinese       0        0      0      0          0  False    1
# 19319          Pizza       0        0      0      1          0  False    1
# 19320        Chinese       0        0      0      0          0  False    1
# 19321          Pizza       0        0      0      1          0   True    0
# 19322         Indian       0        0      0      0          0   True    0
# 19323        Chinese       0        0      0      0          0  False    1
# 19324         Indian       0        0      0      0          0  False    1
# 19325      Fast Food       0        0      0      0          0  False    1
# 19326          Kebab       0        0      0      0          0  False    4
# 19327         Indian       0        0      0      0          0  False    1
# 19328         Indian       0        0      0      0          0  False    1
# 19329      Fast Food       0        0      0      0          0  False    1
# 19330          Other       0        0      0      0          0   True    0
# 19331          Pizza       0        0      0      1          0  False    1
# 19332         Indian       0        0      0      0          0   True    0
# 19333         Indian       0        0      0      0          0  False    1
# 19334         Indian       0        0      0      0          0  False    1
# 19335  Sand/Caf/Bake       0        0      0      0          0  False    3
# 19336        Chicken       0        0      0      0          0   True    0
# 19337        Chinese       0        0      0      0          0  False    1
# 19338          Kebab       0        0      0      0          0   True    0
# 19339          Other       0        0      0      0          0  False    1
# 19340          Other       0        0      0      0          0  False    1
#
# [19341 rows x 11 columns]

# %% [markdown]
# ## Build a Fastai Data Loader
#
# Load in the dataframe and extract indexes for training, validation and balanced trainings.

# %%
#df = pd.read_csv('24_03_2020_use_name_ff_ind_other.csv')
#df = pd.read_csv('24_03_2020_use_name_ff_ind.csv')
df = pd.read_csv('24_03_2020_use_name_sep_ff.csv')
#df = pd.read_csv('18_03_2020_use_name_sep_ff.csv')
#df = pd.read_csv('27_01_2020_use_name_no_burg.csv')

valid_idx = df[df.valid].index
train_idx = df[~df.valid].index

bal_idx = []
for k, v in zip(df.index, df.bal):
    bal_idx += [k]*v

# %%
df[df['label_final']=='Chicken']
# Out:
# Empty DataFrame
# Columns: [label, label2, ascii_name_fix, label_final, Burger, Chicken, Kebab, Pizza, Fast Food, valid, bal]
# Index: []

# %%
class LetterTokenizer(BaseTokenizer):
    "Character level tokenizer function."
    def __init__(self, lang): pass
    def tokenizer(self, t:str) -> List[str]:
        out = []
        i = 0
        while i < len(t):
            if t[i:].startswith(BOS):
                out.append(BOS)
                i += len(BOS)
            else:
                out.append(t[i])
                i += 1
        return out
            
    def add_special_cases(self, toks:Collection[str]): pass

# %%
itos = [UNK, BOS] + list(string.ascii_lowercase + " -'@&)(." +"0123456789")

# %%
vocab=Vocab(itos)
tokenizer=Tokenizer(LetterTokenizer, pre_rules=[], post_rules=[])

# %%
train_df = df.iloc[train_idx, [3,2]]
bal_df = df.iloc[bal_idx, [3,2]]
valid_df = df.iloc[valid_idx, [3,2]]

# %%
df.bal.max()
# Out:
# 13

# %% [markdown]
# ## Language model
#
# Language model with Just Eat data only

# %%
data = TextClasDataBunch.from_df(path='.', train_df=bal_df, valid_df=valid_df,
                         tokenizer=tokenizer, vocab=vocab,
                         mark_fields=False, bs=128)

# %%
learn = text_classifier_learner(data, AWD_LSTM,drop_mult=1.0)

# %%
learn.load_encoder('just_eat_enc_bs128_2')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
# lr = 1e-2
# moms = (0.7,0.8)
# scale = (1**4)
# cycles = 20
lr = 1e-2
moms = (0.7,0.8)
scale = (1**4)
cycles = 20

# %%
learn.fit_one_cycle(cycles, lr, moms=moms)
# Out:
# Total time: 04:18 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>1.694636</th>
#     <th>1.367048</th>
#     <th>0.554500</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.327646</th>
#     <th>1.139838</th>
#     <th>0.624500</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.208520</th>
#     <th>1.089448</th>
#     <th>0.649500</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.192155</th>
#     <th>1.079458</th>
#     <th>0.654500</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.176738</th>
#     <th>1.072330</th>
#     <th>0.653750</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>1.066269</th>
#     <th>1.082941</th>
#     <th>0.670250</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>1.039310</th>
#     <th>1.067451</th>
#     <th>0.669250</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>1.016304</th>
#     <th>1.035586</th>
#     <th>0.671750</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.990714</th>
#     <th>1.040993</th>
#     <th>0.681250</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.923841</th>
#     <th>1.015173</th>
#     <th>0.680250</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.912982</th>
#     <th>1.023221</th>
#     <th>0.685750</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.879990</th>
#     <th>1.021984</th>
#     <th>0.692000</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.827211</th>
#     <th>1.046042</th>
#     <th>0.693000</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.801323</th>
#     <th>1.040610</th>
#     <th>0.696500</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.748636</th>
#     <th>1.062564</th>
#     <th>0.690750</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.718188</th>
#     <th>1.064133</th>
#     <th>0.690750</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.662116</th>
#     <th>1.074598</th>
#     <th>0.691750</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.701373</th>
#     <th>1.090286</th>
#     <th>0.694500</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.675897</th>
#     <th>1.075773</th>
#     <th>0.693500</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.683743</th>
#     <th>1.085624</th>
#     <th>0.691500</th>
#     <th>00:12</th>
#   </tr>
# </table>

# %%
learn.fit_one_cycle(cycles, lr, moms=moms)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='17' class='' max='20', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       85.00% [17/20 03:42<00:39]
#     </div>
#
# <table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>0.681482</th>
#     <th>1.088964</th>
#     <th>0.693750</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.667199</th>
#     <th>1.115001</th>
#     <th>0.690250</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.726251</th>
#     <th>1.089911</th>
#     <th>0.697250</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.742061</th>
#     <th>1.106566</th>
#     <th>0.693750</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.749401</th>
#     <th>1.079967</th>
#     <th>0.692500</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.811146</th>
#     <th>1.114923</th>
#     <th>0.689750</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.808382</th>
#     <th>1.062313</th>
#     <th>0.687500</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.783303</th>
#     <th>1.117974</th>
#     <th>0.685500</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.777148</th>
#     <th>1.100301</th>
#     <th>0.700000</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.727977</th>
#     <th>1.109928</th>
#     <th>0.690250</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.707465</th>
#     <th>1.162987</th>
#     <th>0.693000</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.713025</th>
#     <th>1.153167</th>
#     <th>0.690000</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.686277</th>
#     <th>1.156408</th>
#     <th>0.694500</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.634609</th>
#     <th>1.176224</th>
#     <th>0.693250</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.619190</th>
#     <th>1.167516</th>
#     <th>0.698000</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.574193</th>
#     <th>1.217634</th>
#     <th>0.696500</th>
#     <th>00:13</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.570615</th>
#     <th>1.215418</th>
#     <th>0.696000</th>
#     <th>00:13</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='113' class='' max='179', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       63.13% [113/179 00:07<00:04 0.5758]
#     </div>

# %%
learn.fit_one_cycle(cycles, lr, moms=moms)
# Out:
# Total time: 03:53 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>0.448901</th>
#     <th>1.848607</th>
#     <th>0.622500</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.451448</th>
#     <th>1.935387</th>
#     <th>0.619444</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.502471</th>
#     <th>1.892720</th>
#     <th>0.615833</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.491539</th>
#     <th>1.867887</th>
#     <th>0.611667</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.549414</th>
#     <th>1.709892</th>
#     <th>0.623889</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.588179</th>
#     <th>1.675335</th>
#     <th>0.612222</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.583970</th>
#     <th>1.672935</th>
#     <th>0.631111</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.552800</th>
#     <th>1.720846</th>
#     <th>0.616667</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.587069</th>
#     <th>1.625810</th>
#     <th>0.622222</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.541057</th>
#     <th>1.781037</th>
#     <th>0.604722</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.511456</th>
#     <th>1.765101</th>
#     <th>0.615278</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.498840</th>
#     <th>1.774489</th>
#     <th>0.622500</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.470490</th>
#     <th>1.902389</th>
#     <th>0.615278</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.467259</th>
#     <th>1.957992</th>
#     <th>0.618056</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.443573</th>
#     <th>1.963255</th>
#     <th>0.610833</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.460507</th>
#     <th>1.957869</th>
#     <th>0.620278</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.405656</th>
#     <th>1.980630</th>
#     <th>0.609722</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.383453</th>
#     <th>1.987294</th>
#     <th>0.608056</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.383433</th>
#     <th>1.984578</th>
#     <th>0.609444</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.380794</th>
#     <th>1.976778</th>
#     <th>0.611389</th>
#     <th>00:11</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('2020_03_23_sep_ff_ind_other')

# %%
learn.freeze_to(-2)

# %%
learn.fit_one_cycle(cycles, slice((lr/2)/scale,(lr/2)), moms=moms)
#learn.fit_one_cycle(5, slice(5e-3/(2.6**4),5e-3), moms=(0.2,0.1))
# Out:
# Total time: 00:58 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>1.302489</th>
#     <th>1.210643</th>
#     <th>0.608889</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.147067</th>
#     <th>1.205897</th>
#     <th>0.625079</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.043286</th>
#     <th>1.198088</th>
#     <th>0.634921</th>
#     <th>00:12</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.959284</th>
#     <th>1.212335</th>
#     <th>0.638730</th>
#     <th>00:11</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.937127</th>
#     <th>1.237250</th>
#     <th>0.638095</th>
#     <th>00:11</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.freeze_to(-3)
#learn.fit_one_cycle(5, slice(1e-4 / (2.6 ** 4), 1e-4), moms=(0.2, 0.1))
learn.fit_one_cycle(cycles, slice((lr/10)/scale,(lr/10)), moms=moms)
# Out:
# Total time: 01:32 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#     <th>time</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>0.895113</th>
#     <th>1.222485</th>
#     <th>0.637778</th>
#     <th>00:17</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.889085</th>
#     <th>1.226429</th>
#     <th>0.636825</th>
#     <th>00:18</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.881259</th>
#     <th>1.236015</th>
#     <th>0.634286</th>
#     <th>00:20</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.881231</th>
#     <th>1.257907</th>
#     <th>0.636190</th>
#     <th>00:17</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.855727</th>
#     <th>1.272891</th>
#     <th>0.634286</th>
#     <th>00:18</th>
#   </tr>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(5, slice(5e-5 / (2.6 ** 4), 5e-5), moms=(0.2, 0.1))

# %%
    def confusion_matrix(self):
        "Confusion matrix as an `np.ndarray`"
        x=torch.arange(0,data.c)
        cm = ((self.pred_class==x[:,None]) & (self.y_true==x[:,None,None])).sum(2)
        return cm.cpu().numpy()

    def plot_confusion_matrix(self, normalize:bool=False, title:str='Confusion matrix', cmap:Any="Blues", figsize:tuple=None):
        "Plot the confusion matrix"
        # This function is copied from the scikit docs
        cm = self.confusion_matrix()
        plt.figure(figsize=figsize)
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, self.data.classes, rotation=45)
        plt.yticks(tick_marks, self.data.classes)

        if normalize: cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')

# %%
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)

# %%
interp.plot_confusion_matrix(figsize=(10,10))

# %%
interp.plot_confusion_matrix(figsize=(10,10))

# %%
interp.plot_confusion_matrix(figsize=(10,10))

# %%
interp.plot_confusion_matrix(figsize=(10,10))

# %%
learn.load('2020_03_23_sep_ff_only')
# Out:
# RNNLearner(data=TextClasDataBunch;
#
# Train: LabelList (19211 items)
# x: TextList
# xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a,xxbos   j     a n d     d   k e b a b,xxbos   m a h a r a n i   i n d i a n   c u i s i n e,xxbos   s w e e t   j a m r o c k,xxbos   z a a f r a n
# y: CategoryList
# Fast Food,Fast Food,Indian,Fast Food,Indian
# Path: .;
#
# Valid: LabelList (2400 items)
# x: TextList
# xxbos   j a s m i n e   i n n,xxbos   t a n d o o r i   h a v e n,xxbos   s h a k e xxunk   w a f f l e   n   r o l l,xxbos   c h e n n a i   d o s a   a r t i s a n z,xxbos   c a f e     b a g e l
# y: CategoryList
# Chinese,Indian,Desserts,Indian,Sand/Caf/Bake
# Path: .;
#
# Test: None, model=SequentialRNN(
#   (0): MultiBatchEncoder(
#     (module): AWD_LSTM(
#       (encoder): Embedding(46, 400, padding_idx=1)
#       (encoder_dp): EmbeddingDropout(
#         (emb): Embedding(46, 400, padding_idx=1)
#       )
#       (rnns): ModuleList(
#         (0): WeightDropout(
#           (module): LSTM(400, 1150, batch_first=True)
#         )
#         (1): WeightDropout(
#           (module): LSTM(1150, 1150, batch_first=True)
#         )
#         (2): WeightDropout(
#           (module): LSTM(1150, 400, batch_first=True)
#         )
#       )
#       (input_dp): RNNDropout()
#       (hidden_dps): ModuleList(
#         (0): RNNDropout()
#         (1): RNNDropout()
#         (2): RNNDropout()
#       )
#     )
#   )
#   (1): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.4)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x2ae9da747730>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('.'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: ...
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): Embedding(46, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(46, 400, padding_idx=1)
#   )
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): PoolingLinearClassifier(
#     (layers): Sequential(
#       (0): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): Dropout(p=0.4)
#       (2): Linear(in_features=1200, out_features=50, bias=True)
#       (3): ReLU(inplace)
#       (4): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): Dropout(p=0.1)
#       (6): Linear(in_features=50, out_features=6, bias=True)
#     )
#   )
# )], add_time=True, silent=None)

# %%
#txt_ci = TextClassificationInterpretation.from_learner(learn)
interp2 = TextClassificationInterpretation(learn, *learn.get_preds(with_loss=True, ordered=True))

# %%
#txt_ci.show_top_losses(20)
blah = interp2.show_top_losses(10000)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Text</th>
#       <th>Prediction</th>
#       <th>Actual</th>
#       <th>Loss</th>
#       <th>Probability</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos   k a b a b j i</td>
#       <td>Indian</td>
#       <td>Sand/Caf/Bake</td>
#       <td>16.13</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   c h i c h i n i</td>
#       <td>Fast Food</td>
#       <td>Sand/Caf/Bake</td>
#       <td>14.92</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   a p r i l ' s   c a f e</td>
#       <td>Sand/Caf/Bake</td>
#       <td>Desserts</td>
#       <td>14.75</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   t i k k a   d e l i g h t</td>
#       <td>Indian</td>
#       <td>Sand/Caf/Bake</td>
#       <td>14.50</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s u g a r   l u m p</td>
#       <td>Desserts</td>
#       <td>Sand/Caf/Bake</td>
#       <td>13.42</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p a p a s   f i s h   a n d   c h i p s</td>
#       <td>Fish &amp; Chips</td>
#       <td>Sand/Caf/Bake</td>
#       <td>13.32</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   e m o c h i</td>
#       <td>Indian</td>
#       <td>Desserts</td>
#       <td>13.10</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   c o o p e r   t h a i   r e s t a u r a n t</td>
#       <td>Chinese</td>
#       <td>Sand/Caf/Bake</td>
#       <td>12.97</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   t u c k   i n n</td>
#       <td>Chinese</td>
#       <td>Desserts</td>
#       <td>12.61</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   m o n o l o s</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>12.43</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   d o n   p e r f e t t o</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>12.36</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p i c c a d i l l y</td>
#       <td>Fast Food</td>
#       <td>Sand/Caf/Bake</td>
#       <td>12.24</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p i r l o ' s</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>12.07</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s u g a r   k i n g</td>
#       <td>Desserts</td>
#       <td>Fish &amp; Chips</td>
#       <td>11.91</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   r e s t a u r a c j a   d o m   p o l s k i</td>
#       <td>Indian</td>
#       <td>Desserts</td>
#       <td>11.53</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   t i f f i n   @   d a y t o d a y</td>
#       <td>Indian</td>
#       <td>Sand/Caf/Bake</td>
#       <td>11.37</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   b a n a n a   i s l a n d   c a r i b b e a n   c u i s i n e</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>11.16</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   m a m m a   m i a ' s</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>11.07</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   t i n y   r i c k ' s   c a f e</td>
#       <td>Sand/Caf/Bake</td>
#       <td>Desserts</td>
#       <td>10.96</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   m r   n i t r o ' s</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>10.85</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   k a r d e l o w</td>
#       <td>Indian</td>
#       <td>Desserts</td>
#       <td>10.78</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   w o o d y   g r i l l</td>
#       <td>Fast Food</td>
#       <td>Sand/Caf/Bake</td>
#       <td>10.77</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   n u t t y e l l a</td>
#       <td>Sand/Caf/Bake</td>
#       <td>Desserts</td>
#       <td>10.72</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   y a h g o</td>
#       <td>Indian</td>
#       <td>Desserts</td>
#       <td>10.64</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   m o x i e s   f i s h   b a r</td>
#       <td>Fish &amp; Chips</td>
#       <td>Sand/Caf/Bake</td>
#       <td>10.43</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   e a s y   e a t s</td>
#       <td>Chinese</td>
#       <td>Desserts</td>
#       <td>10.14</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   w 2   b u b b l e   t e a     a n d     b u b b l e   w a f f l e s</td>
#       <td>Desserts</td>
#       <td>Chinese</td>
#       <td>10.01</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   q u i z n o s</td>
#       <td>Fast Food</td>
#       <td>Sand/Caf/Bake</td>
#       <td>9.86</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p a p a s   a m e r i c a n   d i n e r</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>9.78</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   w h i t c h u r c h   e a t   h o u s e</td>
#       <td>Chinese</td>
#       <td>Desserts</td>
#       <td>9.77</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s o u v l a k i</td>
#       <td>Fast Food</td>
#       <td>Sand/Caf/Bake</td>
#       <td>9.76</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   a g o r a</td>
#       <td>Indian</td>
#       <td>Sand/Caf/Bake</td>
#       <td>9.68</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   m e l t   b o x</td>
#       <td>Sand/Caf/Bake</td>
#       <td>Desserts</td>
#       <td>9.53</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   d o o r s t e p s   c a t e r i n g</td>
#       <td>Sand/Caf/Bake</td>
#       <td>Desserts</td>
#       <td>9.47</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   g u l l i v e r s</td>
#       <td>Indian</td>
#       <td>Fish &amp; Chips</td>
#       <td>9.33</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   d a n d a n s   c a r i b b e a n   r e s t a u r a n t     a n d     t a k e a w a y</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>9.30</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   h o t   s p i c y   c a r i b b e a n   t a k e a w a y</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>9.26</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   m e a t   ' n '   e a t</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>9.25</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s h i s h   l e g e n d s   f u s i o n   t u r k i s h   m e z e</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>9.21</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   k a s p a ' s</td>
#       <td>Indian</td>
#       <td>Desserts</td>
#       <td>9.19</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   h o t   l y f e</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>9.14</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   p l a v a   l a g u n a</td>
#       <td>Indian</td>
#       <td>Sand/Caf/Bake</td>
#       <td>9.12</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   y u m m y   b i t e s</td>
#       <td>Chinese</td>
#       <td>Desserts</td>
#       <td>9.11</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   l i m e   c u i s i n e</td>
#       <td>Indian</td>
#       <td>Desserts</td>
#       <td>8.68</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   b i g m u n c h</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>8.62</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   s m a s h   i t</td>
#       <td>Indian</td>
#       <td>Desserts</td>
#       <td>8.60</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   e l s h a   d e l i g h t</td>
#       <td>Indian</td>
#       <td>Sand/Caf/Bake</td>
#       <td>8.57</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   c a s p a r</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>
#       <td>8.56</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <td>xxbos   a r t i s a n</td>
#       <td>Fast Food</td>
#       <td>Desserts</td>

# %%
interp2.
# Out:
# TextClasDataBunch;
#
# Train: LabelList (45000 items)
# x: TextList
# xxbos   s o u t h e r n   f r i e d   c h i c k e n     a n d     p i z z a,xxbos   m a h a r a n i   i n d i a n   c u i s i n e,xxbos   s w e e t   j a m r o c k,xxbos   s w e e t   j a m r o c k,xxbos   z a a f r a n
# y: CategoryList
# Fast Food,Indian,Fast Food,Fast Food,Indian
# Path: .;
#
# Valid: LabelList (3600 items)
# x: TextList
# xxbos   j     a n d     d   k e b a b,xxbos   v a r i e t y s   t a k e a w a y,xxbos   h o t   e x p r e s s,xxbos   f a m i l y   k e b a b     a n d     p i z z a r i a,xxbos   s u r f     a n d     t u r f
# y: CategoryList
# Kebab,Fast Food,Kebab,Fast Food,Fast Food
# Path: .;
#
# Test: None

# %%
my_top_losses = interp2.top_losses()
my_ds = interp2.data.dl('Valid').dataset
my_classes = interp2.data.valid_ds.classes
my_preds_class = interp2.pred_class
tl_val,tl_idx = my_top_losses


items = []
for idx in tl_idx:
    tx,cl = interp2.data.valid_ds[idx]
    cl = cl.data
    txt =  ' '.join([''.join(i.split()) for i in re.split(r' {2,}',tx.text)])[6:]
    tmp = [txt, f'{my_classes[my_preds_class[idx]]}', f'{my_classes[cl]}']
    items.append(tmp)
items = np.array(items)
names = ['Text', 'Prediction', 'Actual']
df = pd.DataFrame({n:items[:,i] for i,n in enumerate(names)}, columns=names)

# %%
df.to_csv('13_01_2020_errors.csv', index=False)

# %%
cm = interp2.confusion_matrix()

# %%
plt.rcParams.update({'font.size': 14})
interp2.plot_confusion_matrix(figsize=(8,8))

# %%
#Precision = tp / tp + fp
recall = np.diag(cm) / np.sum(cm, axis = 1)
precision = np.diag(cm) / np.sum(cm, axis = 0)

# %%
recall
# Out:
# array([0.805 , 0.7   , 0.8875, 0.785 , 0.8525, 0.5775])

# %%
precision
# Out:
# array([0.879781, 0.875   , 0.541985, 0.931751, 0.787529, 0.799308])

# %%
precision.mean()
# Out:
# 0.8025589537111673

# %%
recall.mean()
# Out:
# 0.7679166666666667

# %%
learn.predict("mamoods mirch")
# Out:
# (Category Desserts,
#  tensor(2),
#  tensor([0.1397, 0.0117, 0.3502, 0.1343, 0.0332, 0.0265, 0.0559, 0.1784, 0.0701]))

# %%
learn.predict("fryer tuck")
# Out:
# (Category Fish & Chips,
#  tensor(4),
#  tensor([3.3629e-07, 1.2309e-03, 3.5925e-06, 8.1342e-04, 9.9777e-01, 9.5526e-05,
#          4.4523e-06, 3.9081e-05, 4.0542e-05]))

# %%
learn.predict("jade garden")
# Out:
# (Category Chinese,
#  tensor(1),
#  tensor([2.3990e-07, 9.9865e-01, 2.2686e-07, 2.7119e-04, 5.1614e-05, 9.7042e-04,
#          1.6681e-06, 3.7176e-05, 1.4342e-05]))

# %%
learn.predict("jerk house")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([0.2168, 0.0406, 0.6402, 0.0161, 0.0781, 0.0083]))

# %%
learn.predict("abra kebabra")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([2.4363e-05, 9.9402e-07, 9.9972e-01, 2.5463e-07, 2.4918e-04, 2.0597e-07]))

# %%
learn.predict("mcdoner")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([3.2807e-03, 5.0873e-04, 9.7921e-01, 6.8078e-03, 9.9109e-03, 2.7945e-04]))

# %%
learn.predict("southern fried rooster")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([1.2324e-02, 4.9889e-04, 9.6919e-01, 4.4617e-03, 1.1890e-02, 1.6323e-03]))

# %%
learn.predict("luigis pizza parlour")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([1.8512e-04, 1.0966e-05, 9.9935e-01, 4.0324e-05, 3.8692e-04, 2.2607e-05]))

# %%
learn.predict("mrs boggins sandwich shop")
# Out:
# (Category Sand/Caf/Bake,
#  tensor(5),
#  tensor([1.2056e-05, 4.1230e-05, 2.2578e-04, 1.1115e-05, 3.0048e-06, 9.9971e-01]))

# %%
learn.predict("codfather")
# Out:
# (Category Fish & Chips,
#  tensor(3),
#  tensor([5.8303e-05, 7.2931e-06, 5.3680e-03, 9.9445e-01, 4.3550e-05, 7.2614e-05]))

# %%
learn.predict("top chef")
# Out:
# (Category Chinese,
#  tensor(0),
#  tensor([7.6555e-01, 1.6182e-03, 1.3469e-01, 5.7949e-03, 9.1621e-02, 7.2157e-04]))

# %%
learn.predict("doner cha want me")
# Out:
# (Category Indian,
#  tensor(4),
#  tensor([0.1948, 0.0015, 0.3805, 0.0207, 0.3818, 0.0207]))

# %%
learn.predict("kebabs r us")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([3.2910e-05, 6.0077e-08, 9.9990e-01, 9.7345e-08, 6.6743e-05, 2.0561e-07]))

# %%
learn.predict("sapna")
# Out:
# (Category Indian,
#  tensor(4),
#  tensor([2.1046e-02, 7.7136e-05, 2.6818e-01, 1.6395e-03, 7.0792e-01, 1.1401e-03]))

# %%
learn.predict("cocum")
# Out:
# (Category Indian,
#  tensor(4),
#  tensor([1.2241e-02, 2.1769e-04, 9.6867e-02, 6.4483e-04, 8.8962e-01, 4.1378e-04]))

# %%
learn.predict("uncle sam")
# Out:
# (Category Fast Food,
#  tensor(2),
#  tensor([0.0388, 0.1145, 0.4139, 0.1552, 0.2734, 0.0042]))
